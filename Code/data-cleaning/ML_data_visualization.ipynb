# %%
import re
dataFilePath = "dataset/sample.md"

dataFile = open(dataFilePath)

# %%
include_Product_Name_in_Dataset = 1

dictionary = {}

ingdList = []

buf = []
for line in dataFile.readlines():
    if(len(line) > 2):
        ## Check if new ingridient has started
        if (line[1] == "." or line[2] == "."):
            # store product name
            # words = line.split(' ')
            # words 


            # store ingridients from buf to list
            ingdList.append(buf)
            buf = []
        else:
            spaceCount = line.count(' ')
            newLineCount = line.count('\n')

            # check if it has other character than space and new line
            if (spaceCount + newLineCount != len(line)):
              if(line[0] == '-' or line[0] == '.'):
                line = line[1:]
                while(line[0] == ' '):
                  line = line[1:]
                while(line[-1] == '\n'):
                  line = line[0:-1]
                buf.append(line)


print(ingdList)
# Out:
# [[], ['Milk Fat (80%), Moisture (16%), Salt (3%), permitted natural color (Annatto)'], ['Sugar, Milk Solids (23%), Cocoa Butter, Cocoa Solids, Emulsifiers (442, 476), Vegetable Fat, Maltitol, Flavoring Substances, Contains added flavors (Artificial (Vanilla and Chocolate)), Sweetener (Maltitol (965 I)).'], ['Moong Dal (52%), Edible Vegetable Oil, Salt, Red Chilli Powder, Black Pepper Powder, Cumin Powder, Dry Ginger Powder.'], ['Noodles: Wheat Flour, Palm Oil, Salt, Wheat Gluten, Mineral (Calcium Carbonate), Guar Gum, Sodium Tripolyphosphate, Potassium Carbonate, Sodium Carbonate. Masala Tastemaker: Hydrolysed groundnut (peanut) protein, Mixed spices {(23.9%) (Dehydrated onion, Coriander powder, Red chilli powder (3.3%), Turmeric powder, Ginger powder, Cumin powder, Aniseed, Fenugreek powder, Garlic powder, Clove powder, Black pepper powder)}, Noodle Powder {Wheat flour, Palm oil, Salt, Wheat gluten, Mineral (Calcium carbonate), Guar gum, Sodium triphosphate, Potassium carbonate, Sodium carbonate}, Sugar, Edible starch, Palm oil, Acidifying agent (Citric acid), Colour (Plain caramel), Salt, Mineral (Ferric pyrophosphate), Flavour enhancer (Monosodium glutamate), Wheat protein, Raising agent (Sodium bicarbonate).'], ['Wheat Flour, Sugar, Vegetable Oil, Tutti Frutti (5%), Raisins (5%), Liquid Glucose, Butter, Dextrose Monohydrate, Glycerine, Skimmed Milk Powder, Wheat Bran, Starch, Salt, Emulsifiers [471, 477, 481 (i)], Leavening Agents [450 (i), 500 (ii)], Acidity Regulators [330, 260, 341 (i)], Preservatives [202, 282], Spices & Condiments (Clove, Cinnamon).'], ['Coriander, Cumin, Turmeric, Black Pepper, Cloves, Nutmeg, Dry Ginger, Cassia, Cardamom Seeds, Red Chillies, Fennel, Bay Leaf, Salt, Mustard, Garlic Flakes, Onion Flakes, Mace.'], ['100% Masoor Dal (Split Red Lentil).'], ['Dehydrated Vegetables [Tomato (22.5%), Onion], Iodized Salt, Starch, Sugar, Edible Vegetable Oil, Acidifying Agent (Citric Acid), Hydrolyzed Vegetable Protein, Spices and Condiments [Cumin Powder, Turmeric Powder, Garlic Powder, Coriander Powder, Red Chilli Powder (0.4%)], Flavour Enhancers (Disodium Guanylate, Disodium Inosinate), Thickener (Xanthan Gum), Antioxidant (E320).'], ['Potato (57%), Edible Vegetable Oil, Chickpea Flour (10%), Salt, Red Chilli Powder, Mango Powder, Black Salt.'], [], ['Wheat Flour, Sugar, Refined Palm Oil, Invert Syrup, Leavening [Ammonium Bicarbonate (E 503 (ii)), Sodium Bicarbonate (E 500(ii)), Salt, Skim Milk Powder, Soya Lecithin (E 322), Artificial Vanilla Flavor, Sodium Metabisulphite (E 223) as Preservative.'], ['Sugar, Acidity Regulator (330), Contains Permitted Synthetic Food Colour (110) and Added Orange Flavours (Natural and Nature Identical Flavouring Substances).'], ['Atta Noodles (90.5%) [Wheat Flour, Edible Veg Oil, Salt, Mineral (Calcium Carbonate), Guar Gum], Spice Mix (9.5%) [Mixed Spices {Red Chilli Powder (3.2%), Turmeric Powder, Coriander Powder, Dry Ginger Powder, Cumin Powder, Aniseed Powder, Fenugreek Powder, Black Pepper Powder, Clove Powder, Nutmeg Powder, Cardamom Powder (1.7%), Cinnamon Powder (1.7%), Mustard Powder, Curry Leaf Powder, Mace Powder}, Dehydrated Onion, Sugar, Edible Starch, Hydrolysed Groundnut Protein, Salt, Tomato Powder, Edible Vegetable Oil, Garlic Powder, Acidifying Agent (Citric Acid), Flavour Enhancers (Disodium 5’-Ribonucleotide).'], ['Sugar, Wheat Flour, Vegetable Oil, Cocoa Solids, Invert Syrup, Leavening Agents [503(ii), 500(ii)], Salt, Milk Solids, Emulsifiers [322(i), 471], Permitted Flavor.'], ['Coriander, Cumin, Red Chilli, Turmeric, Black Pepper, Mustard, Dry Mango Powder, Fenugreek Leaves, Salt, Pomegranate Seeds, Nutmeg, Cloves, Caraway, Green Cardamom, Mace, Cinnamon, Bay Leaves, Asafoetida.'], ['Gram Flour (65%), Edible Vegetable Oil, Tapioca Starch, Salt, Red Chilli Powder, Mango Powder, Black Salt, Acidity Regulator (E 330).'], ['Noodles [Wheat Flour, Palm Oil, Salt, Wheat Gluten, Mineral (Calcium Carbonate), Guar Gum, Sodium Tripolyphosphate, Potassium Carbo ...

# %%
def letters2(input):
    valids = []
    for character in input:
        if character.isalpha() or character == ' ' or character == ',':
            valids.append(character)
    return ''.join(valids)

# %%
def letters(input):
    return re.sub(r"[^A-Za-z ,]+", '', input)

# %%
words = []
for ingridient in ingdList:
    if(type(ingridient) == list and len(ingridient) > 0):
        ingridient = ingridient[0]
    for word in ingridient:
        onlyLetters = ''.join(letters(word.lower()))
        words.append(onlyLetters)

# %%
sentence = ''
for letter in words:
    sentence += letter

# %%
sentence
# Out:
# 'milk fat , moisture , salt , permitted natural color annattosugar, milk solids , cocoa butter, cocoa solids, emulsifiers , , vegetable fat, maltitol, flavoring substances, contains added flavors artificial vanilla and chocolate, sweetener maltitol  imoong dal , edible vegetable oil, salt, red chilli powder, black pepper powder, cumin powder, dry ginger powdernoodles wheat flour, palm oil, salt, wheat gluten, mineral calcium carbonate, guar gum, sodium tripolyphosphate, potassium carbonate, sodium carbonate masala tastemaker hydrolysed groundnut peanut protein, mixed spices  dehydrated onion, coriander powder, red chilli powder , turmeric powder, ginger powder, cumin powder, aniseed, fenugreek powder, garlic powder, clove powder, black pepper powder, noodle powder wheat flour, palm oil, salt, wheat gluten, mineral calcium carbonate, guar gum, sodium triphosphate, potassium carbonate, sodium carbonate, sugar, edible starch, palm oil, acidifying agent citric acid, colour plain caramel, salt, mineral ferric pyrophosphate, flavour enhancer monosodium glutamate, wheat protein, raising agent sodium bicarbonatewheat flour, sugar, vegetable oil, tutti frutti , raisins , liquid glucose, butter, dextrose monohydrate, glycerine, skimmed milk powder, wheat bran, starch, salt, emulsifiers , ,  i, leavening agents  i,  ii, acidity regulators , ,  i, preservatives , , spices  condiments clove, cinnamoncoriander, cumin, turmeric, black pepper, cloves, nutmeg, dry ginger, cassia, cardamom seeds, red chillies, fennel, bay leaf, salt, mustard, garlic flakes, onion flakes, mace masoor dal split red lentildehydrated vegetables tomato , onion, iodized salt, starch, sugar, edible vegetable oil, acidifying agent citric acid, hydrolyzed vegetable protein, spices and condiments cumin powder, turmeric powder, garlic powder, coriander powder, red chilli powder , flavour enhancers disodium guanylate, disodium inosinate, thickener xanthan gum, antioxidant epotato , edible vegetable oil, chickpea flour , salt, red chilli powder, mango powder, black saltwheat flour, sugar, refined palm oil, invert syrup, leavening ammonium bicarbonate e  ii, sodium bicarbonate e ii, salt, skim milk powder, soya lecithin e , artificial vanilla flavor, sodium metabisulphite e  as preservativesugar, acidity regulator , contains permitted synthetic food colour  and added orange flavours natural and nature identical flavouring substancesatta noodles  wheat flour, edible veg oil, salt, mineral calcium carbonate, guar gum, spice mix  mixed spices red chilli powder , turmeric powder, coriander powder, dry ginger powder, cumin powder, aniseed powder, fenugreek powder, black pepper powder, clove powder, nutmeg powder, cardamom powder , cinnamon powder , mustard powder, curry leaf powder, mace powder, dehydrated onion, sugar, edible starch, hydrolysed groundnut protein, salt, tomato powder, edible vegetable oil, garlic powder, acidifying agent citric acid, flavour enhancers disodium ribonucleotidesugar, wheat flour, vegetable oil, cocoa solids, invert syrup, leavening agents ii, ii, salt, milk solids, emulsifiers i, , permitted flavorcoriander, cumin, red chilli, turmeric, black pepper, mustard, dry mango powder, fenugreek leaves, salt, pomegranate seeds, nutmeg, cloves, caraway, green cardamom, mace, cinnamon, bay leaves, asafoetidagram flour , edible vegetable oil, tapioca starch, salt, red chilli powder, mango powder, black salt, acidity regulator e noodles wheat flour, palm oil, salt, wheat gluten, mineral calcium carbonate, guar gum, sodium tripolyphosphate, potassium carbonate, sodium carbonate, seasoning mix dehydrated vegetables tomato, garlic, sugar, salt, corn starch, edible vegetable oil, hydrolyzed vegetable protein, flavour enhancer , spices and condiments cumin powder, turmeric powder, black pepper powder, red chilli powder , fenugreek powder, thickener , acidity regulator , antioxidant cheese , water, emulsifiers e , e , e , common salt, acidity regulator e , preservativ ...

# %%
sentence.split(', ')
# Out:
# ['milk fat ',
#  'moisture ',
#  'salt ',
#  'permitted natural color annattosugar',
#  'milk solids ',
#  'cocoa butter',
#  'cocoa solids',
#  'emulsifiers ',
#  '',
#  'vegetable fat',
#  'maltitol',
#  'flavoring substances',
#  'contains added flavors artificial vanilla and chocolate',
#  'sweetener maltitol  imoong dal ',
#  'edible vegetable oil',
#  'salt',
#  'red chilli powder',
#  'black pepper powder',
#  'cumin powder',
#  'dry ginger powdernoodles wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium tripolyphosphate',
#  'potassium carbonate',
#  'sodium carbonate masala tastemaker hydrolysed groundnut peanut protein',
#  'mixed spices  dehydrated onion',
#  'coriander powder',
#  'red chilli powder ',
#  'turmeric powder',
#  'ginger powder',
#  'cumin powder',
#  'aniseed',
#  'fenugreek powder',
#  'garlic powder',
#  'clove powder',
#  'black pepper powder',
#  'noodle powder wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium triphosphate',
#  'potassium carbonate',
#  'sodium carbonate',
#  'sugar',
#  'edible starch',
#  'palm oil',
#  'acidifying agent citric acid',
#  'colour plain caramel',
#  'salt',
#  'mineral ferric pyrophosphate',
#  'flavour enhancer monosodium glutamate',
#  'wheat protein',
#  'raising agent sodium bicarbonatewheat flour',
#  'sugar',
#  'vegetable oil',
#  'tutti frutti ',
#  'raisins ',
#  'liquid glucose',
#  'butter',
#  'dextrose monohydrate',
#  'glycerine',
#  'skimmed milk powder',
#  'wheat bran',
#  'starch',
#  'salt',
#  'emulsifiers ',
#  '',
#  ' i',
#  'leavening agents  i',
#  ' ii',
#  'acidity regulators ',
#  '',
#  ' i',
#  'preservatives ',
#  '',
#  'spices  condiments clove',
#  'cinnamoncoriander',
#  'cumin',
#  'turmeric',
#  'black pepper',
#  'cloves',
#  'nutmeg',
#  'dry ginger',
#  'cassia',
#  'cardamom seeds',
#  'red chillies',
#  'fennel',
#  'bay leaf',
#  'salt',
#  'mustard',
#  'garlic flakes',
#  'onion flakes',
#  'mace masoor dal split red lentildehydrated vegetables tomato ',
#  'onion',
#  'iodized salt',
#  'starch',
#  'sugar',
#  'edible vegetable oil',
#  'acidifying agent citric acid',
#  'hydrolyzed vegetable protein',
#  'spices and condiments cumin powder',
#  'turmeric powder',
#  'garlic powder',
#  'coriander powder',
#  'red chilli powder ',
#  'flavour enhancers disodium guanylate',
#  'disodium inosinate',
#  'thickener xanthan gum',
#  'antioxidant epotato ',
#  'edible vegetable oil',
#  'chickpea flour ',
#  'salt',
#  'red chilli powder',
#  'mango powder',
#  'black saltwheat flour',
#  'sugar',
#  'refined palm oil',
#  'invert syrup',
#  'leavening ammonium bicarbonate e  ii',
#  'sodium bicarbonate e ii',
#  'salt',
#  'skim milk powder',
#  'soya lecithin e ',
#  'artificial vanilla flavor',
#  'sodium metabisulphite e  as preservativesugar',
#  'acidity regulator ',
#  'contains permitted synthetic food colour  and added orange flavours natural and nature identical flavouring substancesatta noodles  wheat flour',
#  'edible veg oil',
#  'salt',
#  'mineral calcium carbonate',
#  'guar gum',
#  'spice mix  mixed spices red chilli powder ',
#  'turmeric powder',
#  'coriander powder',
#  'dry ginger powder',
#  'cumin powder',
#  'aniseed powder',
#  'fenugreek powder',
#  'black pepper powder',
#  'clove powder',
#  'nutmeg powder',
#  'cardamom powder ',
#  'cinnamon powder ',
#  'mustard powder',
#  'curry leaf powder',
#  'mace powder',
#  'dehydrated onion',
#  'sugar',
#  'edible starch',
#  'hydrolysed groundnut protein',
#  'salt',
#  'tomato powder',
#  'edible vegetable oil',
#  'garlic powder',
#  'acidifying agent citric acid',
#  'flavour enhancers disodium ribonucleotidesugar',
#  'wheat flour',
#  'vegetable oil',
#  'cocoa solids',
#  'invert syrup',
#  'leavening agents ii',
#  'ii',
#  'salt',
#  'milk solids',
#  'emulsifiers i',
#  '',
#  'permitted flavorcoriander',
#  'cumin',
#  'red chilli',
#  'turmeric',
#  'black pepper',
#  'mustard',
#  'dry mango powder',
#  'fenugreek leaves',
#  'salt',
#  'pomegranate seeds',
#  'nutmeg',
#  'cloves',
#  'caraway',
#  'green cardamom',
#  'mace',
#  'cinnamon',
#  'bay leaves',
#  'asafoetidagram flour ',
#  'edible vegetable oil',
#  'tapioca starch',
#  'salt',
#  'red chilli powder',
#  'mango powder',
#  'black salt',
#  'acidity regulator e noodles wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium tripolyphosphate',
#  'potassium carbonate',
#  'sodium carbonate',
#  'seasoning mix dehydrated vegetables tomato',
#  'garlic',
#  'sugar',
#  'salt',
#  'corn starch',
#  'edible vegetable oil',
#  'hydrolyzed vegetable protein',
#  'flavour enhancer ',
#  'spices and condiments cumin powder',
#  'turmeric powder',
#  'black pepper powder',
#  'red chilli powder ',
#  'fenugreek powder',
#  'thickener ',
#  'acidity regulator ',
#  'antioxidant cheese ',
#  'water',
#  'emulsifiers e ',
#  'e ',
#  'e ',
#  'common salt',
#  'acidity regulator e ',
#  'preservative e water',
#  'sugar',
#  'tomato paste ',
#  'chilli puree ',
#  'salt',
#  'vinegar',
#  'corn starch',
#  'garlic powder',
#  'ginger powderwheat flour',
#  'edible vegetable oil',
#  'saltwater',
#  'onion',
#  'tomato',
#  'potato',
#  'green peas',
#  'refined sunflower oil',
#  'butter',
#  'coriander leaves',
#  'salt',
#  'red chilli powder',
#  'cumin powder',
#  'turmeric powder',
#  'dry mango powder',
#  'ginger',
#  'garlic',
#  'green chilli',
#  'cinnamon',
#  'cardamom',
#  'black peppernoodles wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium tripolyphosphate',
#  'potassium carbonate',
#  'sodium carbonate',
#  'seasoning mix salt',
#  'sugar',
#  'edible vegetable fat',
#  'flavour enhancers ',
#  '',
#  'hydrolysed vegetable protein',
#  'spices onion powder ',
#  'turmeric powder',
#  'garlic powder ',
#  'coriander powder',
#  'ginger powder ',
#  'cumin powder',
#  'chilli powder',
#  'black pepper powder',
#  'cardamom powder ',
#  'clove powder',
#  'nutmeg powder',
#  'onion flakes ',
#  'garlic flakes ',
#  'acidity regulator ',
#  'edible vegetable oilwhole wheat flourpotato ',
#  'edible vegetable oil',
#  'chickpeas flour ',
#  'salt',
#  'red chilli powder',
#  'mango powder',
#  'black salt',
#  'coriander powder',
#  'cumin powder',
#  'dried ginger powder',
#  'cardamom powder',
#  'cinnamon powdermalt extract',
#  'sugar',
#  'cocoa solids',
#  'caramel ins c',
#  'vitamins',
#  'minerals',
#  'emulsifier ins ',
#  'saltmango slices ',
#  'edible vegetable oil',
#  'salt',
#  'spices  condiments chilli powder',
#  'fenugreek powder',
#  'mustard powder',
#  'turmeric powder',
#  'cumin powder',
#  'asafoetida',
#  'coriander powder',
#  'acidity regulator ins noodles wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium tripolyphosphate',
#  'potassium carbonate',
#  'sodium carbonate',
#  'masala tastemaker hydrolysed groundnut protein',
#  'mixed spices coriander powder',
#  'cumin powder',
#  'turmeric powder',
#  'red chilli powder ',
#  'garlic powder',
#  'aniseed powder',
#  'fenugreek powder',
#  'ginger powder',
#  'black pepper powder',
#  'cardamom powder ',
#  'clove powder',
#  'nutmeg powder',
#  'sugar',
#  'edible vegetable oil',
#  'salt',
#  'wheat flour',
#  'flavour enhancer ',
#  'acidity regulator ',
#  'thickener ',
#  'noodle powder wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium tripolyphosphate',
#  'potassium carbonate',
#  'sodium carbonate',
#  'edible vegetable oilwheat flour',
#  'sugar',
#  'edible vegetable oil',
#  'invert syrup',
#  'milk solids',
#  'raising agents ii',
#  'ii',
#  'salt',
#  'emulsifiers i',
#  '',
#  'permitted flavorextract of coconut',
#  'waterwhole wheat flournoodles wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium tripolyphosphate',
#  'potassium carbonate',
#  'sodium carbonate',
#  'tastemaker hydrolysed groundnut protein',
#  'mixed spices onion powder',
#  'coriander powder',
#  'cumin powder',
#  'turmeric powder',
#  'garlic powder',
#  'aniseed powder',
#  'fenugreek powder',
#  'ginger powder',
#  'black pepper powder',
#  'clove powder',
#  'green cardamom powder',
#  'nutmeg powder',
#  'noodle powder wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium tripolyphosphate',
#  'potassium carbonate',
#  'sodium carbonate',
#  'sugar',
#  'edible vegetable oil',
#  'salt',
#  'wheat flour',
#  'corn flour',
#  'flavour enhancer ',
#  'acidity regulator ',
#  'mineral ferric pyrophosphate',
#  'colour plain caramel',
#  'edible vegetable oilmilk fatedible vegetable oil',
#  'bengal gram flour',
#  'split green gram flour',
#  'edible common salt',
#  'red chilli',
#  'ginger',
#  'clove',
#  'nutmeg',
#  'cinnamon',
#  'mace',
#  'bay leaftea',
#  'natural flavourmilk solids',
#  'sugarcorn flour',
#  'iodized salt',
#  'sugar',
#  'edible vegetable fat',
#  'dried sweet corn ',
#  'maltodextrin',
#  'milk solids',
#  'corn starch',
#  'yeast extract',
#  'onion powder ',
#  'garlic powder ',
#  'edible starch',
#  'spices  white pepper powder',
#  'turmeric powder',
#  'natural flavourings',
#  'acidity regulator ins ',
#  'soy sauce powder',
#  'caramel powder ins d',
#  'natural colour ins wheat flour',
#  'sugar',
#  'edible vegetable oil',
#  'invert syrup',
#  'leavening agents ii',
#  'ii',
#  'salt',
#  'emulsifiers i',
#  '',
#  'dough conditioner ginger ',
#  'garlic ',
#  'edible vegetable oil',
#  'salt',
#  'acidity regulator ins wheat flour',
#  'sugar',
#  'edible vegetable oil',
#  'cashew ',
#  'invert syrup',
#  'milk solids',
#  'raising agents ii',
#  'ii',
#  'salt',
#  'emulsifiers i',
#  '',
#  'permitted flavorspotato ',
#  'edible vegetable oil',
#  'gram flour',
#  'salt',
#  'red chilli powder',
#  'mango powder',
#  'black pepper powder',
#  'cumin powder',
#  'nutmeg powdercoriander',
#  'red chilli',
#  'cumin',
#  'fenugreek',
#  'pepper',
#  'turmeric',
#  'mustard',
#  'bengal gram dal',
#  'urad dal',
#  'curry leaves',
#  'asafoetidawheat flour ',
#  'sugar',
#  'refined palm oil',
#  'invert syrup',
#  'salt',
#  'leavening ii',
#  'sodium metabisulphite wheat flour ',
#  'edible vegetable oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gumnoodles  wheat flour',
#  'palm oil',
#  'salt',
#  'sodium carbonate',
#  'potassium carbonate',
#  'iodized salt',
#  'chicken ',
#  'flavors contains milk and soya',
#  'yeast extract',
#  'corn starch',
#  'sugar',
#  'onion powder',
#  'palm oil',
#  'spices turmeric',
#  'pepper',
#  'chicken fat ',
#  'acidity regulator citric acid',
#  'leekmilk solids',
#  'cheese solids milk',
#  'common salt',
#  'cheese cultures',
#  'enzymes',
#  'emulsifiers e',
#  'e',
#  'common salt',
#  'permitted stabilizing and preservative agents e',
#  'e',
#  'ewheat flour ',
#  'sugar',
#  'refined palm oil',
#  'invert syrup',
#  'leavening ii',
#  'milk solids',
#  'salt',
#  'emulsifiers ',
#  'i',
#  'dough conditioner ',
#  'vitamins and minerals niacin',
#  'thiamin',
#  'riboflavin',
#  'folic acid',
#  'ironcoriander',
#  'cumin',
#  'chilli',
#  'black pepper',
#  'cloves',
#  'nutmeg',
#  'cinnamon',
#  'cardamom',
#  'bay leaf',
#  'anistarcoriander',
#  'cumin',
#  'dry mango',
#  'salt',
#  'pomegranate seeds',
#  'black pepper',
#  'black salt',
#  'mint',
#  'mustard',
#  'fenugreek leaves',
#  'fennel',
#  'chilli',
#  'turmeric',
#  'ajwain',
#  'bay leavesoats ',
#  'vegetables  carrot',
#  'green peas',
#  'french beans',
#  'onion',
#  'edible vegetable oil',
#  'spices and condiments  garlic',
#  'ginger',
#  'green chilli',
#  'mustard seeds',
#  'cumin seeds',
#  'red chilli',
#  'salt',
#  'sugar',
#  'milk solids',
#  'wheat flour',
#  'raisinsdehydrated onion ',
#  'iodised salt',
#  'corn starch',
#  'sugar',
#  'spices  cumin',
#  'turmeric',
#  'ginger',
#  'coriander',
#  'red chilli powder ',
#  'cardamom',
#  'clove',
#  'nutmeg',
#  'edible vegetable oil palm oil',
#  'garlic ',
#  'acidifying agent citric acid',
#  'flavour enhancer monosodium glutamaterefined wheat flour',
#  'sugar',
#  'edible vegetable oil palm',
#  'chocolate chips  sugar',
#  'cocoa solids',
#  'cocoa butter',
#  'emulsifier soy lecithin',
#  'artificial flavour',
#  'invert syrup',
#  'milk solids',
#  'raising agents ii',
#  'ii',
#  'edible common salt',
#  'emulsifiers  i',
#  '',
#  'artificial flavouring substances vanilla and butterred chilli powder ',
#  'edible vegetable oil ',
#  'acidity regulator e',
#  'moisture content ',
#  'stabilizer e',
#  'anticaking agent e',
#  'emulsifying and stabilizing agents e',
#  'e',
#  'contains permitted class ii preservatives e',
#  'egram flour besan ',
#  'sugar',
#  'clarified butter ghee ',
#  'wheat flour ',
#  'liquid glucose',
#  'almonds ',
#  'pistachio ',
#  'cardamom ',
#  'silver leaves toor dal split pigeon peasoats ',
#  'dehydrated vegetables tomato ',
#  'onion',
#  'edible vegetable oil',
#  'sugar',
#  'spices and condiments  coriander powder',
#  'turmeric powder',
#  'garlic powder',
#  'ginger powder',
#  'cumin powder',
#  'red chilli powder',
#  'salt',
#  'milk solids',
#  'wheat flour',
#  'acidity regulator citric acid',
#  'raisins',
#  'antioxidant ewater',
#  'whole black gram ',
#  'red kidney beans ',
#  'tomato paste',
#  'refined sunflower oil',
#  'butter',
#  'salt',
#  'garlic',
#  'green chillies',
#  'ginger',
#  'cumin powder',
#  'coriander powder',
#  'red chilli powder',
#  'cinnamon',
#  'turmeric',
#  'bay leavesvermicelli wheat semolina',
#  'sugar',
#  'milk solids',
#  'edible vegetable fat palm oil',
#  'cashew nut',
#  'raisin',
#  'edible common salt',
#  'cardamom powder',
#  'saffronwater',
#  'sugar',
#  'tomato paste ',
#  'red chilli paste ',
#  'salt',
#  'acidity regulator acetic acid',
#  'modified corn starch',
#  'onion powder',
#  'garlic powder',
#  'ginger powder',
#  'coriander powder',
#  'cumin powder',
#  'red chilli powder ',
#  'thickener xanthan gum',
#  'preservative sodium benzoaterice flakes ',
#  'gram flour ',
#  'split bengal gram ',
#  'edible vegetable oil',
#  'corn flakes ',
#  'peanuts ',
#  'green peas oats ',
#  'vegetables  carrot',
#  'peas',
#  'onion',
#  'beans',
#  'tomato',
#  'spices  condiments onion powder',
#  'red chilli powder',
#  'coriander powder',
#  'turmeric powder',
#  'garlic powder',
#  'cumin powder',
#  'mustard seeds',
#  'salt',
#  'sugar',
#  'milk solids',
#  'edible vegetable oil palm oil',
#  'malic acidwheat flour',
#  'edible vegetable oil',
#  'sugar',
#  'refined palm oil',
#  'salt',
#  'invert syrup',
#  'raising agents ii',
#  'ii',
#  'ammonium bicarbonate',
#  'acidity regulator ',
#  'dough conditioner ',
#  'yeastwheat flour',
#  'sugar',
#  'edible vegetable oil',
#  'invert syrup',
#  'milk solids',
#  'raising agents ii',
#  'ii',
#  'salt',
#  'emulsifiers i',
#  '',
#  'permitted flavorssemolina ',
#  'edible vegetable oil',
#  'salt',
#  'mustard',
#  'bengal gram dal',
#  'black gram dal',
#  'raising agents eii',
#  'eii',
#  'acidity regulator e',
#  'curry leaves',
#  'green chilli',
#  'gingerpotato ',
#  'edible vegetable oil',
#  'chickpea flour',
#  'tapioca starch',
#  'salt',
#  'red chilli powder',
#  'mango powder',
#  'black salt',
#  'coriander powder',
#  'cumin powder',
#  'dry ginger powder',
#  'black pepper powder',
#  'cardamom powder',
#  'cinnamon powder',
#  'mace powder',
#  'nutmeg powdertomato puree ',
#  'sugar',
#  'water',
#  'vinegar',
#  'red chilli paste ',
#  'iodized salt',
#  'corn starch',
#  'garlic powder',
#  'onion powder',
#  'ginger powder',
#  'red chilli powder ',
#  'thickener ',
#  'acidity regulator ',
#  'preservative ',
#  'cumin powder',
#  'clove powderextracted from fresh coconutsurad flour ',
#  'water',
#  'asafoetida',
#  'edible common saltcoriander',
#  'chilli',
#  'cumin',
#  'salt',
#  'turmeric',
#  'black pepper',
#  'dry ginger',
#  'cassia',
#  'cloves',
#  'fennel',
#  'garlic',
#  'cardamom seedsvermicelli wheat semolina ',
#  'edible vegetable oil',
#  'saltsugar',
#  'corn starch',
#  'edible vegetable oil',
#  'salt',
#  'tomato powder ',
#  'wheat flour',
#  'milk solids',
#  'edible starch',
#  'dehydrated vegetables onion',
#  'garlic',
#  'tomato ',
#  'flavors',
#  'yeast extract',
#  'acidifying agent ',
#  'soy sauce powderwheat flour',
#  'sugar',
#  'edible vegetable oil',
#  'invert syrup',
#  'leavening ii',
#  'ii',
#  'salt',
#  'milk solids',
#  'permitted emulsifiers i',
#  '',
#  'dough conditioner ',
#  'artificial flavorsnoodles wheat flour',
#  'palm oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum',
#  'sodium tripolyphosphate',
#  'potassium carbonate',
#  'sodium carbonate',
#  'acidity regulator citric acid masala tastemaker hydrolysed peanut protein',
#  'mixed spices coriander',
#  'cumin',
#  'chilli',
#  'turmeric',
#  'ginger',
#  'aniseed',
#  'pepper',
#  'fenugreek',
#  'clove',
#  'nutmeg',
#  'noodle powder',
#  'sugar',
#  'edible starch',
#  'salt',
#  'palm oil',
#  'soy sauce powder',
#  'onion',
#  'garlic',
#  'citric acid',
#  'potassium chloride',
#  'sodium bicarbonatesugar',
#  'gram flour',
#  'refined palm oil',
#  'wheat flour',
#  'skimmed milk powder',
#  'cardamom powder',
#  'pistachio',
#  'almondvacuum evaporated iodized salt whole wheat flour amla juice emblica officinalis ',
#  'permitted class ii preservative echickpeas ',
#  'refined vegetable oil',
#  'red lentils ',
#  'green peas',
#  'split bengal gram ',
#  'salt',
#  'spices  condiments  onion powder',
#  'red chilli powder',
#  'coriander powder',
#  'turmeric powder',
#  'garlic powder',
#  'cumin powder',
#  'mustard seeds',
#  'fennel seeds',
#  'black pepper',
#  'fenugreek leaves',
#  'mango powder',
#  'citric acidblack salt',
#  'salt',
#  'dry mango',
#  'cumin',
#  'red chilli',
#  'coriander',
#  'black pepper',
#  'pomegranate seeds',
#  'mint leaves',
#  'nutmeg',
#  'caraway',
#  'cloves',
#  'asafoetidacoriander',
#  'cumin',
#  'chilli',
#  'black pepper',
#  'fennel seeds',
#  'brown cardamom',
#  'cassia',
#  'cloveswheat flour',
#  'sugar',
#  'edible vegetable oil',
#  'butter',
#  'invert syrup',
#  'milk solids',
#  'raising agents ii',
#  'ii',
#  'salt',
#  'emulsifiers i',
#  '',
#  'dough conditioner ',
#  'artificial flavorsmixed fruit pulp  banana',
#  'papaya',
#  'apple',
#  'pear',
#  'pineapple',
#  'mango',
#  'sugar',
#  'thickener ',
#  'acidity regulator ',
#  'preservative ',
#  'mixed spiceschickpeas',
#  'water',
#  'onion',
#  'tomato',
#  'edible vegetable oil',
#  'salt',
#  'ginger',
#  'garlic',
#  'coriander leaves',
#  'cumin',
#  'coriander powder',
#  'red chilli',
#  'turmeric powder',
#  'bay leaves',
#  'cinnamoncoriander',
#  'cumin',
#  'turmeric',
#  'black pepper',
#  'chilli',
#  'fenugreek leaves',
#  'salt',
#  'nutmeg',
#  'dry ginger',
#  'mustard',
#  'cassia',
#  'cardamom seeds',
#  'cloves',
#  'asafoetidagram flour',
#  'edible vegetable oil',
#  'salt',
#  'red chilli powder',
#  'clove powder',
#  'black pepper powder',
#  'cardamom powder',
#  'nutmeg powder',
#  'mace powdersoluble coffee powder ',
#  'chicory powder sugar',
#  'hydrogenated vegetable fat',
#  'milk solids',
#  'cocoa solids',
#  'rice crispies rice flour',
#  'sugar',
#  'wheat flour',
#  'malt extract',
#  'salt',
#  'dextrose monohydrate',
#  'emulsifiers i',
#  '',
#  'salt',
#  'edible glittermilk fat ',
#  'moisturehoney sugar',
#  'malt extract ',
#  'cocoa solids',
#  'caramel c',
#  'milk solids',
#  'emulsifiers ',
#  '',
#  'vitamins',
#  'minerals',
#  'raising agent ii',
#  'saltnoodles wheat flour',
#  'edible vegetable oil',
#  'salt',
#  'wheat gluten',
#  'mineral calcium carbonate',
#  'guar gum curry flavour mix salt',
#  'spices coriander',
#  'turmeric',
#  'red chilli',
#  'cumin',
#  'sugar',
#  'dehydrated vegetables onion',
#  'garlic',
#  'tomato',
#  'edible vegetable oil',
#  'hydrolysed groundnut protein',
#  'coriander leaves',
#  'tartaric acid']

# %%
words = []

for ingridient in ingdList:
  if(ingridient == []):
    continue
  separated = ingridient[0].split(',')
  for word in separated:
    while word[0] == ' ':
      word = word[1:]
    newingridient = word[0:word.find('(')]
    words.append(newingridient)

# %%
writer = open('dataset/outWords.csv', 'w')
for ing in sentence.split(', '):
    writer.write(ing + '\n')

# %%
items = sentence.split(', ')

while(items.__contains__('')):
    items.remove('')

    
for item in items:
    print(item)
    while(item[0] == ' '):
        item = item[1:]
    while(item[-1] == ' '):
        item = item[0:-1]
# Out:
# milk fat
# moisture
# salt
# permitted natural color annattosugar
# milk solids
# cocoa butter
# cocoa solids
# emulsifiers
# vegetable fat
# maltitol
# flavoring substances
# contains added flavors artificial vanilla and chocolate
# sweetener maltitol  imoong dal
# edible vegetable oil
# salt
# red chilli powder
# black pepper powder
# cumin powder
# dry ginger powdernoodles wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium tripolyphosphate
# potassium carbonate
# sodium carbonate masala tastemaker hydrolysed groundnut peanut protein
# mixed spices  dehydrated onion
# coriander powder
# red chilli powder
# turmeric powder
# ginger powder
# cumin powder
# aniseed
# fenugreek powder
# garlic powder
# clove powder
# black pepper powder
# noodle powder wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium triphosphate
# potassium carbonate
# sodium carbonate
# sugar
# edible starch
# palm oil
# acidifying agent citric acid
# colour plain caramel
# salt
# mineral ferric pyrophosphate
# flavour enhancer monosodium glutamate
# wheat protein
# raising agent sodium bicarbonatewheat flour
# sugar
# vegetable oil
# tutti frutti
# raisins
# liquid glucose
# butter
# dextrose monohydrate
# glycerine
# skimmed milk powder
# wheat bran
# starch
# salt
# emulsifiers
#  i
# leavening agents  i
#  ii
# acidity regulators
#  i
# preservatives
# spices  condiments clove
# cinnamoncoriander
# cumin
# turmeric
# black pepper
# cloves
# nutmeg
# dry ginger
# cassia
# cardamom seeds
# red chillies
# fennel
# bay leaf
# salt
# mustard
# garlic flakes
# onion flakes
# mace masoor dal split red lentildehydrated vegetables tomato
# onion
# iodized salt
# starch
# sugar
# edible vegetable oil
# acidifying agent citric acid
# hydrolyzed vegetable protein
# spices and condiments cumin powder
# turmeric powder
# garlic powder
# coriander powder
# red chilli powder
# flavour enhancers disodium guanylate
# disodium inosinate
# thickener xanthan gum
# antioxidant epotato
# edible vegetable oil
# chickpea flour
# salt
# red chilli powder
# mango powder
# black saltwheat flour
# sugar
# refined palm oil
# invert syrup
# leavening ammonium bicarbonate e  ii
# sodium bicarbonate e ii
# salt
# skim milk powder
# soya lecithin e
# artificial vanilla flavor
# sodium metabisulphite e  as preservativesugar
# acidity regulator
# contains permitted synthetic food colour  and added orange flavours natural and nature identical flavouring substancesatta noodles  wheat flour
# edible veg oil
# salt
# mineral calcium carbonate
# guar gum
# spice mix  mixed spices red chilli powder
# turmeric powder
# coriander powder
# dry ginger powder
# cumin powder
# aniseed powder
# fenugreek powder
# black pepper powder
# clove powder
# nutmeg powder
# cardamom powder
# cinnamon powder
# mustard powder
# curry leaf powder
# mace powder
# dehydrated onion
# sugar
# edible starch
# hydrolysed groundnut protein
# salt
# tomato powder
# edible vegetable oil
# garlic powder
# acidifying agent citric acid
# flavour enhancers disodium ribonucleotidesugar
# wheat flour
# vegetable oil
# cocoa solids
# invert syrup
# leavening agents ii
# ii
# salt
# milk solids
# emulsifiers i
# permitted flavorcoriander
# cumin
# red chilli
# turmeric
# black pepper
# mustard
# dry mango powder
# fenugreek leaves
# salt
# pomegranate seeds
# nutmeg
# cloves
# caraway
# green cardamom
# mace
# cinnamon
# bay leaves
# asafoetidagram flour
# edible vegetable oil
# tapioca starch
# salt
# red chilli powder
# mango powder
# black salt
# acidity regulator e noodles wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium tripolyphosphate
# potassium carbonate
# sodium carbonate
# seasoning mix dehydrated vegetables tomato
# garlic
# sugar
# salt
# corn starch
# edible vegetable oil
# hydrolyzed vegetable protein
# flavour enhancer
# spices and condiments cumin powder
# turmeric powder
# black pepper powder
# red chilli powder
# fenugreek powder
# thickener
# acidity regulator
# antioxidant cheese
# water
# emulsifiers e
# e
# e
# common salt
# acidity regulator e
# preservative e water
# sugar
# tomato paste
# chilli puree
# salt
# vinegar
# corn starch
# garlic powder
# ginger powderwheat flour
# edible vegetable oil
# saltwater
# onion
# tomato
# potato
# green peas
# refined sunflower oil
# butter
# coriander leaves
# salt
# red chilli powder
# cumin powder
# turmeric powder
# dry mango powder
# ginger
# garlic
# green chilli
# cinnamon
# cardamom
# black peppernoodles wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium tripolyphosphate
# potassium carbonate
# sodium carbonate
# seasoning mix salt
# sugar
# edible vegetable fat
# flavour enhancers
# hydrolysed vegetable protein
# spices onion powder
# turmeric powder
# garlic powder
# coriander powder
# ginger powder
# cumin powder
# chilli powder
# black pepper powder
# cardamom powder
# clove powder
# nutmeg powder
# onion flakes
# garlic flakes
# acidity regulator
# edible vegetable oilwhole wheat flourpotato
# edible vegetable oil
# chickpeas flour
# salt
# red chilli powder
# mango powder
# black salt
# coriander powder
# cumin powder
# dried ginger powder
# cardamom powder
# cinnamon powdermalt extract
# sugar
# cocoa solids
# caramel ins c
# vitamins
# minerals
# emulsifier ins
# saltmango slices
# edible vegetable oil
# salt
# spices  condiments chilli powder
# fenugreek powder
# mustard powder
# turmeric powder
# cumin powder
# asafoetida
# coriander powder
# acidity regulator ins noodles wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium tripolyphosphate
# potassium carbonate
# sodium carbonate
# masala tastemaker hydrolysed groundnut protein
# mixed spices coriander powder
# cumin powder
# turmeric powder
# red chilli powder
# garlic powder
# aniseed powder
# fenugreek powder
# ginger powder
# black pepper powder
# cardamom powder
# clove powder
# nutmeg powder
# sugar
# edible vegetable oil
# salt
# wheat flour
# flavour enhancer
# acidity regulator
# thickener
# noodle powder wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium tripolyphosphate
# potassium carbonate
# sodium carbonate
# edible vegetable oilwheat flour
# sugar
# edible vegetable oil
# invert syrup
# milk solids
# raising agents ii
# ii
# salt
# emulsifiers i
# permitted flavorextract of coconut
# waterwhole wheat flournoodles wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium tripolyphosphate
# potassium carbonate
# sodium carbonate
# tastemaker hydrolysed groundnut protein
# mixed spices onion powder
# coriander powder
# cumin powder
# turmeric powder
# garlic powder
# aniseed powder
# fenugreek powder
# ginger powder
# black pepper powder
# clove powder
# green cardamom powder
# nutmeg powder
# noodle powder wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium tripolyphosphate
# potassium carbonate
# sodium carbonate
# sugar
# edible vegetable oil
# salt
# wheat flour
# corn flour
# flavour enhancer
# acidity regulator
# mineral ferric pyrophosphate
# colour plain caramel
# edible vegetable oilmilk fatedible vegetable oil
# bengal gram flour
# split green gram flour
# edible common salt
# red chilli
# ginger
# clove
# nutmeg
# cinnamon
# mace
# bay leaftea
# natural flavourmilk solids
# sugarcorn flour
# iodized salt
# sugar
# edible vegetable fat
# dried sweet corn
# maltodextrin
# milk solids
# corn starch
# yeast extract
# onion powder
# garlic powder
# edible starch
# spices  white pepper powder
# turmeric powder
# natural flavourings
# acidity regulator ins
# soy sauce powder
# caramel powder ins d
# natural colour ins wheat flour
# sugar
# edible vegetable oil
# invert syrup
# leavening agents ii
# ii
# salt
# emulsifiers i
# dough conditioner ginger
# garlic
# edible vegetable oil
# salt
# acidity regulator ins wheat flour
# sugar
# edible vegetable oil
# cashew
# invert syrup
# milk solids
# raising agents ii
# ii
# salt
# emulsifiers i
# permitted flavorspotato
# edible vegetable oil
# gram flour
# salt
# red chilli powder
# mango powder
# black pepper powder
# cumin powder
# nutmeg powdercoriander
# red chilli
# cumin
# fenugreek
# pepper
# turmeric
# mustard
# bengal gram dal
# urad dal
# curry leaves
# asafoetidawheat flour
# sugar
# refined palm oil
# invert syrup
# salt
# leavening ii
# sodium metabisulphite wheat flour
# edible vegetable oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gumnoodles  wheat flour
# palm oil
# salt
# sodium carbonate
# potassium carbonate
# iodized salt
# chicken
# flavors contains milk and soya
# yeast extract
# corn starch
# sugar
# onion powder
# palm oil
# spices turmeric
# pepper
# chicken fat
# acidity regulator citric acid
# leekmilk solids
# cheese solids milk
# common salt
# cheese cultures
# enzymes
# emulsifiers e
# e
# common salt
# permitted stabilizing and preservative agents e
# e
# ewheat flour
# sugar
# refined palm oil
# invert syrup
# leavening ii
# milk solids
# salt
# emulsifiers
# i
# dough conditioner
# vitamins and minerals niacin
# thiamin
# riboflavin
# folic acid
# ironcoriander
# cumin
# chilli
# black pepper
# cloves
# nutmeg
# cinnamon
# cardamom
# bay leaf
# anistarcoriander
# cumin
# dry mango
# salt
# pomegranate seeds
# black pepper
# black salt
# mint
# mustard
# fenugreek leaves
# fennel
# chilli
# turmeric
# ajwain
# bay leavesoats
# vegetables  carrot
# green peas
# french beans
# onion
# edible vegetable oil
# spices and condiments  garlic
# ginger
# green chilli
# mustard seeds
# cumin seeds
# red chilli
# salt
# sugar
# milk solids
# wheat flour
# raisinsdehydrated onion
# iodised salt
# corn starch
# sugar
# spices  cumin
# turmeric
# ginger
# coriander
# red chilli powder
# cardamom
# clove
# nutmeg
# edible vegetable oil palm oil
# garlic
# acidifying agent citric acid
# flavour enhancer monosodium glutamaterefined wheat flour
# sugar
# edible vegetable oil palm
# chocolate chips  sugar
# cocoa solids
# cocoa butter
# emulsifier soy lecithin
# artificial flavour
# invert syrup
# milk solids
# raising agents ii
# ii
# edible common salt
# emulsifiers  i
# artificial flavouring substances vanilla and butterred chilli powder
# edible vegetable oil
# acidity regulator e
# moisture content
# stabilizer e
# anticaking agent e
# emulsifying and stabilizing agents e
# e
# contains permitted class ii preservatives e
# egram flour besan
# sugar
# clarified butter ghee
# wheat flour
# liquid glucose
# almonds
# pistachio
# cardamom
# silver leaves toor dal split pigeon peasoats
# dehydrated vegetables tomato
# onion
# edible vegetable oil
# sugar
# spices and condiments  coriander powder
# turmeric powder
# garlic powder
# ginger powder
# cumin powder
# red chilli powder
# salt
# milk solids
# wheat flour
# acidity regulator citric acid
# raisins
# antioxidant ewater
# whole black gram
# red kidney beans
# tomato paste
# refined sunflower oil
# butter
# salt
# garlic
# green chillies
# ginger
# cumin powder
# coriander powder
# red chilli powder
# cinnamon
# turmeric
# bay leavesvermicelli wheat semolina
# sugar
# milk solids
# edible vegetable fat palm oil
# cashew nut
# raisin
# edible common salt
# cardamom powder
# saffronwater
# sugar
# tomato paste
# red chilli paste
# salt
# acidity regulator acetic acid
# modified corn starch
# onion powder
# garlic powder
# ginger powder
# coriander powder
# cumin powder
# red chilli powder
# thickener xanthan gum
# preservative sodium benzoaterice flakes
# gram flour
# split bengal gram
# edible vegetable oil
# corn flakes
# peanuts
# green peas oats
# vegetables  carrot
# peas
# onion
# beans
# tomato
# spices  condiments onion powder
# red chilli powder
# coriander powder
# turmeric powder
# garlic powder
# cumin powder
# mustard seeds
# salt
# sugar
# milk solids
# edible vegetable oil palm oil
# malic acidwheat flour
# edible vegetable oil
# sugar
# refined palm oil
# salt
# invert syrup
# raising agents ii
# ii
# ammonium bicarbonate
# acidity regulator
# dough conditioner
# yeastwheat flour
# sugar
# edible vegetable oil
# invert syrup
# milk solids
# raising agents ii
# ii
# salt
# emulsifiers i
# permitted flavorssemolina
# edible vegetable oil
# salt
# mustard
# bengal gram dal
# black gram dal
# raising agents eii
# eii
# acidity regulator e
# curry leaves
# green chilli
# gingerpotato
# edible vegetable oil
# chickpea flour
# tapioca starch
# salt
# red chilli powder
# mango powder
# black salt
# coriander powder
# cumin powder
# dry ginger powder
# black pepper powder
# cardamom powder
# cinnamon powder
# mace powder
# nutmeg powdertomato puree
# sugar
# water
# vinegar
# red chilli paste
# iodized salt
# corn starch
# garlic powder
# onion powder
# ginger powder
# red chilli powder
# thickener
# acidity regulator
# preservative
# cumin powder
# clove powderextracted from fresh coconutsurad flour
# water
# asafoetida
# edible common saltcoriander
# chilli
# cumin
# salt
# turmeric
# black pepper
# dry ginger
# cassia
# cloves
# fennel
# garlic
# cardamom seedsvermicelli wheat semolina
# edible vegetable oil
# saltsugar
# corn starch
# edible vegetable oil
# salt
# tomato powder
# wheat flour
# milk solids
# edible starch
# dehydrated vegetables onion
# garlic
# tomato
# flavors
# yeast extract
# acidifying agent
# soy sauce powderwheat flour
# sugar
# edible vegetable oil
# invert syrup
# leavening ii
# ii
# salt
# milk solids
# permitted emulsifiers i
# dough conditioner
# artificial flavorsnoodles wheat flour
# palm oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum
# sodium tripolyphosphate
# potassium carbonate
# sodium carbonate
# acidity regulator citric acid masala tastemaker hydrolysed peanut protein
# mixed spices coriander
# cumin
# chilli
# turmeric
# ginger
# aniseed
# pepper
# fenugreek
# clove
# nutmeg
# noodle powder
# sugar
# edible starch
# salt
# palm oil
# soy sauce powder
# onion
# garlic
# citric acid
# potassium chloride
# sodium bicarbonatesugar
# gram flour
# refined palm oil
# wheat flour
# skimmed milk powder
# cardamom powder
# pistachio
# almondvacuum evaporated iodized salt whole wheat flour amla juice emblica officinalis
# permitted class ii preservative echickpeas
# refined vegetable oil
# red lentils
# green peas
# split bengal gram
# salt
# spices  condiments  onion powder
# red chilli powder
# coriander powder
# turmeric powder
# garlic powder
# cumin powder
# mustard seeds
# fennel seeds
# black pepper
# fenugreek leaves
# mango powder
# citric acidblack salt
# salt
# dry mango
# cumin
# red chilli
# coriander
# black pepper
# pomegranate seeds
# mint leaves
# nutmeg
# caraway
# cloves
# asafoetidacoriander
# cumin
# chilli
# black pepper
# fennel seeds
# brown cardamom
# cassia
# cloveswheat flour
# sugar
# edible vegetable oil
# butter
# invert syrup
# milk solids
# raising agents ii
# ii
# salt
# emulsifiers i
# dough conditioner
# artificial flavorsmixed fruit pulp  banana
# papaya
# apple
# pear
# pineapple
# mango
# sugar
# thickener
# acidity regulator
# preservative
# mixed spiceschickpeas
# water
# onion
# tomato
# edible vegetable oil
# salt
# ginger
# garlic
# coriander leaves
# cumin
# coriander powder
# red chilli
# turmeric powder
# bay leaves
# cinnamoncoriander
# cumin
# turmeric
# black pepper
# chilli
# fenugreek leaves
# salt
# nutmeg
# dry ginger
# mustard
# cassia
# cardamom seeds
# cloves
# asafoetidagram flour
# edible vegetable oil
# salt
# red chilli powder
# clove powder
# black pepper powder
# cardamom powder
# nutmeg powder
# mace powdersoluble coffee powder
# chicory powder sugar
# hydrogenated vegetable fat
# milk solids
# cocoa solids
# rice crispies rice flour
# sugar
# wheat flour
# malt extract
# salt
# dextrose monohydrate
# emulsifiers i
# salt
# edible glittermilk fat
# moisturehoney sugar
# malt extract
# cocoa solids
# caramel c
# milk solids
# emulsifiers
# vitamins
# minerals
# raising agent ii
# saltnoodles wheat flour
# edible vegetable oil
# salt
# wheat gluten
# mineral calcium carbonate
# guar gum curry flavour mix salt
# spices coriander
# turmeric
# red chilli
# cumin
# sugar
# dehydrated vegetables onion
# garlic
# tomato
# edible vegetable oil
# hydrolysed groundnut protein
# coriander leaves
# tartaric acid

# %%
dictionary = {}

for item in items:
    if item in dictionary:
        dictionary[item] += 1
    else:
        dictionary[item] = 1

# %%
dictionary
# Out:
# {'milk fat ': 1,
#  'moisture ': 1,
#  'salt ': 1,
#  'permitted natural color annattosugar': 1,
#  'milk solids ': 1,
#  'cocoa butter': 2,
#  'cocoa solids': 6,
#  'emulsifiers ': 4,
#  'vegetable fat': 1,
#  'maltitol': 1,
#  'flavoring substances': 1,
#  'contains added flavors artificial vanilla and chocolate': 1,
#  'sweetener maltitol  imoong dal ': 1,
#  'edible vegetable oil': 32,
#  'salt': 59,
#  'red chilli powder': 12,
#  'black pepper powder': 10,
#  'cumin powder': 17,
#  'dry ginger powdernoodles wheat flour': 1,
#  'palm oil': 13,
#  'wheat gluten': 11,
#  'mineral calcium carbonate': 12,
#  'guar gum': 10,
#  'sodium tripolyphosphate': 8,
#  'potassium carbonate': 10,
#  'sodium carbonate masala tastemaker hydrolysed groundnut peanut protein': 1,
#  'mixed spices  dehydrated onion': 1,
#  'coriander powder': 13,
#  'red chilli powder ': 7,
#  'turmeric powder': 14,
#  'ginger powder': 6,
#  'aniseed': 2,
#  'fenugreek powder': 6,
#  'garlic powder': 11,
#  'clove powder': 6,
#  'noodle powder wheat flour': 3,
#  'sodium triphosphate': 1,
#  'sodium carbonate': 9,
#  'sugar': 35,
#  'edible starch': 5,
#  'acidifying agent citric acid': 4,
#  'colour plain caramel': 2,
#  'mineral ferric pyrophosphate': 2,
#  'flavour enhancer monosodium glutamate': 1,
#  'wheat protein': 1,
#  'raising agent sodium bicarbonatewheat flour': 1,
#  'vegetable oil': 2,
#  'tutti frutti ': 1,
#  'raisins ': 1,
#  'liquid glucose': 2,
#  'butter': 4,
#  'dextrose monohydrate': 2,
#  'glycerine': 1,
#  'skimmed milk powder': 2,
#  'wheat bran': 1,
#  'starch': 2,
#  ' i': 2,
#  'leavening agents  i': 1,
#  ' ii': 1,
#  'acidity regulators ': 1,
#  'preservatives ': 1,
#  'spices  condiments clove': 1,
#  'cinnamoncoriander': 2,
#  'cumin': 12,
#  'turmeric': 10,
#  'black pepper': 9,
#  'cloves': 6,
#  'nutmeg': 8,
#  'dry ginger': 3,
#  'cassia': 4,
#  'cardamom seeds': 2,
#  'red chillies': 1,
#  'fennel': 3,
#  'bay leaf': 2,
#  'mustard': 6,
#  'garlic flakes': 1,
#  'onion flakes': 1,
#  'mace masoor dal split red lentildehydrated vegetables tomato ': 1,
#  'onion': 7,
#  'iodized salt': 4,
#  'hydrolyzed vegetable protein': 2,
#  'spices and condiments cumin powder': 2,
#  'flavour enhancers disodium guanylate': 1,
#  'disodium inosinate': 1,
#  'thickener xanthan gum': 2,
#  'antioxidant epotato ': 1,
#  'chickpea flour ': 1,
#  'mango powder': 6,
#  'black saltwheat flour': 1,
#  'refined palm oil': 5,
#  'invert syrup': 12,
#  'leavening ammonium bicarbonate e  ii': 1,
#  'sodium bicarbonate e ii': 1,
#  'skim milk powder': 1,
#  'soya lecithin e ': 1,
#  'artificial vanilla flavor': 1,
#  'sodium metabisulphite e  as preservativesugar': 1,
#  'acidity regulator ': 8,
#  'contains permitted synthetic food colour  and added orange flavours natural and nature identical flavouring substancesatta noodles  wheat flour': 1,
#  'edible veg oil': 1,
#  'spice mix  mixed spices red chilli powder ': 1,
#  'dry ginger powder': 2,
#  'aniseed powder': 3,
#  'nutmeg powder': 5,
#  'cardamom powder ': 3,
#  'cinnamon powder ': 1,
#  'mustard powder': 2,
#  'curry leaf powder': 1,
#  'mace powder': 2,
#  'dehydrated onion': 1,
#  'hydrolysed groundnut protein': 2,
#  'tomato powder': 1,
#  'flavour enhancers disodium ribonucleotidesugar': 1,
#  'wheat flour': 8,
#  'leavening agents ii': 2,
#  'ii': 9,
#  'milk solids': 16,
#  'emulsifiers i': 7,
#  'permitted flavorcoriander': 1,
#  'red chilli': 7,
#  'dry mango powder': 2,
#  'fenugreek leaves': 4,
#  'pomegranate seeds': 3,
#  'caraway': 2,
#  'green cardamom': 1,
#  'mace': 2,
#  'cinnamon': 5,
#  'bay leaves': 2,
#  'asafoetidagram flour ': 1,
#  'tapioca starch': 2,
#  'black salt': 4,
#  'acidity regulator e noodles wheat flour': 1,
#  'seasoning mix dehydrated vegetables tomato': 1,
#  'garlic': 8,
#  'corn starch': 7,
#  'flavour enhancer ': 3,
#  'thickener ': 4,
#  'antioxidant cheese ': 1,
#  'water': 4,
#  'emulsifiers e ': 1,
#  'e ': 2,
#  'common salt': 3,
#  'acidity regulator e ': 1,
#  'preservative e water': 1,
#  'tomato paste ': 2,
#  'chilli puree ': 1,
#  'vinegar': 2,
#  'ginger powderwheat flour': 1,
#  'saltwater': 1,
#  'tomato': 4,
#  'potato': 1,
#  'green peas': 3,
#  'refined sunflower oil': 2,
#  'coriander leaves': 3,
#  'ginger': 7,
#  'green chilli': 3,
#  'cardamom': 3,
#  'black peppernoodles wheat flour': 1,
#  'seasoning mix salt': 1,
#  'edible vegetable fat': 2,
#  'flavour enhancers ': 1,
#  'hydrolysed vegetable protein': 1,
#  'spices onion powder ': 1,
#  'garlic powder ': 2,
#  'ginger powder ': 1,
#  'chilli powder': 1,
#  'onion flakes ': 1,
#  'garlic flakes ': 1,
#  'edible vegetable oilwhole wheat flourpotato ': 1,
#  'chickpeas flour ': 1,
#  'dried ginger powder': 1,
#  'cardamom powder': 5,
#  'cinnamon powdermalt extract': 1,
#  'caramel ins c': 1,
#  'vitamins': 2,
#  'minerals': 2,
#  'emulsifier ins ': 1,
#  'saltmango slices ': 1,
#  'spices  condiments chilli powder': 1,
#  'asafoetida': 2,
#  'acidity regulator ins noodles wheat flour': 1,
#  'masala tastemaker hydrolysed groundnut protein': 1,
#  'mixed spices coriander powder': 1,
#  'edible vegetable oilwheat flour': 1,
#  'raising agents ii': 6,
#  'permitted flavorextract of coconut': 1,
#  'waterwhole wheat flournoodles wheat flour': 1,
#  'tastemaker hydrolysed groundnut protein': 1,
#  'mixed spices onion powder': 1,
#  'green cardamom powder': 1,
#  'corn flour': 1,
#  'edible vegetable oilmilk fatedible vegetable oil': 1,
#  'bengal gram flour': 1,
#  'split green gram flour': 1,
#  'edible common salt': 3,
#  'clove': 3,
#  'bay leaftea': 1,
#  'natural flavourmilk solids': 1,
#  'sugarcorn flour': 1,
#  'dried sweet corn ': 1,
#  'maltodextrin': 1,
#  'yeast extract': 3,
#  'onion powder ': 1,
#  'spices  white pepper powder': 1,
#  'natural flavourings': 1,
#  'acidity regulator ins ': 1,
#  'soy sauce powder': 2,
#  'caramel powder ins d': 1,
#  'natural colour ins wheat flour': 1,
#  'dough conditioner ginger ': 1,
#  'garlic ': 2,
#  'acidity regulator ins wheat flour': 1,
#  'cashew ': 1,
#  'permitted flavorspotato ': 1,
#  'gram flour': 2,
#  'nutmeg powdercoriander': 1,
#  'fenugreek': 2,
#  'pepper': 3,
#  'bengal gram dal': 2,
#  'urad dal': 1,
#  'curry leaves': 2,
#  'asafoetidawheat flour ': 1,
#  'leavening ii': 3,
#  'sodium metabisulphite wheat flour ': 1,
#  'guar gumnoodles  wheat flour': 1,
#  'chicken ': 1,
#  'flavors contains milk and soya': 1,
#  'onion powder': 3,
#  'spices turmeric': 1,
#  'chicken fat ': 1,
#  'acidity regulator citric acid': 2,
#  'leekmilk solids': 1,
#  'cheese solids milk': 1,
#  'cheese cultures': 1,
#  'enzymes': 1,
#  'emulsifiers e': 1,
#  'e': 3,
#  'permitted stabilizing and preservative agents e': 1,
#  'ewheat flour ': 1,
#  'i': 1,
#  'dough conditioner ': 4,
#  'vitamins and minerals niacin': 1,
#  'thiamin': 1,
#  'riboflavin': 1,
#  'folic acid': 1,
#  'ironcoriander': 1,
#  'chilli': 6,
#  'anistarcoriander': 1,
#  'dry mango': 2,
#  'mint': 1,
#  'ajwain': 1,
#  'bay leavesoats ': 1,
#  'vegetables  carrot': 2,
#  'french beans': 1,
#  'spices and condiments  garlic': 1,
#  'mustard seeds': 3,
#  'cumin seeds': 1,
#  'raisinsdehydrated onion ': 1,
#  'iodised salt': 1,
#  'spices  cumin': 1,
#  'coriander': 2,
#  'edible vegetable oil palm oil': 2,
#  'flavour enhancer monosodium glutamaterefined wheat flour': 1,
#  'edible vegetable oil palm': 1,
#  'chocolate chips  sugar': 1,
#  'emulsifier soy lecithin': 1,
#  'artificial flavour': 1,
#  'emulsifiers  i': 1,
#  'artificial flavouring substances vanilla and butterred chilli powder ': 1,
#  'edible vegetable oil ': 1,
#  'acidity regulator e': 2,
#  'moisture content ': 1,
#  'stabilizer e': 1,
#  'anticaking agent e': 1,
#  'emulsifying and stabilizing agents e': 1,
#  'contains permitted class ii preservatives e': 1,
#  'egram flour besan ': 1,
#  'clarified butter ghee ': 1,
#  'wheat flour ': 1,
#  'almonds ': 1,
#  'pistachio ': 1,
#  'cardamom ': 1,
#  'silver leaves toor dal split pigeon peasoats ': 1,
#  'dehydrated vegetables tomato ': 1,
#  'spices and condiments  coriander powder': 1,
#  'raisins': 1,
#  'antioxidant ewater': 1,
#  'whole black gram ': 1,
#  'red kidney beans ': 1,
#  'tomato paste': 1,
#  'green chillies': 1,
#  'bay leavesvermicelli wheat semolina': 1,
#  'edible vegetable fat palm oil': 1,
#  'cashew nut': 1,
#  'raisin': 1,
#  'saffronwater': 1,
#  'red chilli paste ': 2,
#  'acidity regulator acetic acid': 1,
#  'modified corn starch': 1,
#  'preservative sodium benzoaterice flakes ': 1,
#  'gram flour ': 1,
#  'split bengal gram ': 2,
#  'corn flakes ': 1,
#  'peanuts ': 1,
#  'green peas oats ': 1,
#  'peas': 1,
#  'beans': 1,
#  'spices  condiments onion powder': 1,
#  'malic acidwheat flour': 1,
#  'ammonium bicarbonate': 1,
#  'yeastwheat flour': 1,
#  'permitted flavorssemolina ': 1,
#  'black gram dal': 1,
#  'raising agents eii': 1,
#  'eii': 1,
#  'gingerpotato ': 1,
#  'chickpea flour': 1,
#  'cinnamon powder': 1,
#  'nutmeg powdertomato puree ': 1,
#  'preservative ': 2,
#  'clove powderextracted from fresh coconutsurad flour ': 1,
#  'edible common saltcoriander': 1,
#  'cardamom seedsvermicelli wheat semolina ': 1,
#  'saltsugar': 1,
#  'tomato powder ': 1,
#  'dehydrated vegetables onion': 2,
#  'tomato ': 1,
#  'flavors': 1,
#  'acidifying agent ': 1,
#  'soy sauce powderwheat flour': 1,
#  'permitted emulsifiers i': 1,
#  'artificial flavorsnoodles wheat flour': 1,
#  'acidity regulator citric acid masala tastemaker hydrolysed peanut protein': 1,
#  'mixed spices coriander': 1,
#  'noodle powder': 1,
#  'citric acid': 1,
#  'potassium chloride': 1,
#  'sodium bicarbonatesugar': 1,
#  'pistachio': 1,
#  'almondvacuum evaporated iodized salt whole wheat flour amla juice emblica officinalis ': 1,
#  'permitted class ii preservative echickpeas ': 1,
#  'refined vegetable oil': 1,
#  'red lentils ': 1,
#  'spices  condiments  onion powder': 1,
#  'fennel seeds': 2,
#  'citric acidblack salt': 1,
#  'mint leaves': 1,
#  'asafoetidacoriander': 1,
#  'brown cardamom': 1,
#  'cloveswheat flour': 1,
#  'artificial flavorsmixed fruit pulp  banana': 1,
#  'papaya': 1,
#  'apple': 1,
#  'pear': 1,
#  'pineapple': 1,
#  'mango': 1,
#  'mixed spiceschickpeas': 1,
#  'asafoetidagram flour': 1,
#  'mace powdersoluble coffee powder ': 1,
#  'chicory powder sugar': 1,
#  'hydrogenated vegetable fat': 1,
#  'rice crispies rice flour': 1,
#  'malt extract': 1,
#  'edible glittermilk fat ': 1,
#  'moisturehoney sugar': 1,
#  'malt extract ': 1,
#  'caramel c': 1,
#  'raising agent ii': 1,
#  'saltnoodles wheat flour': 1,
#  'guar gum curry flavour mix salt': 1,
#  'spices coriander': 1,
#  'tartaric acid': 1}

# %%
## sort dictionary by value
sorted_dict = sorted(dictionary.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_dict
# Out:
# [('salt', 59),
#  ('sugar', 35),
#  ('edible vegetable oil', 32),
#  ('cumin powder', 17),
#  ('milk solids', 16),
#  ('turmeric powder', 14),
#  ('palm oil', 13),
#  ('coriander powder', 13),
#  ('red chilli powder', 12),
#  ('mineral calcium carbonate', 12),
#  ('cumin', 12),
#  ('invert syrup', 12),
#  ('wheat gluten', 11),
#  ('garlic powder', 11),
#  ('black pepper powder', 10),
#  ('guar gum', 10),
#  ('potassium carbonate', 10),
#  ('turmeric', 10),
#  ('sodium carbonate', 9),
#  ('black pepper', 9),
#  ('ii', 9),
#  ('sodium tripolyphosphate', 8),
#  ('nutmeg', 8),
#  ('acidity regulator ', 8),
#  ('wheat flour', 8),
#  ('garlic', 8),
#  ('red chilli powder ', 7),
#  ('onion', 7),
#  ('emulsifiers i', 7),
#  ('red chilli', 7),
#  ('corn starch', 7),
#  ('ginger', 7),
#  ('cocoa solids', 6),
#  ('ginger powder', 6),
#  ('fenugreek powder', 6),
#  ('clove powder', 6),
#  ('cloves', 6),
#  ('mustard', 6),
#  ('mango powder', 6),
#  ('raising agents ii', 6),
#  ('chilli', 6),
#  ('edible starch', 5),
#  ('refined palm oil', 5),
#  ('nutmeg powder', 5),
#  ('cinnamon', 5),
#  ('cardamom powder', 5),
#  ('emulsifiers ', 4),
#  ('acidifying agent citric acid', 4),
#  ('butter', 4),
#  ('cassia', 4),
#  ('iodized salt', 4),
#  ('fenugreek leaves', 4),
#  ('black salt', 4),
#  ('thickener ', 4),
#  ('water', 4),
#  ('tomato', 4),
#  ('dough conditioner ', 4),
#  ('noodle powder wheat flour', 3),
#  ('dry ginger', 3),
#  ('fennel', 3),
#  ('aniseed powder', 3),
#  ('cardamom powder ', 3),
#  ('pomegranate seeds', 3),
#  ('flavour enhancer ', 3),
#  ('common salt', 3),
#  ('green peas', 3),
#  ('coriander leaves', 3),
#  ('green chilli', 3),
#  ('cardamom', 3),
#  ('edible common salt', 3),
#  ('clove', 3),
#  ('yeast extract', 3),
#  ('pepper', 3),
#  ('leavening ii', 3),
#  ('onion powder', 3),
#  ('e', 3),
#  ('mustard seeds', 3),
#  ('cocoa butter', 2),
#  ('aniseed', 2),
#  ('colour plain caramel', 2),
#  ('mineral ferric pyrophosphate', 2),
#  ('vegetable oil', 2),
#  ('liquid glucose', 2),
#  ('dextrose monohydrate', 2),
#  ('skimmed milk powder', 2),
#  ('starch', 2),
#  (' i', 2),
#  ('cinnamoncoriander', 2),
#  ('cardamom seeds', 2),
#  ('bay leaf', 2),
#  ('hydrolyzed vegetable protein', 2),
#  ('spices and condiments cumin powder', 2),
#  ('thickener xanthan gum', 2),
#  ('dry ginger powder', 2),
#  ('mustard powder', 2),
#  ('mace powder', 2),
#  ('hydrolysed groundnut protein', 2),
#  ('leavening agents ii', 2),
#  ('dry mango powder', 2),
#  ('caraway', 2),
#  ('mace', 2),
#  ('bay leaves', 2),
#  ('tapioca starch', 2),
#  ('e ', 2),
#  ('tomato paste ', 2),
#  ('vinegar', 2),
#  ('refined sunflower oil', 2),
#  ('edible vegetable fat', 2),
#  ('garlic powder ', 2),
#  ('vitamins', 2),
#  ('minerals', 2),
#  ('asafoetida', 2),
#  ('soy sauce powder', 2),
#  ('garlic ', 2),
#  ('gram flour', 2),
#  ('fenugreek', 2),
#  ('bengal gram dal', 2),
#  ('curry leaves', 2),
#  ('acidity regulator citric acid', 2),
#  ('dry mango', 2),
#  ('vegetables  carrot', 2),
#  ('coriander', 2),
#  ('edible vegetable oil palm oil', 2),
#  ('acidity regulator e', 2),
#  ('red chilli paste ', 2),
#  ('split bengal gram ', 2),
#  ('preservative ', 2),
#  ('dehydrated vegetables onion', 2),
#  ('fennel seeds', 2),
#  ('milk fat ', 1),
#  ('moisture ', 1),
#  ('salt ', 1),
#  ('permitted natural color annattosugar', 1),
#  ('milk solids ', 1),
#  ('vegetable fat', 1),
#  ('maltitol', 1),
#  ('flavoring substances', 1),
#  ('contains added flavors artificial vanilla and chocolate', 1),
#  ('sweetener maltitol  imoong dal ', 1),
#  ('dry ginger powdernoodles wheat flour', 1),
#  ('sodium carbonate masala tastemaker hydrolysed groundnut peanut protein', 1),
#  ('mixed spices  dehydrated onion', 1),
#  ('sodium triphosphate', 1),
#  ('flavour enhancer monosodium glutamate', 1),
#  ('wheat protein', 1),
#  ('raising agent sodium bicarbonatewheat flour', 1),
#  ('tutti frutti ', 1),
#  ('raisins ', 1),
#  ('glycerine', 1),
#  ('wheat bran', 1),
#  ('leavening agents  i', 1),
#  (' ii', 1),
#  ('acidity regulators ', 1),
#  ('preservatives ', 1),
#  ('spices  condiments clove', 1),
#  ('red chillies', 1),
#  ('garlic flakes', 1),
#  ('onion flakes', 1),
#  ('mace masoor dal split red lentildehydrated vegetables tomato ', 1),
#  ('flavour enhancers disodium guanylate', 1),
#  ('disodium inosinate', 1),
#  ('antioxidant epotato ', 1),
#  ('chickpea flour ', 1),
#  ('black saltwheat flour', 1),
#  ('leavening ammonium bicarbonate e  ii', 1),
#  ('sodium bicarbonate e ii', 1),
#  ('skim milk powder', 1),
#  ('soya lecithin e ', 1),
#  ('artificial vanilla flavor', 1),
#  ('sodium metabisulphite e  as preservativesugar', 1),
#  ('contains permitted synthetic food colour  and added orange flavours natural and nature identical flavouring substancesatta noodles  wheat flour',
#   1),
#  ('edible veg oil', 1),
#  ('spice mix  mixed spices red chilli powder ', 1),
#  ('cinnamon powder ', 1),
#  ('curry leaf powder', 1),
#  ('dehydrated onion', 1),
#  ('tomato powder', 1),
#  ('flavour enhancers disodium ribonucleotidesugar', 1),
#  ('permitted flavorcoriander', 1),
#  ('green cardamom', 1),
#  ('asafoetidagram flour ', 1),
#  ('acidity regulator e noodles wheat flour', 1),
#  ('seasoning mix dehydrated vegetables tomato', 1),
#  ('antioxidant cheese ', 1),
#  ('emulsifiers e ', 1),
#  ('acidity regulator e ', 1),
#  ('preservative e water', 1),
#  ('chilli puree ', 1),
#  ('ginger powderwheat flour', 1),
#  ('saltwater', 1),
#  ('potato', 1),
#  ('black peppernoodles wheat flour', 1),
#  ('seasoning mix salt', 1),
#  ('flavour enhancers ', 1),
#  ('hydrolysed vegetable protein', 1),
#  ('spices onion powder ', 1),
#  ('ginger powder ', 1),
#  ('chilli powder', 1),
#  ('onion flakes ', 1),
#  ('garlic flakes ', 1),
#  ('edible vegetable oilwhole wheat flourpotato ', 1),
#  ('chickpeas flour ', 1),
#  ('dried ginger powder', 1),
#  ('cinnamon powdermalt extract', 1),
#  ('caramel ins c', 1),
#  ('emulsifier ins ', 1),
#  ('saltmango slices ', 1),
#  ('spices  condiments chilli powder', 1),
#  ('acidity regulator ins noodles wheat flour', 1),
#  ('masala tastemaker hydrolysed groundnut protein', 1),
#  ('mixed spices coriander powder', 1),
#  ('edible vegetable oilwheat flour', 1),
#  ('permitted flavorextract of coconut', 1),
#  ('waterwhole wheat flournoodles wheat flour', 1),
#  ('tastemaker hydrolysed groundnut protein', 1),
#  ('mixed spices onion powder', 1),
#  ('green cardamom powder', 1),
#  ('corn flour', 1),
#  ('edible vegetable oilmilk fatedible vegetable oil', 1),
#  ('bengal gram flour', 1),
#  ('split green gram flour', 1),
#  ('bay leaftea', 1),
#  ('natural flavourmilk solids', 1),
#  ('sugarcorn flour', 1),
#  ('dried sweet corn ', 1),
#  ('maltodextrin', 1),
#  ('onion powder ', 1),
#  ('spices  white pepper powder', 1),
#  ('natural flavourings', 1),
#  ('acidity regulator ins ', 1),
#  ('caramel powder ins d', 1),
#  ('natural colour ins wheat flour', 1),
#  ('dough conditioner ginger ', 1),
#  ('acidity regulator ins wheat flour', 1),
#  ('cashew ', 1),
#  ('permitted flavorspotato ', 1),
#  ('nutmeg powdercoriander', 1),
#  ('urad dal', 1),
#  ('asafoetidawheat flour ', 1),
#  ('sodium metabisulphite wheat flour ', 1),
#  ('guar gumnoodles  wheat flour', 1),
#  ('chicken ', 1),
#  ('flavors contains milk and soya', 1),
#  ('spices turmeric', 1),
#  ('chicken fat ', 1),
#  ('leekmilk solids', 1),
#  ('cheese solids milk', 1),
#  ('cheese cultures', 1),
#  ('enzymes', 1),
#  ('emulsifiers e', 1),
#  ('permitted stabilizing and preservative agents e', 1),
#  ('ewheat flour ', 1),
#  ('i', 1),
#  ('vitamins and minerals niacin', 1),
#  ('thiamin', 1),
#  ('riboflavin', 1),
#  ('folic acid', 1),
#  ('ironcoriander', 1),
#  ('anistarcoriander', 1),
#  ('mint', 1),
#  ('ajwain', 1),
#  ('bay leavesoats ', 1),
#  ('french beans', 1),
#  ('spices and condiments  garlic', 1),
#  ('cumin seeds', 1),
#  ('raisinsdehydrated onion ', 1),
#  ('iodised salt', 1),
#  ('spices  cumin', 1),
#  ('flavour enhancer monosodium glutamaterefined wheat flour', 1),
#  ('edible vegetable oil palm', 1),
#  ('chocolate chips  sugar', 1),
#  ('emulsifier soy lecithin', 1),
#  ('artificial flavour', 1),
#  ('emulsifiers  i', 1),
#  ('artificial flavouring substances vanilla and butterred chilli powder ', 1),
#  ('edible vegetable oil ', 1),
#  ('moisture content ', 1),
#  ('stabilizer e', 1),
#  ('anticaking agent e', 1),
#  ('emulsifying and stabilizing agents e', 1),
#  ('contains permitted class ii preservatives e', 1),
#  ('egram flour besan ', 1),
#  ('clarified butter ghee ', 1),
#  ('wheat flour ', 1),
#  ('almonds ', 1),
#  ('pistachio ', 1),
#  ('cardamom ', 1),
#  ('silver leaves toor dal split pigeon peasoats ', 1),
#  ('dehydrated vegetables tomato ', 1),
#  ('spices and condiments  coriander powder', 1),
#  ('raisins', 1),
#  ('antioxidant ewater', 1),
#  ('whole black gram ', 1),
#  ('red kidney beans ', 1),
#  ('tomato paste', 1),
#  ('green chillies', 1),
#  ('bay leavesvermicelli wheat semolina', 1),
#  ('edible vegetable fat palm oil', 1),
#  ('cashew nut', 1),
#  ('raisin', 1),
#  ('saffronwater', 1),
#  ('acidity regulator acetic acid', 1),
#  ('modified corn starch', 1),
#  ('preservative sodium benzoaterice flakes ', 1),
#  ('gram flour ', 1),
#  ('corn flakes ', 1),
#  ('peanuts ', 1),
#  ('green peas oats ', 1),
#  ('peas', 1),
#  ('beans', 1),
#  ('spices  condiments onion powder', 1),
#  ('malic acidwheat flour', 1),
#  ('ammonium bicarbonate', 1),
#  ('yeastwheat flour', 1),
#  ('permitted flavorssemolina ', 1),
#  ('black gram dal', 1),
#  ('raising agents eii', 1),
#  ('eii', 1),
#  ('gingerpotato ', 1),
#  ('chickpea flour', 1),
#  ('cinnamon powder', 1),
#  ('nutmeg powdertomato puree ', 1),
#  ('clove powderextracted from fresh coconutsurad flour ', 1),
#  ('edible common saltcoriander', 1),
#  ('cardamom seedsvermicelli wheat semolina ', 1),
#  ('saltsugar', 1),
#  ('tomato powder ', 1),
#  ('tomato ', 1),
#  ('flavors', 1),
#  ('acidifying agent ', 1),
#  ('soy sauce powderwheat flour', 1),
#  ('permitted emulsifiers i', 1),
#  ('artificial flavorsnoodles wheat flour', 1),
#  ('acidity regulator citric acid masala tastemaker hydrolysed peanut protein',
#   1),
#  ('mixed spices coriander', 1),
#  ('noodle powder', 1),
#  ('citric acid', 1),
#  ('potassium chloride', 1),
#  ('sodium bicarbonatesugar', 1),
#  ('pistachio', 1),
#  ('almondvacuum evaporated iodized salt whole wheat flour amla juice emblica officinalis ',
#   1),
#  ('permitted class ii preservative echickpeas ', 1),
#  ('refined vegetable oil', 1),
#  ('red lentils ', 1),
#  ('spices  condiments  onion powder', 1),
#  ('citric acidblack salt', 1),
#  ('mint leaves', 1),
#  ('asafoetidacoriander', 1),
#  ('brown cardamom', 1),
#  ('cloveswheat flour', 1),
#  ('artificial flavorsmixed fruit pulp  banana', 1),
#  ('papaya', 1),
#  ('apple', 1),
#  ('pear', 1),
#  ('pineapple', 1),
#  ('mango', 1),
#  ('mixed spiceschickpeas', 1),
#  ('asafoetidagram flour', 1),
#  ('mace powdersoluble coffee powder ', 1),
#  ('chicory powder sugar', 1),
#  ('hydrogenated vegetable fat', 1),
#  ('rice crispies rice flour', 1),
#  ('malt extract', 1),
#  ('edible glittermilk fat ', 1),
#  ('moisturehoney sugar', 1),
#  ('malt extract ', 1),
#  ('caramel c', 1),
#  ('raising agent ii', 1),
#  ('saltnoodles wheat flour', 1),
#  ('guar gum curry flavour mix salt', 1),
#  ('spices coriander', 1),
#  ('tartaric acid', 1)]

# %%
# create histogram
import matplotlib.pyplot as plt
import numpy as np

plt.bar(range(len(sorted_dict)), [val[1] for val in sorted_dict], align='center')
plt.xticks(range(len(sorted_dict)), [val[0] for val in sorted_dict], rotation='vertical')
plt.show()

# %%
# create a new dictionary with only the most common words
new_dict = {}
for i in range(0, 35):
    new_dict[sorted_dict[i][0]] = sorted_dict[i][1]

# %%
# create histogram
# import matplotlib.pyplot as plt
# import numpy as np

plt.bar(range(len(new_dict)), [val for val in new_dict.values()], align='center')
plt.xticks(range(len(new_dict)), [key for key in new_dict.keys()], rotation='vertical')
plt.show()

# %% [markdown]
# # FINDING COMMON DATA FEATURES IN BEAUTY & FOOD

# %%
foodList = open("dataset/topFoodLabels.txt")
beautyList = open("dataset/topBeautyLabels.txt")

# %%
foodList = (foodList.readlines())[0].split(',')
beautyList = (beautyList.readlines())[0].split(',')

# %%
# find common elements in both lists
common = []
for food in foodList:
    if food in beautyList:
        common.append(food)

# %%
common
# Out:
# ['powder', 'oil', 'turmeric', 'sodium', 'gum', 'potassium', 'water']
