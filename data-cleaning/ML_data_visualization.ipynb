# %%
import re
dataFilePath = "dataset/sample2.md"

dataFile = open(dataFilePath)

# %%
include_Product_Name_in_Dataset = 1

dictionary = {}

ingdList = []

buf = []
for line in dataFile.readlines():
    if(len(line) > 2):
        ## Check if new ingridient has started
        if (line[1] == "." or line[2] == "."):
            # store product name
            # words = line.split(' ')
            # words 


            # store ingridients from buf to list
            ingdList.append(buf)
            buf = []
        else:
            spaceCount = line.count(' ')
            newLineCount = line.count('\n')

            # check if it has other character than space and new line
            if (spaceCount + newLineCount != len(line)):
              if(line[0] == '-' or line[0] == '.'):
                line = line[1:]
                while(line[0] == ' '):
                  line = line[1:]
                while(line[-1] == '\n'):
                  line = line[0:-1]
                buf.append(line)


print(ingdList)
# Out:
# [[], ['Water, Ammonium Lauryl Sulfate, Cocamidopropyl Betaine, Sodium Cocoyl Glutamate, Glycerin, Sodium Lauroyl Sarcosinate, Glycol Distearate, Decyl Glucoside, PEG-150 Distearate, Sodium Lauryl Glucose Carboxylate (and) Lauryl Glucoside, Fragrance, Phenoxyethanol, Sodium Benzoate, Azadirachta Indica (Neem) Leaf Extract, Melia Azadirachta (Neem) Leaf Extract, Sodium Citrate, Citric Acid, Butylene Glycol (and) Boswellia Serrata Gum, Tocopheryl Acetate, CI 19140, CI 42090.'], ['Turmeric Extract, Sandalwood Oil, Water, Stearic Acid, Sorbitol, Sodium Hydroxide, Methyl Paraben, Propyl Paraben.'], ['Coconut Oil, Dugdh (Lactus), Manjistha (Rubia Cordifolia), Nimba Kamla (Citrus Limonum), Badam Tail (Prunus Amygdalus Oil), Cream Base Q.S.'], ['Water, Phenylbenzimidazole Sulfonic Acid, Oxybenzone, Octyl Methoxy Cinnamate, Cyclopentasiloxane, Acrylates/C10-30 Alkyl Acrylate Crosspolymer, Triethanolamine, Glycerin, Phenoxyethanol, Polysorbate 20, Methyl Paraben, Propyl Paraben, Fragrance, Carbomer, Disodium EDTA, Vitamin E.'], ['Methi Seed Extract, Bhringraj Extract, Nagarmotha Extract, Amla Extract, Reetha Extract, Madhu (Honey), Kikar Gond (Acacia Arabica Extract), Vanilla Extract, Purified Water Q.S.'], ['Cyclomethicone, Aqua, Butylene Glycol, Glycerin, Talc, Isotridecyl Isononanoate, Cetyl PEG/PPG-10/1 Dimethicone, HDI/Trimethylol Hexyllactone Crosspolymer, Phenyl Trimethicone, Sodium Chloride, Acrylates/Dimethicone Copolymer, Phenoxyethanol, Methylparaben, Ethylparaben, Propylparaben, Parfum, Tocopheryl Acetate, Disodium EDTA, Sodium Hyaluronate, Butylphenyl Methylpropional, Citronellol, Hexyl Cinnamal, Limonene, Linalool, Alpha-Isomethyl Ionone. May contain Cl 77491, Cl 77492, Cl 77499, Cl 77891.'], ['Aloe Vera, Base Material', 'Aqua, Vitamin E, Permitted Colour and Fragrance.'], ['Aqua, Glycerin, Walnut Shell Powder, Apricot Kernel Oil, Sweet Almond Oil, Kokum Butter, Sesame Oil, Beeswax, Avocado Butter, Kokum Butter, Kumkumadi Oil, Saffron Flower Extract, Vitamin E, Grapefruit Seed Extract, Potassium Sorbate, Essential Oils of Rose, Jasmine, and Lotus.'], ['100% Natural Steam Distilled Pure Rosewater.'], ['Sandalwood Oil, Chamomile Extract, Aloe Vera Gel, Wheat Germ Oil, Carrot Seed Oil, Zinc Oxide, Titanium Dioxide, Avobenzone, Octylmethoxy Cinnamate, Micronized Titanium Dioxide, Beeswax, Methyl Paraben, Propyl Paraben, Phenoxyethanol, Triethanolamine, Allantoin, Potassium Sorbate, Sodium Benzoate, Fragrance.'], ['Calcium Carbonate, Water, Sorbitol, Sodium Lauryl Sulphate, Flavour, Indian Licorice Root Extract, Gum Tragacanth, Carrageenan, Clove Oil, Eucalyptus Oil, Sodium Saccharin, Methyl Paraben, Propyl Paraben.'], ['Water, Sodium Lauryl Ether Sulphate, Glycerin, Sodium Lauryl Sulphate, Propylene Glycol, Cocamidopropyl Betaine, Decyl Glucoside, Acrylates Copolymer, Sodium Cocoyl Glutamate, Coco-Glucoside (and) Glyceryl Oleate, Walnut Shell Powder, Niacinamide, Glycolic Acid, Sodium Hydroxide, Tocopheryl Acetate, Allantoin, Sodium PCA, Camellia Sinensis (Green Tea) Leaf Extract, Morus Alba (Mulberry) Root Extract, BHT, Disodium EDTA, Fragrance, Methylchloroisothiazolinone, Methylisothiazolinone.'], ['Water, Caprylic/Capric Triglyceride, Glycerin, Polyglyceryl-3 Methylglucose Distearate, Glyceryl Stearate, Cetyl Alcohol, Isopropyl Myristate, Simmondsia Chinensis (Jojoba) Seed Oil, Triticum Vulgare (Wheat) Germ Oil, Prunus Amygdalus Dulcis (Sweet Almond) Oil, Butyrospermum Parkii (Shea Butter), Hedychium Spicatum (Spiked Ginger Lily) Extract, Citrus Medica Limonum (Lemon) Peel Extract, Malus Domestica (Apple) Fruit Extract, Vitis Vinifera (Grape Seed) Extract, Aloe Barbadensis (Barbados Aloe) Leaf Juice, Tocopherol, Xanthan Gum, Phenoxyethanol, Ethylhexylglycerin, Fragrance.'], ["Multani Mitti, Calamine, Kaolin, Aloe Vera, Fuller's Earth, Glycerin, PEG-400, Sodium Methyl Paraben."], ['Chickpea Flour, Almond Powder, Neem Leaf Powder, Turmeric Root Powder, Mulethi Root Powder, Sandalwood Powder, Saffron Flower Extract, Essential  ...

# %%
def letters2(input):
    valids = []
    for character in input:
        if character.isalpha() or character == ' ' or character == ',':
            valids.append(character)
    return ''.join(valids)

# %%
def letters(input):
    return re.sub(r"[^A-Za-z ,]+", '', input)

# %%
words = []
for ingridient in ingdList:
    if(type(ingridient) == list and len(ingridient) > 0):
        ingridient = ingridient[0]
    for word in ingridient:
        onlyLetters = ''.join(letters(word.lower()))
        words.append(onlyLetters)

# %%
sentence = ''
for letter in words:
    sentence += letter

# %%
sentence
# Out:
# %%
sentence.split(', ')
# Out:
# ['water',
#  'ammonium lauryl sulfate',
#  'cocamidopropyl betaine',
#  'sodium cocoyl glutamate',
#  'glycerin',
#  'sodium lauroyl sarcosinate',
#  'glycol distearate',
#  'decyl glucoside',
#  'peg distearate',
#  'sodium lauryl glucose carboxylate and lauryl glucoside',
#  'fragrance',
#  'phenoxyethanol',
#  'sodium benzoate',
#  'azadirachta indica neem leaf extract',
#  'melia azadirachta neem leaf extract',
#  'sodium citrate',
#  'citric acid',
#  'butylene glycol and boswellia serrata gum',
#  'tocopheryl acetate',
#  'ci ',
#  'ci turmeric extract',
#  'sandalwood oil',
#  'water',
#  'stearic acid',
#  'sorbitol',
#  'sodium hydroxide',
#  'methyl paraben',
#  'propyl parabencoconut oil',
#  'dugdh lactus',
#  'manjistha rubia cordifolia',
#  'nimba kamla citrus limonum',
#  'badam tail prunus amygdalus oil',
#  'cream base qswater',
#  'phenylbenzimidazole sulfonic acid',
#  'oxybenzone',
#  'octyl methoxy cinnamate',
#  'cyclopentasiloxane',
#  'acrylatesc alkyl acrylate crosspolymer',
#  'triethanolamine',
#  'glycerin',
#  'phenoxyethanol',
#  'polysorbate ',
#  'methyl paraben',
#  'propyl paraben',
#  'fragrance',
#  'carbomer',
#  'disodium edta',
#  'vitamin emethi seed extract',
#  'bhringraj extract',
#  'nagarmotha extract',
#  'amla extract',
#  'reetha extract',
#  'madhu honey',
#  'kikar gond acacia arabica extract',
#  'vanilla extract',
#  'purified water qscyclomethicone',
#  'aqua',
#  'butylene glycol',
#  'glycerin',
#  'talc',
#  'isotridecyl isononanoate',
#  'cetyl pegppg dimethicone',
#  'hditrimethylol hexyllactone crosspolymer',
#  'phenyl trimethicone',
#  'sodium chloride',
#  'acrylatesdimethicone copolymer',
#  'phenoxyethanol',
#  'methylparaben',
#  'ethylparaben',
#  'propylparaben',
#  'parfum',
#  'tocopheryl acetate',
#  'disodium edta',
#  'sodium hyaluronate',
#  'butylphenyl methylpropional',
#  'citronellol',
#  'hexyl cinnamal',
#  'limonene',
#  'linalool',
#  'alphaisomethyl ionone may contain cl ',
#  'cl ',
#  'cl ',
#  'cl aloe vera',
#  'base materialaqua',
#  'glycerin',
#  'walnut shell powder',
#  'apricot kernel oil',
#  'sweet almond oil',
#  'kokum butter',
#  'sesame oil',
#  'beeswax',
#  'avocado butter',
#  'kokum butter',
#  'kumkumadi oil',
#  'saffron flower extract',
#  'vitamin e',
#  'grapefruit seed extract',
#  'potassium sorbate',
#  'essential oils of rose',
#  'jasmine',
#  'and lotus natural steam distilled pure rosewatersandalwood oil',
#  'chamomile extract',
#  'aloe vera gel',
#  'wheat germ oil',
#  'carrot seed oil',
#  'zinc oxide',
#  'titanium dioxide',
#  'avobenzone',
#  'octylmethoxy cinnamate',
#  'micronized titanium dioxide',
#  'beeswax',
#  'methyl paraben',
#  'propyl paraben',
#  'phenoxyethanol',
#  'triethanolamine',
#  'allantoin',
#  'potassium sorbate',
#  'sodium benzoate',
#  'fragrancecalcium carbonate',
#  'water',
#  'sorbitol',
#  'sodium lauryl sulphate',
#  'flavour',
#  'indian licorice root extract',
#  'gum tragacanth',
#  'carrageenan',
#  'clove oil',
#  'eucalyptus oil',
#  'sodium saccharin',
#  'methyl paraben',
#  'propyl parabenwater',
#  'sodium lauryl ether sulphate',
#  'glycerin',
#  'sodium lauryl sulphate',
#  'propylene glycol',
#  'cocamidopropyl betaine',
#  'decyl glucoside',
#  'acrylates copolymer',
#  'sodium cocoyl glutamate',
#  'cocoglucoside and glyceryl oleate',
#  'walnut shell powder',
#  'niacinamide',
#  'glycolic acid',
#  'sodium hydroxide',
#  'tocopheryl acetate',
#  'allantoin',
#  'sodium pca',
#  'camellia sinensis green tea leaf extract',
#  'morus alba mulberry root extract',
#  'bht',
#  'disodium edta',
#  'fragrance',
#  'methylchloroisothiazolinone',
#  'methylisothiazolinonewater',
#  'capryliccapric triglyceride',
#  'glycerin',
#  'polyglyceryl methylglucose distearate',
#  'glyceryl stearate',
#  'cetyl alcohol',
#  'isopropyl myristate',
#  'simmondsia chinensis jojoba seed oil',
#  'triticum vulgare wheat germ oil',
#  'prunus amygdalus dulcis sweet almond oil',
#  'butyrospermum parkii shea butter',
#  'hedychium spicatum spiked ginger lily extract',
#  'citrus medica limonum lemon peel extract',
#  'malus domestica apple fruit extract',
#  'vitis vinifera grape seed extract',
#  'aloe barbadensis barbados aloe leaf juice',
#  'tocopherol',
#  'xanthan gum',
#  'phenoxyethanol',
#  'ethylhexylglycerin',
#  'fragrancemultani mitti',
#  'calamine',
#  'kaolin',
#  'aloe vera',
#  'fullers earth',
#  'glycerin',
#  'peg',
#  'sodium methyl parabenchickpea flour',
#  'almond powder',
#  'neem leaf powder',
#  'turmeric root powder',
#  'mulethi root powder',
#  'sandalwood powder',
#  'saffron flower extract',
#  'essential oils of sandalwood',
#  'orange',
#  'and nagkesarwheat germ oil',
#  'sunflower oil',
#  'aloe vera juice',
#  'honey',
#  'methi seed extract',
#  'kulanjan rhizome extract',
#  'ankurit gehun seed extract',
#  'madhu',
#  'purified water',
#  'cream base',
#  'qswater',
#  'paraffinum liquidum',
#  'isohexadecane',
#  'glycerin',
#  'cetearyl alcohol',
#  'glyceryl stearate citrate',
#  'dimethicone',
#  'glyceryl stearate',
#  'prunus amygdalus dulcis oil',
#  'sodium carbomer',
#  'sodium acrylatesc alkyl acrylate crosspolymer',
#  'phenoxyethanol',
#  'ethylhexylglycerin',
#  'linalool',
#  'citronellol',
#  'alphaisomethyl ionone',
#  'geraniol',
#  'benzyl alcohol',
#  'parfumpapaya seed scrub  papaya seed powder',
#  'kaolin powder',
#  'solum fullonum fullers earth',
#  'sodium methylparaben',
#  'fragrance cucumber gel  cucumber extract',
#  'propylene glycol',
#  'glycerine',
#  'cellulose gum',
#  'methylparaben',
#  'propylparaben',
#  'fragrance peach massage cream  wheat germ oil',
#  'olive oil',
#  'vitamin e',
#  'xanthan gum',
#  'isopropyl myristate',
#  'methylparaben',
#  'propylparaben',
#  'fragrance orange antitan pack  orange peel powder',
#  'zinc oxide',
#  'kaolin powder',
#  'bentonite powder',
#  'cetyl alcohol',
#  'isopropyl myristate',
#  'sodium lauryl sulphate',
#  'methylparaben',
#  'propylparaben',
#  'fragrancealoe vera',
#  'manjishta',
#  'ghritkumari',
#  'kesar',
#  'sandalwood',
#  'akarkara',
#  'anantmool',
#  'durva',
#  'ghritkumari b',
#  'daruhaldi',
#  'lodhra',
#  'neem',
#  'tulsi',
#  'turmeric',
#  'xanthan gum',
#  'vitamin e',
#  'potassium sorbate',
#  'sodium benzoate',
#  'pudina ka phool',
#  'sugandhit dravya',
#  'aquacyclopentasiloxane',
#  'trimethylsiloxysilicate',
#  'polyethylene',
#  'mica',
#  'lauroyl lysine',
#  'ozokerite',
#  'octyldodecanol',
#  'disteardimonium hectorite',
#  'propylene carbonate',
#  'tocopherol',
#  'calcium aluminum borosilicate',
#  'propylparaben',
#  'bht',
#  'tin oxide',
#  'may contain cl ',
#  'cl ',
#  'cl ',
#  'cl ',
#  'cl ',
#  'cl water',
#  'octyl methoxy cinnamate',
#  'butyl methoxy dibenzoyl methane',
#  'benzophenone',
#  'phenylbenzimidazole sulfonic acid',
#  'polyacrylamide c isoparaffin',
#  'laureth',
#  'triethanolamine',
#  'cyclopentasiloxane',
#  'dimethicone',
#  'titanium dioxide',
#  'methyl paraben',
#  'propyl paraben',
#  'disodium edta',
#  'allantoin',
#  'glycerin',
#  'butylene glycol',
#  'phenoxyethanol',
#  'perfumefullers earth multani mitti',
#  'calamine powder',
#  'sandalwood powder',
#  'neem powder',
#  'turmeric powder',
#  'fennel powder',
#  'star anise powder',
#  'almond powder',
#  'fenugreek powder',
#  'saffron extract',
#  'orange peel powderwater',
#  'ammonium lauryl sulfate',
#  'disodium cocamphodiacetate',
#  'sodium lauroyl sarcosinate',
#  'cocamidopropyl betaine',
#  'extracts of neem and turmeric',
#  'sodium pca',
#  'sodium cocoyl glutamate',
#  'decyl glucoside',
#  'fragrance',
#  'phenoxyethanol',
#  'methylchloroisothiazolinone',
#  'methylisothiazolinone',
#  'citric acid',
#  'ci ',
#  'ci saffron',
#  'vetiver',
#  'lotus',
#  'licorice',
#  'indian madder',
#  'manjistha',
#  'sandalwood',
#  'orange peel',
#  'turmeric',
#  'sesame oil',
#  'bael',
#  'base qsaquawater',
#  'sodium laureth sulfate',
#  'cocobetaine',
#  'sodium chloride',
#  'glycol distearate',
#  'dimethicone',
#  'guar hydroxypropyltrimonium chloride',
#  'cocamide mipa',
#  'sodium benzoate',
#  'hydroxypropyltrimonium hydrolyzed wheat protein',
#  'sodium hydroxide',
#  'ppgceteth',
#  'arginine',
#  'salicylic acid',
#  'polyquaternium',
#  'limonene',
#  'linalool',
#  'benzyl salicylate',
#  'oleamido,octadecanediol',
#  'carbomer',
#  'serine',
#  'butylphenyl methylpropional',
#  'citric acid',
#  'glutamic acid',
#  'hexyl cinnamal',
#  'glyceryl linoleate',
#  'glyceryl oleate',
#  'glyceryl linolenate',
#  'parfumfragranceturmeric',
#  'sandalwood oil',
#  'sodium hydroxide',
#  'beeswax',
#  'water',
#  'borax',
#  'perfumegreen apple',
#  'centella',
#  'bhringraj',
#  'sea algae',
#  'himalayan water',
#  'sles derived',
#  'neutral thickener',
#  'polyquaterium ',
#  'natural preservative blendfullers earth',
#  'neem',
#  'turmeric',
#  'lodhra',
#  'multani mitti',
#  'kaolin',
#  'aloe vera',
#  'bentone gel',
#  'zinc oxide',
#  'gum acacia',
#  'methylparaben sodium',
#  'propylparaben sodium',
#  'sodium lauryl ether sulphate',
#  'titanium dioxide',
#  'perfumealoe vera',
#  'base material qs',
#  'preservativesisododecane',
#  'polyethylene',
#  'synthetic wax',
#  'hydrogenated polydicyclopentadiene',
#  'ethylenepropylene copolymer',
#  'bisdiglyceryl polyacyladipate',
#  'hydrogenated styrenemethyl styreneindene copolymer',
#  'silica',
#  'polybutene',
#  'pentaerythrityl tetraditbutyl hydroxyhydrocinnamate',
#  'cococaprylatecaprate',
#  'talc',
#  'trimethylsiloxysilicate',
#  'mica',
#  ' ci  nanoblack ',
#  'ci ultramarines',
#  'ci iron oxides',
#  'ci iron oxides',
#  'ci iron oxideskiehls clearly corrective dark spot solutionpurified water',
#  'decyl glucoside',
#  'cocoamidopropyl betain',
#  'lauryl glucoside',
#  'glycerin',
#  'sodium pca',
#  'sodium lactate',
#  'pca glyceryl oleate',
#  'hydrolyzed wheat protein',
#  'soy protein',
#  'coco glucoside',
#  'aloe vera extract',
#  'vetiver oil',
#  'patchouli oil',
#  'lavender oil',
#  'geranium oil',
#  'rose oil',
#  'hibiscus extract',
#  'shikakai extract',
#  'reetha extract',
#  'lemon extract',
#  'citric acid',
#  'potassium sorbate',
#  'sodium benzoate',
#  'xanthan gum',
#  'caprylyl glycol',
#  'essential oils of lavender',
#  'patchouli',
#  'geranium and rose certified organic ingredientpurified water',
#  'bhringraj extract',
#  'hibiscus extract',
#  'fenugreek extract',
#  'brahmi extract',
#  'nettle extract',
#  'cinnamon extract',
#  'bay leaf extract',
#  'almond extract',
#  'orange peel extract',
#  'neem extract',
#  'turmeric extract',
#  'wheat protein',
#  'vegetable glycerin',
#  'hydroxypropyltrimonium honey',
#  'silk amino acids',
#  'inositol',
#  'citric acid',
#  'essential oils of orange',
#  'lemongrass and lavenderpurified water',
#  'decyl glucoside',
#  'glycerin',
#  'sodium lauroyl sarcosinate',
#  'carbomer',
#  'turmeric',
#  'saffron',
#  'cucumber',
#  'aloe vera extract',
#  'licorice extract',
#  'peppermint oil',
#  'potassium sorbate',
#  'sodium benzoate',
#  'citric acidmadhu honey',
#  'ghrit kumari aloe vera barbadensis',
#  'rosa rose ',
#  'purified water qswater',
#  'propylene glycol',
#  'cyclopentasiloxane',
#  'cyclohexasiloxane',
#  'zinc oxide',
#  'titanium dioxide',
#  'isopropyl myristate',
#  'octyl methoxycinnamate',
#  'phenylbenzimidazole sulfonic acid',
#  'triethanolamine',
#  'stearic acid',
#  'aluminum hydroxide',
#  'carbomer',
#  'tocopheryl acetate',
#  'methylparaben',
#  'propylparaben',
#  'fragrancepurified water',
#  'decyl glucoside',
#  'cocoamidopropyl betaine',
#  'lauryl glucoside',
#  'sodium cocoyl glutamate',
#  'vegetable glycerin',
#  'honey',
#  'vanilla extract',
#  'brahmi extract',
#  'neem extract',
#  'fenugreek extract',
#  'bhringraj extract',
#  'hibiscus extract',
#  'almond extract',
#  'wheat protein',
#  'soy protein',
#  'xanthan gum',
#  'citric acid',
#  'caprylyl glycol',
#  'sodium benzoate',
#  'potassium sorbatemultani mitti',
#  'geru red clay',
#  'yasad bhasm yasad bhasma',
#  'tomato lycopersicum esculentum',
#  'pineapple ananas comosus',
#  'papaya carica papaya',
#  'apple malus domestica',
#  'cucumber cucumis sativus',
#  'fullers earth solum multani',
#  'qsaloe vera',
#  'extracts of kesar and chandan',
#  'vitamin e',
#  'permitted colour',
#  'sugandhit dravya',
#  'base material qswater',
#  'ammonium lauryl sulfate',
#  'melia azadirachta leaf extract',
#  'cocamidopropyl betaine',
#  'sodium cocoyl glutamate',
#  'sodium lauryl glucose carboxylate',
#  'lauryl glucoside',
#  'decyl glucoside',
#  'glycerin',
#  'citric acid',
#  'fragrance',
#  'potassium sorbate',
#  'sodium benzoate',
#  'tocopheryl acetateaqua',
#  'rose water',
#  'aloe vera',
#  'honey',
#  'decyl glucoside',
#  'cocoglucoside',
#  'lauryl glucoside',
#  'glycerin',
#  'citric acid',
#  'xanthan gum',
#  'sodium levulinate',
#  'sodium anisate',
#  'sodium benzoate',
#  'potassium sorbate',
#  'fragrancecapryliccapric triglyceride',
#  'onion seed oil',
#  'organic sunflower oil',
#  'organic amla oil',
#  'organic hibiscus oil',
#  'tocopherol',
#  'rosemary oil',
#  'sodium benzoatesaffron',
#  'indian madder',
#  'licorice',
#  'lotus',
#  'vetiver',
#  'kashmiri saffron',
#  'sweet almond oil',
#  'sesame oil',
#  'castor oil',
#  'sandalwood oil',
#  'vetiver oil',
#  'lotus oil',
#  'turmeric',
#  'manjishtha',
#  'padmakashtha',
#  'anantmoolturmeric extract',
#  'sandalwood oil',
#  'water',
#  'stearic acid',
#  'sorbitol',
#  'methylparaben',
#  'propylparaben',
#  'sodium hydroxide',
#  'scented perfumeaqua',
#  'kaolin',
#  'china clay',
#  'glycerin',
#  'aloe vera extract',
#  'bentonite powder',
#  'activated charcoal powder',
#  'tea tree oil',
#  'calendula extract',
#  'lavender oil',
#  'camphor oil',
#  'vitamin e oilaqua',
#  'capryliccapric triglyceride',
#  'isopropyl myristate',
#  'glycerin',
#  'cetyl alcohol',
#  'glyceryl stearate',
#  'cetearyl alcohol',
#  'dimethicone',
#  'phenoxyethanol',
#  'sodium lauryl sulfate',
#  'fragrance',
#  'triethanolamine',
#  'carbomer',
#  'sodium benzoate',
#  'methylparaben',
#  'tocopheryl acetate',
#  'propylparaben',
#  'disodium edta',
#  'sodium metabisulfiteextracts of haldi',
#  'chandan',
#  'aloe vera',
#  'glycerin',
#  'perfume',
#  'soap base qsdesi cows milk',
#  'ghee',
#  'kokum butter',
#  'raw honey',
#  'sandalwood oil',
#  'rose oil',
#  'anantmool root extract',
#  'aloe vera leaf extract',
#  'nagkesar flower extract',
#  'mulethi root extract',
#  'vitamin e',
#  'potassium sorbatewater',
#  'light liquid paraffin',
#  'hydrogenated polyisobutene',
#  'glycerin',
#  'arbutin',
#  'cyclopentasiloxane',
#  'capryliccapric triglyceride',
#  'titanium dioxide',
#  'cetyl alcohol',
#  'glyceryl stearate',
#  'peg stearate',
#  'behenyl alcohol',
#  'phenoxyethanol',
#  'methylparaben',
#  'propylparaben',
#  'carbomer',
#  'triethanolamine',
#  'tocopheryl acetate',
#  'fragrance',
#  'sodium ascorbyl phosphate',
#  'allantoin',
#  'disodium edtaghrit kumari aloe vera barbadensis',
#  'methi trigonella foenumgraecum',
#  'madhu honey',
#  'ankurit gehun triticum vulgare',
#  'kusumbhi carthamus tinctorius',
#  'vach acorus calamus',
#  'lotion base qswater',
#  'mineral oil',
#  'propylene glycol',
#  'stearic acid',
#  'glyceryl stearate',
#  'cetyl alcohol',
#  'triethanolamine',
#  'polysorbate',
#  'phenoxyethanol',
#  'methylparaben',
#  'propylparaben',
#  'sodium lauryl ether sulfate',
#  'acrylatesc alkyl acrylate crosspolymer',
#  'fragrance',
#  'allantoin',
#  'disodium edta',
#  'tocopheryl acetate',
#  'sandalwood oil',
#  'milkpurified water',
#  'almond oil',
#  'honey',
#  'aloe vera juice',
#  'rose water',
#  'emulsifying wax',
#  'glycerin',
#  'stearic acid',
#  'sodium benzoate',
#  'potassium sorbate',
#  'cetyl alcohol',
#  'triethanolamine',
#  'vitamin e acetate',
#  'dimethicone',
#  'methylparaben',
#  'propylparaben',
#  'carbopol',
#  'fragrancealoe vera',
#  'neem',
#  'tulsi',
#  'orange peel',
#  'pudina',
#  'aqua',
#  'gel base',
#  'diazolidinyl urea  iodopropynyl butylcarbamate',
#  'vitamin e',
#  'vitamin a',
#  'ci',
#  'ci',
#  'sugandhit dravyaqsamla',
#  'shikakai',
#  'reetha',
#  'water',
#  'sodium laureth sulphate',
#  'cocamidopropyl betaine',
#  'cocamide dea',
#  'polyquaternium',
#  'glycerin',
#  'sodium chloride',
#  'methylparaben',
#  'propylparaben',
#  'citric acid',
#  'fragrancewater',
#  'glycerin',
#  'cyclopentasiloxane',
#  'ethylhexyl methoxycinnamate',
#  'dimethicone crosspolymer',
#  'titanium dioxide',
#  'sodium acrylatesodium acryloyldimethyl taurate copolymer',
#  'isohexadecane',
#  'cyclohexasiloxane',
#  'peg trimethylolpropane coconut ether',
#  'benzophenone',
#  'polysorbate ',
#  'aluminium hydroxide',
#  'stearic acid',
#  'phenoxyethanol',
#  'methylparaben',
#  'propylparaben',
#  'allantoin',
#  'vitamin e acetate',
#  'fragrancewater',
#  'ammonium lauryl sulfate',
#  'cocamidopropyl betaine',
#  'sodium cocoyl glutamate',
#  'sodium lauryl glucose carboxylate and lauryl glucoside',
#  'decyl glucoside',
#  'glycerin',
#  'sodium hydroxide',
#  'fragrance',
#  'phenoxyethanol',
#  'curcuma longa turmeric root extract',
#  'azadirachta indica neem leaf extract',
#  'sodium benzoate',
#  'potassium sorbate',
#  'citric acidgreen apple',
#  'sea algae',
#  'centella',
#  'sodium laureth sulphate',
#  'himalayan water qsaqua',
#  'glycerin',
#  'almond oil',
#  'mulethi',
#  'anantmool',
#  'ashwagandha',
#  'nagkesar',
#  'durva',
#  'yashtimadhu',
#  'manjishtha',
#  'cows milk',
#  'sesame oil',
#  'shea butter',
#  'kokum butter',
#  'bees wax',
#  'vitamin e',
#  'saffron',
#  ' karat gold bhasma',
#  'cinnamon oil',
#  'rose oil',
#  'mogra oil',
#  'jasmine oil',
#  'spf rosa damascena flower wateraqua',
#  'sodium laureth sulfate',
#  'cocobetaine',
#  'dimethicone',
#  'glycol distearate',
#  'sodium chloride',
#  'guar hydroxypropyltrimonium chloride',
#  'cocoamide mipa',
#  'sodium benzoate',
#  'sodium hydroxide',
#  'citric acid',
#  'hexylene glycol',
#  'argania spinosa kernel oil',
#  'salicylic acid',
#  'carbomer',
#  'ci ',
#  'ci ',
#  'fragrancealoe vera ',
#  'base material qs',
#  'preservatives sorbic acid  ',
#  'diazolidinyl urea  turmeric',
#  'sandalwood oil',
#  'sodium hydroxide',
#  'borax',
#  'waterwater',
#  'cyclopentasiloxane',
#  'ethylhexyl methoxycinnamate',
#  'titanium dioxide',
#  'zinc oxide',
#  'butyl methoxydibenzoylmethane',
#  'octocrylene',
#  'glycerin',
#  'potassium cetyl phosphate',
#  'cetyl alcohol',
#  'phenylbenzimidazole sulfonic acid',
#  'glyceryl stearate',
#  'peg stearate',
#  'phenoxyethanol',
#  'acrylatesc alkyl acrylate crosspolymer',
#  'triethanolamine',
#  'methylparaben',
#  'propylparaben',
#  'xanthan gum',
#  'disodium edta',
#  'fragrance',
#  'bht',
#  'epilobium angustifolium extract',
#  'cyclohexasiloxanemineral oil',
#  'vegetable oil',
#  'amla extract emblica officinalis',
#  'perfume',
#  'antioxidant tertbutylhydroquinone tbhqfullers earth',
#  'chickpea flour',
#  'sandalwood powder',
#  'turmeric powder',
#  'mulberry extract',
#  'cucumber extract',
#  'papaya extract',
#  'licorice extract',
#  'carrot seed oil',
#  'saffron oil',
#  'aqua',
#  'preservatives phenoxyethanol and sodium benzoatewater',
#  'cyclomethicone',
#  'dimethicone crosspolymer',
#  'caprylyl methicone',
#  'glycerine',
#  'niacinamide',
#  'sodium pca',
#  'trehalose',
#  'sodium hyaluronate',
#  'saxifraga extract',
#  'grape extract',
#  'morus alba root extract',
#  'scutellaria baicalensis root extract',
#  'glutathione',
#  'phenyl ethyl resorcinol',
#  'sodium ascorbyl phosphate',
#  'polysorbate',
#  'fragrance',
#  'disodium edta',
#  'phenoxyethanol',
#  'methylparaben',
#  'propylparaben',
#  'ethylparaben',
#  'butylparaben',
#  'isobutylparaben',
#  'sodium hydroxidewater',
#  'juglans regia walnut shell granules',
#  'glyceryl stearate se',
#  'propylene glycol',
#  'cetyl alcohol',
#  'stearic acid',
#  'isopropyl myristate',
#  'cetearyl alcohol',
#  'fragrance',
#  'tocopheryl acetate',
#  'methylparaben',
#  'propylparaben',
#  'phenoxyethanol',
#  'carbomer',
#  'sodium hydroxidepurified water',
#  'almond oil',
#  'coconut oil',
#  'cocoa butter',
#  'shea butter',
#  'bees wax',
#  'kokum butter',
#  'glycerin',
#  'jasmine extract',
#  'mogra extract',
#  'aloe vera',
#  'vitamin e',
#  'potassium sorbate',
#  'sodium benzoate',
#  'essential oil of jasminesesame oil',
#  'milk',
#  'indigo',
#  'eclipta alba',
#  'gooseberry',
#  'balloon vine',
#  'liquorice',
#  'madder root',
#  'fenugreek',
#  'rosemary',
#  'himalayan cedarwood',
#  'henna',
#  'ashwagandha',
#  'essential oil of vetiver',
#  'essential oil of geraniumcastor oil',
#  'amla',
#  'almond oil',
#  'triphala',
#  'ghrit kumari',
#  'damask rose',
#  'camphor',
#  'cows gheewater',
#  'cyclopentasiloxane',
#  'ethylhexyl methoxycinnamate',
#  'zinc oxide',
#  'titanium dioxide',
#  'glycerin',
#  'peg dimethicone',
#  'methylene bisbenzotriazolyl tetramethylbutylphenol',
#  'butyl methoxydibenzoylmethane',
#  'isododecane',
#  'bisethylhexyloxyphenol methoxyphenyl triazine',
#  'sodium chloride',
#  'phenoxyethanol',
#  'benzyl alcohol',
#  'acrylatesdimethicone copolymer',
#  'triethanolamine',
#  'tocopheryl acetate',
#  'perfume',
#  'disodium edta',
#  'bhtneem bark',
#  'chamomile',
#  'haldi',
#  'gulab phool',
#  'water',
#  'ritha',
#  'kulanjan',
#  'madhu',
#  'coconut oil derivatives',
#  'purified himalayan water qsaloe vera  ',
#  'vitamin e',
#  'permitted colour',
#  'fragrance',
#  'preservatives qswater',
#  'aloe vera leaf juice',
#  'apricot kernel oil',
#  'sweet almond oil',
#  'emulsifying wax',
#  'walnuts',
#  'beeswax',
#  'glycerin',
#  'cetyl alcohol',
#  'sodium pca',
#  'potassium sorbate',
#  'sodium benzoate',
#  'kokum butter',
#  'honey',
#  'olive oil',
#  'vitamin e',
#  'turmeric',
#  'sandalwood oil',
#  'geranium oilmultani mitti',
#  'geru',
#  'yasad bhasm',
#  'tamator',
#  'ananas',
#  'seb',
#  'beheda',
#  'badam',
#  'jaiphal',
#  'kikar gaund',
#  'paste base qssaffron',
#  'red sandalwood',
#  'vetiver',
#  'lotus',
#  'liquorice',
#  'turmeric',
#  'manjistha',
#  'sesame oil',
#  'indian madder',
#  'banyan',
#  'indian barberry',
#  'flame of the forest',
#  'mulethi',
#  'kashmiri saffron',
#  'rose',
#  'padma kesar',
#  'and sesame oilneem',
#  'turmeric',
#  'water',
#  'ammonium lauryl sulfate',
#  'cocamidopropyl betaine',
#  'sodium cocoyl glutamate',
#  'sodium lauryl sarcosinate',
#  'glycol distearate',
#  'decyl glucoside',
#  'polyquaternium',
#  'citric acid',
#  'fragrance',
#  'phenoxyethanol',
#  'methylchloroisothiazolinone',
#  'methylisothiazolinone',
#  ...]

# %%
words = []

for ingridient in ingdList:
  if(ingridient == []):
    continue
  separated = ingridient[0].split(',')
  for word in separated:
    while word[0] == ' ':
      word = word[1:]
    newingridient = word[0:word.find('(')]
    words.append(newingridient)

# %%
writer = open('dataset/outWords.csv', 'w')
for ing in sentence.split(', '):
    writer.write(ing + '\n')

# %%
items = sentence.split(', ')

while(items.__contains__('')):
    items.remove('')

    
for item in items:
    print(item)
    while(item[0] == ' '):
        item = item[1:]
    while(item[-1] == ' '):
        item = item[0:-1]
# Out:
# water
# ammonium lauryl sulfate
# cocamidopropyl betaine
# sodium cocoyl glutamate
# glycerin
# sodium lauroyl sarcosinate
# glycol distearate
# decyl glucoside
# peg distearate
# sodium lauryl glucose carboxylate and lauryl glucoside
# fragrance
# phenoxyethanol
# sodium benzoate
# azadirachta indica neem leaf extract
# melia azadirachta neem leaf extract
# sodium citrate
# citric acid
# butylene glycol and boswellia serrata gum
# tocopheryl acetate
# ci
# ci turmeric extract
# sandalwood oil
# water
# stearic acid
# sorbitol
# sodium hydroxide
# methyl paraben
# propyl parabencoconut oil
# dugdh lactus
# manjistha rubia cordifolia
# nimba kamla citrus limonum
# badam tail prunus amygdalus oil
# cream base qswater
# phenylbenzimidazole sulfonic acid
# oxybenzone
# octyl methoxy cinnamate
# cyclopentasiloxane
# acrylatesc alkyl acrylate crosspolymer
# triethanolamine
# glycerin
# phenoxyethanol
# polysorbate
# methyl paraben
# propyl paraben
# fragrance
# carbomer
# disodium edta
# vitamin emethi seed extract
# bhringraj extract
# nagarmotha extract
# amla extract
# reetha extract
# madhu honey
# kikar gond acacia arabica extract
# vanilla extract
# purified water qscyclomethicone
# aqua
# butylene glycol
# glycerin
# talc
# isotridecyl isononanoate
# cetyl pegppg dimethicone
# hditrimethylol hexyllactone crosspolymer
# phenyl trimethicone
# sodium chloride
# acrylatesdimethicone copolymer
# phenoxyethanol
# methylparaben
# ethylparaben
# propylparaben
# parfum
# tocopheryl acetate
# disodium edta
# sodium hyaluronate
# butylphenyl methylpropional
# citronellol
# hexyl cinnamal
# limonene
# linalool
# alphaisomethyl ionone may contain cl
# cl
# cl
# cl aloe vera
# base materialaqua
# glycerin
# walnut shell powder
# apricot kernel oil
# sweet almond oil
# kokum butter
# sesame oil
# beeswax
# avocado butter
# kokum butter
# kumkumadi oil
# saffron flower extract
# vitamin e
# grapefruit seed extract
# potassium sorbate
# essential oils of rose
# jasmine
# and lotus natural steam distilled pure rosewatersandalwood oil
# chamomile extract
# aloe vera gel
# wheat germ oil
# carrot seed oil
# zinc oxide
# titanium dioxide
# avobenzone
# octylmethoxy cinnamate
# micronized titanium dioxide
# beeswax
# methyl paraben
# propyl paraben
# phenoxyethanol
# triethanolamine
# allantoin
# potassium sorbate
# sodium benzoate
# fragrancecalcium carbonate
# water
# sorbitol
# sodium lauryl sulphate
# flavour
# indian licorice root extract
# gum tragacanth
# carrageenan
# clove oil
# eucalyptus oil
# sodium saccharin
# methyl paraben
# propyl parabenwater
# sodium lauryl ether sulphate
# glycerin
# sodium lauryl sulphate
# propylene glycol
# cocamidopropyl betaine
# decyl glucoside
# acrylates copolymer
# sodium cocoyl glutamate
# cocoglucoside and glyceryl oleate
# walnut shell powder
# niacinamide
# glycolic acid
# sodium hydroxide
# tocopheryl acetate
# allantoin
# sodium pca
# potassium sorbate
# disodium edta
# and ci turmeric extract
# sandalwood oil
# sodi biboras
# borax
# and cream baseonion seed oil
# sunflower oil
# amla oil
# hibiscus oil
# bhringraj oil
# sesame oil
# castor oil
# jojoba oil
# rosemary oil
# vitamin e
# and fragranceisododecane
# dimethicone
# trimethylsiloxysilicate
# polybutene
# petrolatum
# cyclohexasiloxane
# kaolin
# disteardimonium hectorite
# cera alba
# silica dimethyl silylate
# synthetic fluorphlogopite
# glyceryl behenateeicosadioate
# propylene carbonate
# silica
# tin oxide
# tocopherol
# persea gratissima oil
# and  ci
# ci
# ci
# ci
# ci
# ci chickpea flour
# almond powder
# turmeric
# sandalwood powder
# fenugreek powder
# lodhra powder
# orange peel powder
# rose petal powder
# indian madder powder
# licorice root powder
# and saffrongreen apple
# sea algae extract
# centella asiatica extract
# eclipta prostrata extract
# soap nut extract
# musk root extract
# grape seed oil
# and pure himalayan waterwater
# glycerin
# sodium polyacrylate starch
# alumina
# methyl paraben
# propyl paraben
# arbutin
# mulberry extract
# saxifraga extract
# grape extract
# milk enzymes
# and titanium dioxidesaffron
# kumkumadi tailam
# manjistha
# lodhra
# turmeric
# and kumariaqua
# caprylylcapryl glucoside
# sodium lauroyl glutamate
# coco glucoside
# glyceryl oleate
# sodium pca
# xylitylglucoside
# anhydroxylitol
# xylitol
# sodium levulinate
# potassium sorbate
# sodium gluconate
# betaine
# aloe vera juice
# rosa damascena flower oil
# and jasminum grandiflorum flower extractwater
# ammonium lauryl sulfate
# cocamidopropyl betaine
# sodium cocoyl glutamate
# sodium lauryl sulfate
# glycerin
# glycol distearate
# acrylatesc alkyl acrylate crosspolymer
# polyquaternium
# phenoxyethanol
# sodium hydroxide
# fragrance
# azadirachta indica neem leaf extract
# and curcuma longa turmeric root extractaloe vera juice
# rosa centifolia rose flower extract
# ocimum basilicum basil extract
# santalum album sandalwood oil
# and aquakokum butter
# organic beeswax
# organic honey
# aloe vera juice
# mulethi extract
# fennel extract
# lodhra extract
# lemon peel extract
# orange peel extract
# sandalwood oil
# rose oil
# saffron extract
# and turmeric oilpurified water
# sodium lauroyl sarcosinate
# disodium cocoamphodiacetate
# glycerin
# sodium pca
# sodium lactate
# tea tree oil
# allantoin
# xanthan gum
# vitamin e
# and lavender oilhoney
# aloe vera
# neem leaf extract
# turmeric extract
# and rose extractrosa damascena flower distillatewater
# talc
# cyclomethicone
# octyl methoxy cinnamate
# butyl methoxydibenzoylmethane
# benzophenone
# phenoxyethanol
# methylparaben
# propylparaben
# ethylhexyl methoxycinnamate
# perfume
# allantoin
# and polysorbate surajmukhi oil
# badam oil
# arandi oil
# neem oil
# soy lecithin
# vitamin e
# and cleanser base qswater
# glycerin
# propylene glycol
# niacinamide
# glycyrrhiza glabra licorice root extract
# punica granatum pomegranate fruit extract
# morus nigra mulberry fruit extract
# arctostaphylos uva ursi bearberry leaf extract
# lactic acid
# polysorbate
# xanthan gum
# phenoxyethanol
# and methylparabenpurified water
# cold pressed organic oils of coconut
# almond
# and wheat germ
# beeswax
# kokum butter
# ghee
# honey
# mulethi
# sandalwood oil
# and k gold bhasmawater
# ammonium lauryl sulfate
# cocamidopropyl betaine
# sodium cocoyl glutamate
# sodium lauryl sulfoacetate
# glycerin
# polysorbate
# azadirachta indica neem leaf extract
# peg distearate
# fragrance
# phenoxyethanol
# caprylyl glycol
# sodium benzoate
# and citric acidaloe vera aloe barbadensis gel
# base material qs
# vitamin e
# and permitted colorextracts of neem
# long pepper
# red sandalwood
# and tea tree oil
# clove oil
# camphor
# zinc oxide
# and cream base qs

# %%
dictionary = {}

for item in items:
    if item in dictionary:
        dictionary[item] += 1
    else:
        dictionary[item] = 1

# %%
dictionary
# Out:
# {'milk fat ': 1,
#  'moisture ': 1,
#  'salt ': 1,
#  'permitted natural color annattosugar': 1,
#  'milk solids ': 1,
#  'cocoa butter': 2,
#  'cocoa solids': 6,
#  'emulsifiers ': 4,
#  'vegetable fat': 1,
#  'maltitol': 1,
#  'flavoring substances': 1,
#  'contains added flavors artificial vanilla and chocolate': 1,
#  'sweetener maltitol  imoong dal ': 1,
#  'edible vegetable oil': 32,
#  'salt': 59,
#  'red chilli powder': 12,
#  'black pepper powder': 10,
#  'cumin powder': 17,
#  'dry ginger powdernoodles wheat flour': 1,
#  'palm oil': 13,
#  'wheat gluten': 11,
#  'mineral calcium carbonate': 12,
#  'guar gum': 10,
#  'sodium tripolyphosphate': 8,
#  'potassium carbonate': 10,
#  'sodium carbonate masala tastemaker hydrolysed groundnut peanut protein': 1,
#  'mixed spices  dehydrated onion': 1,
#  'coriander powder': 13,
#  'red chilli powder ': 7,
#  'turmeric powder': 14,
#  'ginger powder': 6,
#  'aniseed': 2,
#  'fenugreek powder': 6,
#  'garlic powder': 11,
#  'clove powder': 6,
#  'noodle powder wheat flour': 3,
#  'sodium triphosphate': 1,
#  'sodium carbonate': 9,
#  'sugar': 35,
#  'edible starch': 5,
#  'acidifying agent citric acid': 4,
#  'colour plain caramel': 2,
#  'mineral ferric pyrophosphate': 2,
#  'flavour enhancer monosodium glutamate': 1,
#  'wheat protein': 1,
#  'raising agent sodium bicarbonatewheat flour': 1,
#  'vegetable oil': 2,
#  'tutti frutti ': 1,
#  'raisins ': 1,
#  'liquid glucose': 2,
#  'butter': 4,
#  'dextrose monohydrate': 2,
#  'glycerine': 1,
#  'skimmed milk powder': 2,
#  'wheat bran': 1,
#  'starch': 2,
#  ' i': 2,
#  'leavening agents  i': 1,
#  ' ii': 1,
#  'acidity regulators ': 1,
#  'preservatives ': 1,
#  'spices  condiments clove': 1,
#  'cinnamoncoriander': 2,
#  'cumin': 12,
#  'turmeric': 10,
#  'black pepper': 9,
#  'cloves': 6,
#  'nutmeg': 8,
#  'dry ginger': 3,
#  'cassia': 4,
#  'cardamom seeds': 2,
#  'red chillies': 1,
#  'fennel': 3,
#  'bay leaf': 2,
#  'mustard': 6,
#  'garlic flakes': 1,
#  'onion flakes': 1,
#  'mace masoor dal split red lentildehydrated vegetables tomato ': 1,
#  'onion': 7,
#  'iodized salt': 4,
#  'hydrolyzed vegetable protein': 2,
#  'spices and condiments cumin powder': 2,
#  'flavour enhancers disodium guanylate': 1,
#  'disodium inosinate': 1,
#  'thickener xanthan gum': 2,
#  'antioxidant epotato ': 1,
#  'chickpea flour ': 1,
#  'mango powder': 6,
#  'black saltwheat flour': 1,
#  'refined palm oil': 5,
#  'invert syrup': 12,
#  'leavening ammonium bicarbonate e  ii': 1,
#  'sodium bicarbonate e ii': 1,
#  'skim milk powder': 1,
#  'soya lecithin e ': 1,
#  'artificial vanilla flavor': 1,
#  'sodium metabisulphite e  as preservativesugar': 1,
#  'acidity regulator ': 8,
#  'contains permitted synthetic food colour  and added orange flavours natural and nature identical flavouring substancesatta noodles  wheat flour': 1,
#  'edible veg oil': 1,
#  'spice mix  mixed spices red chilli powder ': 1,
#  'dry ginger powder': 2,
#  'aniseed powder': 3,
#  'nutmeg powder': 5,
#  'cardamom powder ': 3,
#  'cinnamon powder ': 1,
#  'mustard powder': 2,
#  'curry leaf powder': 1,
#  'mace powder': 2,
#  'dehydrated onion': 1,
#  'hydrolysed groundnut protein': 2,
#  'tomato powder': 1,
#  'flavour enhancers disodium ribonucleotidesugar': 1,
#  'wheat flour': 8,
#  'leavening agents ii': 2,
#  'ii': 9,
#  'milk solids': 16,
#  'emulsifiers i': 7,
#  'permitted flavorcoriander': 1,
#  'red chilli': 7,
#  'dry mango powder': 2,
#  'fenugreek leaves': 4,
#  'pomegranate seeds': 3,
#  'caraway': 2,
#  'green cardamom': 1,
#  'mace': 2,
#  'cinnamon': 5,
#  'bay leaves': 2,
#  'asafoetidagram flour ': 1,
#  'tapioca starch': 2,
#  'black salt': 4,
#  'acidity regulator e noodles wheat flour': 1,
#  'seasoning mix dehydrated vegetables tomato': 1,
#  'garlic': 8,
#  'corn starch': 7,
#  'flavour enhancer ': 3,
#  'thickener ': 4,
#  'antioxidant cheese ': 1,
#  'water': 4,
#  'emulsifiers e ': 1,
#  'e ': 2,
#  'common salt': 3,
#  'acidity regulator e ': 1,
#  'preservative e water': 1,
#  'tomato paste ': 2,
#  'chilli puree ': 1,
#  'vinegar': 2,
#  'ginger powderwheat flour': 1,
#  'saltwater': 1,
#  'tomato': 4,
#  'potato': 1,
#  'green peas': 3,
#  'refined sunflower oil': 2,
#  'coriander leaves': 3,
#  'ginger': 7,
#  'green chilli': 3,
#  'cardamom': 3,
#  'black peppernoodles wheat flour': 1,
#  'seasoning mix salt': 1,
#  'edible vegetable fat': 2,
#  'flavour enhancers ': 1,
#  'hydrolysed vegetable protein': 1,
#  'spices onion powder ': 1,
#  'garlic powder ': 2,
#  'ginger powder ': 1,
#  'chilli powder': 1,
#  'onion flakes ': 1,
#  'garlic flakes ': 1,
#  'edible vegetable oilwhole wheat flourpotato ': 1,
#  'chickpeas flour ': 1,
#  'dried ginger powder': 1,
#  'cardamom powder': 5,
#  'cinnamon powdermalt extract': 1,
#  'caramel ins c': 1,
#  'vitamins': 2,
#  'minerals': 2,
#  'emulsifier ins ': 1,
#  'saltmango slices ': 1,
#  'spices  condiments chilli powder': 1,
#  'asafoetida': 2,
#  'acidity regulator ins noodles wheat flour': 1,
#  'masala tastemaker hydrolysed groundnut protein': 1,
#  'mixed spices coriander powder': 1,
#  'edible vegetable oilwheat flour': 1,
#  'raising agents ii': 6,
#  'permitted flavorextract of coconut': 1,
#  'waterwhole wheat flournoodles wheat flour': 1,
#  'tastemaker hydrolysed groundnut protein': 1,
#  'mixed spices onion powder': 1,
#  'green cardamom powder': 1,
#  'corn flour': 1,
#  'edible vegetable oilmilk fatedible vegetable oil': 1,
#  'bengal gram flour': 1,
#  'split green gram flour': 1,
#  'edible common salt': 3,
#  'clove': 3,
#  'bay leaftea': 1,
#  'natural flavourmilk solids': 1,
#  'sugarcorn flour': 1,
#  'dried sweet corn ': 1,
#  'maltodextrin': 1,
#  'yeast extract': 3,
#  'onion powder ': 1,
#  'spices  white pepper powder': 1,
#  'natural flavourings': 1,
#  'acidity regulator ins ': 1,
#  'soy sauce powder': 2,
#  'caramel powder ins d': 1,
#  'natural colour ins wheat flour': 1,
#  'dough conditioner ginger ': 1,
#  'garlic ': 2,
#  'acidity regulator ins wheat flour': 1,
#  'cashew ': 1,
#  'permitted flavorspotato ': 1,
#  'gram flour': 2,
#  'nutmeg powdercoriander': 1,
#  'fenugreek': 2,
#  'pepper': 3,
#  'bengal gram dal': 2,
#  'urad dal': 1,
#  'curry leaves': 2,
#  'asafoetidawheat flour ': 1,
#  'leavening ii': 3,
#  'sodium metabisulphite wheat flour ': 1,
#  'guar gumnoodles  wheat flour': 1,
#  'chicken ': 1,
#  'flavors contains milk and soya': 1,
#  'onion powder': 3,
#  'spices turmeric': 1,
#  'chicken fat ': 1,
#  'acidity regulator citric acid': 2,
#  'leekmilk solids': 1,
#  'cheese solids milk': 1,
#  'cheese cultures': 1,
#  'enzymes': 1,
#  'emulsifiers e': 1,
#  'e': 3,
#  'permitted stabilizing and preservative agents e': 1,
#  'ewheat flour ': 1,
#  'i': 1,
#  'dough conditioner ': 4,
#  'vitamins and minerals niacin': 1,
#  'thiamin': 1,
#  'riboflavin': 1,
#  'folic acid': 1,
#  'ironcoriander': 1,
#  'chilli': 6,
#  'anistarcoriander': 1,
#  'dry mango': 2,
#  'mint': 1,
#  'ajwain': 1,
#  'bay leavesoats ': 1,
#  'vegetables  carrot': 2,
#  'french beans': 1,
#  'spices and condiments  garlic': 1,
#  'mustard seeds': 3,
#  'cumin seeds': 1,
#  'raisinsdehydrated onion ': 1,
#  'iodised salt': 1,
#  'spices  cumin': 1,
#  'coriander': 2,
#  'edible vegetable oil palm oil': 2,
#  'flavour enhancer monosodium glutamaterefined wheat flour': 1,
#  'edible vegetable oil palm': 1,
#  'chocolate chips  sugar': 1,
#  'emulsifier soy lecithin': 1,
#  'artificial flavour': 1,
#  'emulsifiers  i': 1,
#  'artificial flavouring substances vanilla and butterred chilli powder ': 1,
#  'edible vegetable oil ': 1,
#  'acidity regulator e': 2,
#  'moisture content ': 1,
#  'stabilizer e': 1,
#  'anticaking agent e': 1,
#  'emulsifying and stabilizing agents e': 1,
#  'contains permitted class ii preservatives e': 1,
#  'egram flour besan ': 1,
#  'clarified butter ghee ': 1,
#  'wheat flour ': 1,
#  'almonds ': 1,
#  'pistachio ': 1,
#  'cardamom ': 1,
#  'silver leaves toor dal split pigeon peasoats ': 1,
#  'dehydrated vegetables tomato ': 1,
#  'spices and condiments  coriander powder': 1,
#  'raisins': 1,
#  'antioxidant ewater': 1,
#  'whole black gram ': 1,
#  'red kidney beans ': 1,
#  'tomato paste': 1,
#  'green chillies': 1,
#  'bay leavesvermicelli wheat semolina': 1,
#  'edible vegetable fat palm oil': 1,
#  'cashew nut': 1,
#  'raisin': 1,
#  'saffronwater': 1,
#  'red chilli paste ': 2,
#  'acidity regulator acetic acid': 1,
#  'modified corn starch': 1,
#  'preservative sodium benzoaterice flakes ': 1,
#  'gram flour ': 1,
#  'split bengal gram ': 2,
#  'corn flakes ': 1,
#  'peanuts ': 1,
#  'green peas oats ': 1,
#  'peas': 1,
#  'beans': 1,
#  'spices  condiments onion powder': 1,
#  'malic acidwheat flour': 1,
#  'ammonium bicarbonate': 1,
#  'yeastwheat flour': 1,
#  'permitted flavorssemolina ': 1,
#  'black gram dal': 1,
#  'raising agents eii': 1,
#  'eii': 1,
#  'gingerpotato ': 1,
#  'chickpea flour': 1,
#  'cinnamon powder': 1,
#  'nutmeg powdertomato puree ': 1,
#  'preservative ': 2,
#  'clove powderextracted from fresh coconutsurad flour ': 1,
#  'edible common saltcoriander': 1,
#  'cardamom seedsvermicelli wheat semolina ': 1,
#  'saltsugar': 1,
#  'tomato powder ': 1,
#  'dehydrated vegetables onion': 2,
#  'tomato ': 1,
#  'flavors': 1,
#  'acidifying agent ': 1,
#  'soy sauce powderwheat flour': 1,
#  'permitted emulsifiers i': 1,
#  'artificial flavorsnoodles wheat flour': 1,
#  'acidity regulator citric acid masala tastemaker hydrolysed peanut protein': 1,
#  'mixed spices coriander': 1,
#  'noodle powder': 1,
#  'citric acid': 1,
#  'potassium chloride': 1,
#  'sodium bicarbonatesugar': 1,
#  'pistachio': 1,
#  'almondvacuum evaporated iodized salt whole wheat flour amla juice emblica officinalis ': 1,
#  'permitted class ii preservative echickpeas ': 1,
#  'refined vegetable oil': 1,
#  'red lentils ': 1,
#  'spices  condiments  onion powder': 1,
#  'fennel seeds': 2,
#  'citric acidblack salt': 1,
#  'mint leaves': 1,
#  'asafoetidacoriander': 1,
#  'brown cardamom': 1,
#  'cloveswheat flour': 1,
#  'artificial flavorsmixed fruit pulp  banana': 1,
#  'papaya': 1,
#  'apple': 1,
#  'pear': 1,
#  'pineapple': 1,
#  'mango': 1,
#  'mixed spiceschickpeas': 1,
#  'asafoetidagram flour': 1,
#  'mace powdersoluble coffee powder ': 1,
#  'chicory powder sugar': 1,
#  'hydrogenated vegetable fat': 1,
#  'rice crispies rice flour': 1,
#  'malt extract': 1,
#  'edible glittermilk fat ': 1,
#  'moisturehoney sugar': 1,
#  'malt extract ': 1,
#  'caramel c': 1,
#  'raising agent ii': 1,
#  'saltnoodles wheat flour': 1,
#  'guar gum curry flavour mix salt': 1,
#  'spices coriander': 1,
#  'tartaric acid': 1}

# %%
## sort dictionary by value
sorted_dict = sorted(dictionary.items(), key=lambda x: x[1], reverse=True)

# %%
sorted_dict
# Out:
# [('glycerin', 31),
#  ('phenoxyethanol', 22),
#  ('sodium benzoate', 17),
#  ('propylparaben', 17),
#  ('fragrance', 16),
#  ('methylparaben', 16),
#  ('vitamin e', 14),
#  ('potassium sorbate', 13),
#  ('citric acid', 11),
#  ('sandalwood oil', 11),
#  ('decyl glucoside', 10),
#  ('triethanolamine', 10),
#  ('disodium edta', 10),
#  ('turmeric', 10),
#  ('cocamidopropyl betaine', 9),
#  ('sodium cocoyl glutamate', 9),
#  ('tocopheryl acetate', 9),
#  ('sodium hydroxide', 9),
#  ('cetyl alcohol', 9),
#  ('xanthan gum', 9),
#  ('water', 8),
#  ('ci ', 8),
#  ('carbomer', 8),
#  ('titanium dioxide', 8),
#  ('allantoin', 8),
#  ('ammonium lauryl sulfate', 7),
#  ('stearic acid', 7),
#  ('cyclopentasiloxane', 7),
#  ('kokum butter', 7),
#  ('zinc oxide', 7),
#  ('sodium pca', 7),
#  ('dimethicone', 7),
#  ('methyl paraben', 6),
#  ('cl ', 6),
#  ('sesame oil', 6),
#  ('propylene glycol', 6),
#  ('glyceryl stearate', 6),
#  ('isopropyl myristate', 6),
#  ('aloe vera', 6),
#  ('honey', 6),
#  ('glycol distearate', 5),
#  ('sodium chloride', 5),
#  ('beeswax', 5),
#  ('sodium lauroyl sarcosinate', 4),
#  ('azadirachta indica neem leaf extract', 4),
#  ('phenylbenzimidazole sulfonic acid', 4),
#  ('acrylatesc alkyl acrylate crosspolymer', 4),
#  ('polysorbate ', 4),
#  ('propyl paraben', 4),
#  ('tocopherol', 4),
#  ('kaolin', 4),
#  ('sandalwood powder', 4),
#  ('aloe vera juice', 4),
#  ('polyquaternium', 4),
#  ('lauryl glucoside', 4),
#  ('rose oil', 4),
#  ('perfume', 4),
#  ('almond oil', 4),
#  ('ethylhexyl methoxycinnamate', 4),
#  ('sorbitol', 3),
#  ('octyl methoxy cinnamate', 3),
#  ('bhringraj extract', 3),
#  ('aqua', 3),
#  ('talc', 3),
#  ('linalool', 3),
#  ('sweet almond oil', 3),
#  ('sodium lauryl sulphate', 3),
#  ('niacinamide', 3),
#  ('bht', 3),
#  ('methylchloroisothiazolinone', 3),
#  ('capryliccapric triglyceride', 3),
#  ('almond powder', 3),
#  ('cetearyl alcohol', 3),
#  ('lodhra', 3),
#  ('neem', 3),
#  ('trimethylsiloxysilicate', 3),
#  ('benzophenone', 3),
#  ('vetiver', 3),
#  ('lotus', 3),
#  ('indian madder', 3),
#  ('manjistha', 3),
#  ('borax', 3),
#  ('base material qs', 3),
#  ('aloe vera extract', 3),
#  ('hibiscus extract', 3),
#  ('caprylyl glycol', 3),
#  ('cyclohexasiloxane', 3),
#  ('mulethi', 3),
#  ('butyl methoxydibenzoylmethane', 3),
#  ('peg distearate', 2),
#  ('sodium lauryl glucose carboxylate and lauryl glucoside', 2),
#  ('reetha extract', 2),
#  ('madhu honey', 2),
#  ('vanilla extract', 2),
#  ('butylene glycol', 2),
#  ('acrylatesdimethicone copolymer', 2),
#  ('ethylparaben', 2),
#  ('sodium hyaluronate', 2),
#  ('butylphenyl methylpropional', 2),
#  ('citronellol', 2),
#  ('hexyl cinnamal', 2),
#  ('limonene', 2),
#  ('walnut shell powder', 2),
#  ('apricot kernel oil', 2),
#  ('saffron flower extract', 2),
#  ('carrot seed oil', 2),
#  ('clove oil', 2),
#  ('sodium lauryl ether sulphate', 2),
#  ('ethylhexylglycerin', 2),
#  ('sunflower oil', 2),
#  ('madhu', 2),
#  ('isohexadecane', 2),
#  ('benzyl alcohol', 2),
#  ('kaolin powder', 2),
#  ('glycerine', 2),
#  ('olive oil', 2),
#  ('bentonite powder', 2),
#  ('fragrancealoe vera', 2),
#  ('sandalwood', 2),
#  ('anantmool', 2),
#  ('durva', 2),
#  ('tulsi', 2),
#  ('sugandhit dravya', 2),
#  ('polyethylene', 2),
#  ('mica', 2),
#  ('disteardimonium hectorite', 2),
#  ('propylene carbonate', 2),
#  ('tin oxide', 2),
#  ('turmeric powder', 2),
#  ('fenugreek powder', 2),
#  ('saffron extract', 2),
#  ('methylisothiazolinone', 2),
#  ('licorice', 2),
#  ('orange peel', 2),
#  ('sodium laureth sulfate', 2),
#  ('cocobetaine', 2),
#  ('guar hydroxypropyltrimonium chloride', 2),
#  ('salicylic acid', 2),
#  ('glyceryl oleate', 2),
#  ('centella', 2),
#  ('sea algae', 2),
#  ('silica', 2),
#  ('polybutene', 2),
#  ('ci iron oxides', 2),
#  ('sodium lactate', 2),
#  ('soy protein', 2),
#  ('coco glucoside', 2),
#  ('vetiver oil', 2),
#  ('lavender oil', 2),
#  ('fenugreek extract', 2),
#  ('brahmi extract', 2),
#  ('almond extract', 2),
#  ('orange peel extract', 2),
#  ('neem extract', 2),
#  ('turmeric extract', 2),
#  ('wheat protein', 2),
#  ('vegetable glycerin', 2),
#  ('saffron', 2),
#  ('licorice extract', 2),
#  ('permitted colour', 2),
#  ('rose water', 2),
#  ('sodium levulinate', 2),
#  ('rosemary oil', 2),
#  ('kashmiri saffron', 2),
#  ('castor oil', 2),
#  ('manjishtha', 2),
#  ('tea tree oil', 2),
#  ('sodium lauryl sulfate', 2),
#  ('ghee', 2),
#  ('arbutin', 2),
#  ('peg stearate', 2),
#  ('sodium ascorbyl phosphate', 2),
#  ('polysorbate', 2),
#  ('emulsifying wax', 2),
#  ('vitamin e acetate', 2),
#  ('ci', 2),
#  ('sodium laureth sulphate', 2),
#  ('fragrancewater', 2),
#  ('dimethicone crosspolymer', 2),
#  ('ashwagandha', 2),
#  ('shea butter', 2),
#  ('bees wax', 2),
#  ('mulberry extract', 2),
#  ('cyclomethicone', 2),
#  ('saxifraga extract', 2),
#  ('grape extract', 2),
#  ('liquorice', 2),
#  ('camphor', 2),
#  ('red sandalwood', 2),
#  ('melia azadirachta neem leaf extract', 1),
#  ('sodium citrate', 1),
#  ('butylene glycol and boswellia serrata gum', 1),
#  ('ci turmeric extract', 1),
#  ('propyl parabencoconut oil', 1),
#  ('dugdh lactus', 1),
#  ('manjistha rubia cordifolia', 1),
#  ('nimba kamla citrus limonum', 1),
#  ('badam tail prunus amygdalus oil', 1),
#  ('cream base qswater', 1),
#  ('oxybenzone', 1),
#  ('vitamin emethi seed extract', 1),
#  ('nagarmotha extract', 1),
#  ('amla extract', 1),
#  ('kikar gond acacia arabica extract', 1),
#  ('purified water qscyclomethicone', 1),
#  ('isotridecyl isononanoate', 1),
#  ('cetyl pegppg dimethicone', 1),
#  ('hditrimethylol hexyllactone crosspolymer', 1),
#  ('phenyl trimethicone', 1),
#  ('parfum', 1),
#  ('alphaisomethyl ionone may contain cl ', 1),
#  ('cl aloe vera', 1),
#  ('base materialaqua', 1),
#  ('avocado butter', 1),
#  ('kumkumadi oil', 1),
#  ('grapefruit seed extract', 1),
#  ('essential oils of rose', 1),
#  ('jasmine', 1),
#  ('and lotus natural steam distilled pure rosewatersandalwood oil', 1),
#  ('chamomile extract', 1),
#  ('aloe vera gel', 1),
#  ('wheat germ oil', 1),
#  ('avobenzone', 1),
#  ('octylmethoxy cinnamate', 1),
#  ('micronized titanium dioxide', 1),
#  ('fragrancecalcium carbonate', 1),
#  ('flavour', 1),
#  ('indian licorice root extract', 1),
#  ('gum tragacanth', 1),
#  ('carrageenan', 1),
#  ('eucalyptus oil', 1),
#  ('sodium saccharin', 1),
#  ('propyl parabenwater', 1),
#  ('acrylates copolymer', 1),
#  ('cocoglucoside and glyceryl oleate', 1),
#  ('glycolic acid', 1),
#  ('camellia sinensis green tea leaf extract', 1),
#  ('morus alba mulberry root extract', 1),
#  ('methylisothiazolinonewater', 1),
#  ('polyglyceryl methylglucose distearate', 1),
#  ('simmondsia chinensis jojoba seed oil', 1),
#  ('triticum vulgare wheat germ oil', 1),
#  ('prunus amygdalus dulcis sweet almond oil', 1),
#  ('butyrospermum parkii shea butter', 1),
#  ('hedychium spicatum spiked ginger lily extract', 1),
#  ('citrus medica limonum lemon peel extract', 1),
#  ('malus domestica apple fruit extract', 1),
#  ('vitis vinifera grape seed extract', 1),
#  ('aloe barbadensis barbados aloe leaf juice', 1),
#  ('fragrancemultani mitti', 1),
#  ('calamine', 1),
#  ('fullers earth', 1),
#  ('peg', 1),
#  ('sodium methyl parabenchickpea flour', 1),
#  ('neem leaf powder', 1),
#  ('turmeric root powder', 1),
#  ('mulethi root powder', 1),
#  ('essential oils of sandalwood', 1),
#  ('orange', 1),
#  ('and nagkesarwheat germ oil', 1),
#  ('methi seed extract', 1),
#  ('kulanjan rhizome extract', 1),
#  ('ankurit gehun seed extract', 1),
#  ('purified water', 1),
#  ('cream base', 1),
#  ('qswater', 1),
#  ('paraffinum liquidum', 1),
#  ('glyceryl stearate citrate', 1),
#  ('prunus amygdalus dulcis oil', 1),
#  ('sodium carbomer', 1),
#  ('sodium acrylatesc alkyl acrylate crosspolymer', 1),
#  ('alphaisomethyl ionone', 1),
#  ('geraniol', 1),
#  ('parfumpapaya seed scrub  papaya seed powder', 1),
#  ('solum fullonum fullers earth', 1),
#  ('sodium methylparaben', 1),
#  ('fragrance cucumber gel  cucumber extract', 1),
#  ('cellulose gum', 1),
#  ('fragrance peach massage cream  wheat germ oil', 1),
#  ('fragrance orange antitan pack  orange peel powder', 1),
#  ('manjishta', 1),
#  ('ghritkumari', 1),
#  ('kesar', 1),
#  ('akarkara', 1),
#  ('ghritkumari b', 1),
#  ('daruhaldi', 1),
#  ('pudina ka phool', 1),
#  ('aquacyclopentasiloxane', 1),
#  ('lauroyl lysine', 1),
#  ('ozokerite', 1),
#  ('octyldodecanol', 1),
#  ('calcium aluminum borosilicate', 1),
#  ('may contain cl ', 1),
#  ('cl water', 1),
#  ('butyl methoxy dibenzoyl methane', 1),
#  ('polyacrylamide c isoparaffin', 1),
#  ('laureth', 1),
#  ('perfumefullers earth multani mitti', 1),
#  ('calamine powder', 1),
#  ('neem powder', 1),
#  ('fennel powder', 1),
#  ('star anise powder', 1),
#  ('orange peel powderwater', 1),
#  ('disodium cocamphodiacetate', 1),
#  ('extracts of neem and turmeric', 1),
#  ('ci saffron', 1),
#  ('bael', 1),
#  ('base qsaquawater', 1),
#  ('cocamide mipa', 1),
#  ('hydroxypropyltrimonium hydrolyzed wheat protein', 1),
#  ('ppgceteth', 1),
#  ('arginine', 1),
#  ('benzyl salicylate', 1),
#  ('oleamido,octadecanediol', 1),
#  ('serine', 1),
#  ('glutamic acid', 1),
#  ('glyceryl linoleate', 1),
#  ('glyceryl linolenate', 1),
#  ('parfumfragranceturmeric', 1),
#  ('perfumegreen apple', 1),
#  ('bhringraj', 1),
#  ('himalayan water', 1),
#  ('sles derived', 1),
#  ('neutral thickener', 1),
#  ('polyquaterium ', 1),
#  ('natural preservative blendfullers earth', 1),
#  ('multani mitti', 1),
#  ('bentone gel', 1),
#  ('gum acacia', 1),
#  ('methylparaben sodium', 1),
#  ('propylparaben sodium', 1),
#  ('perfumealoe vera', 1),
#  ('preservativesisododecane', 1),
#  ('synthetic wax', 1),
#  ('hydrogenated polydicyclopentadiene', 1),
#  ('ethylenepropylene copolymer', 1),
#  ('bisdiglyceryl polyacyladipate', 1),
#  ('hydrogenated styrenemethyl styreneindene copolymer', 1),
#  ('pentaerythrityl tetraditbutyl hydroxyhydrocinnamate', 1),
#  ('cococaprylatecaprate', 1),
#  (' ci  nanoblack ', 1),
#  ('ci ultramarines', 1),
#  ('ci iron oxideskiehls clearly corrective dark spot solutionpurified water',
#   1),
#  ('cocoamidopropyl betain', 1),
#  ('pca glyceryl oleate', 1),
#  ('hydrolyzed wheat protein', 1),
#  ('patchouli oil', 1),
#  ('geranium oil', 1),
#  ('shikakai extract', 1),
#  ('lemon extract', 1),
#  ('essential oils of lavender', 1),
#  ('patchouli', 1),
#  ('geranium and rose certified organic ingredientpurified water', 1),
#  ('nettle extract', 1),
#  ('cinnamon extract', 1),
#  ('bay leaf extract', 1),
#  ('hydroxypropyltrimonium honey', 1),
#  ('silk amino acids', 1),
#  ('inositol', 1),
#  ('essential oils of orange', 1),
#  ('lemongrass and lavenderpurified water', 1),
#  ('cucumber', 1),
#  ('peppermint oil', 1),
#  ('citric acidmadhu honey', 1),
#  ('ghrit kumari aloe vera barbadensis', 1),
#  ('rosa rose ', 1),
#  ('purified water qswater', 1),
#  ('octyl methoxycinnamate', 1),
#  ('aluminum hydroxide', 1),
#  ('fragrancepurified water', 1),
#  ('cocoamidopropyl betaine', 1),
#  ('potassium sorbatemultani mitti', 1),
#  ('geru red clay', 1),
#  ('yasad bhasm yasad bhasma', 1),
#  ('tomato lycopersicum esculentum', 1),
#  ('pineapple ananas comosus', 1),
#  ('papaya carica papaya', 1),
#  ('apple malus domestica', 1),
#  ('cucumber cucumis sativus', 1),
#  ('fullers earth solum multani', 1),
#  ('qsaloe vera', 1),
#  ('extracts of kesar and chandan', 1),
#  ('base material qswater', 1),
#  ('melia azadirachta leaf extract', 1),
#  ('sodium lauryl glucose carboxylate', 1),
#  ('tocopheryl acetateaqua', 1),
#  ('cocoglucoside', 1),
#  ('sodium anisate', 1),
#  ('fragrancecapryliccapric triglyceride', 1),
#  ('onion seed oil', 1),
#  ('organic sunflower oil', 1),
#  ('organic amla oil', 1),
#  ('organic hibiscus oil', 1),
#  ('sodium benzoatesaffron', 1),
#  ('lotus oil', 1),
#  ('padmakashtha', 1),
#  ('anantmoolturmeric extract', 1),
#  ('scented perfumeaqua', 1),
#  ('china clay', 1),
#  ('activated charcoal powder', 1),
#  ('calendula extract', 1),
#  ('camphor oil', 1),
#  ('vitamin e oilaqua', 1),
#  ('sodium metabisulfiteextracts of haldi', 1),
#  ('chandan', 1),
#  ('soap base qsdesi cows milk', 1),
#  ('raw honey', 1),
#  ('anantmool root extract', 1),
#  ('aloe vera leaf extract', 1),
#  ('nagkesar flower extract', 1),
#  ('mulethi root extract', 1),
#  ('potassium sorbatewater', 1),
#  ('light liquid paraffin', 1),
#  ('hydrogenated polyisobutene', 1),
#  ('behenyl alcohol', 1),
#  ('disodium edtaghrit kumari aloe vera barbadensis', 1),
#  ('methi trigonella foenumgraecum', 1),
#  ('ankurit gehun triticum vulgare', 1),
#  ('kusumbhi carthamus tinctorius', 1),
#  ('vach acorus calamus', 1),
#  ('lotion base qswater', 1),
#  ('mineral oil', 1),
#  ('sodium lauryl ether sulfate', 1),
#  ('milkpurified water', 1),
#  ('carbopol', 1),
#  ('pudina', 1),
#  ('gel base', 1),
#  ('diazolidinyl urea  iodopropynyl butylcarbamate', 1),
#  ('vitamin a', 1),
#  ('sugandhit dravyaqsamla', 1),
#  ('shikakai', 1),
#  ('reetha', 1),
#  ('cocamide dea', 1),
#  ('sodium acrylatesodium acryloyldimethyl taurate copolymer', 1),
#  ('peg trimethylolpropane coconut ether', 1),
#  ('aluminium hydroxide', 1),
#  ('curcuma longa turmeric root extract', 1),
#  ('citric acidgreen apple', 1),
#  ('himalayan water qsaqua', 1),
#  ('nagkesar', 1),
#  ('yashtimadhu', 1),
#  ('cows milk', 1),
#  (' karat gold bhasma', 1),
#  ('cinnamon oil', 1),
#  ('mogra oil', 1),
#  ('jasmine oil', 1),
#  ('spf rosa damascena flower wateraqua', 1),
#  ('cocoamide mipa', 1),
#  ('hexylene glycol', 1),
#  ('argania spinosa kernel oil', 1),
#  ('fragrancealoe vera ', 1),
#  ('preservatives sorbic acid  ', 1),
#  ('diazolidinyl urea  turmeric', 1),
#  ('waterwater', 1),
#  ('octocrylene', 1),
#  ('potassium cetyl phosphate', 1),
#  ('epilobium angustifolium extract', 1),
#  ('cyclohexasiloxanemineral oil', 1),
#  ('vegetable oil', 1),
#  ('amla extract emblica officinalis', 1),
#  ('antioxidant tertbutylhydroquinone tbhqfullers earth', 1),
#  ('chickpea flour', 1),
#  ('cucumber extract', 1),
#  ('papaya extract', 1),
#  ('saffron oil', 1),
#  ('preservatives phenoxyethanol and sodium benzoatewater', 1),
#  ('caprylyl methicone', 1),
#  ('trehalose', 1),
#  ('morus alba root extract', 1),
#  ('scutellaria baicalensis root extract', 1),
#  ('glutathione', 1),
#  ('phenyl ethyl resorcinol', 1),
#  ('butylparaben', 1),
#  ('isobutylparaben', 1),
#  ('sodium hydroxidewater', 1),
#  ('juglans regia walnut shell granules', 1),
#  ('glyceryl stearate se', 1),
#  ('sodium hydroxidepurified water', 1),
#  ('coconut oil', 1),
#  ('cocoa butter', 1),
#  ('jasmine extract', 1),
#  ('mogra extract', 1),
#  ('essential oil of jasminesesame oil', 1),
#  ('milk', 1),
#  ('indigo', 1),
#  ('eclipta alba', 1),
#  ('gooseberry', 1),
#  ('balloon vine', 1),
#  ('madder root', 1),
#  ('fenugreek', 1),
#  ('rosemary', 1),
#  ('himalayan cedarwood', 1),
#  ('henna', 1),
#  ('essential oil of vetiver', 1),
#  ('essential oil of geraniumcastor oil', 1),
#  ('amla', 1),
#  ('triphala', 1),
#  ('ghrit kumari', 1),
#  ('damask rose', 1),
#  ('cows gheewater', 1),
#  ('peg dimethicone', 1),
#  ('methylene bisbenzotriazolyl tetramethylbutylphenol', 1),
#  ('isododecane', 1),
#  ('bisethylhexyloxyphenol methoxyphenyl triazine', 1),
#  ('bhtneem bark', 1),
#  ('chamomile', 1),
#  ('haldi', 1),
#  ('gulab phool', 1),
#  ('ritha', 1),
#  ('kulanjan', 1),
#  ('coconut oil derivatives', 1),
#  ('purified himalayan water qsaloe vera  ', 1),
#  ('preservatives qswater', 1),
#  ('aloe vera leaf juice', 1),
#  ('walnuts', 1),
#  ('geranium oilmultani mitti', 1),
#  ('geru', 1),
#  ('yasad bhasm', 1),
#  ('tamator', 1),
#  ('ananas', 1),
#  ('seb', 1),
#  ('beheda', 1),
#  ('badam', 1),
#  ('jaiphal', 1),
#  ('kikar gaund', 1),
#  ('paste base qssaffron', 1),
#  ('banyan', 1),
#  ('indian barberry', 1),
#  ('flame of the forest', 1),
#  ('rose', 1),
#  ('padma kesar', 1),
#  ('and sesame oilneem', 1),
#  ('sodium lauryl sarcosinate', 1),
#  ('and ci turmeric extract', 1),
#  ('sodi biboras', 1),
#  ('and cream baseonion seed oil', 1),
#  ('amla oil', 1),
#  ('hibiscus oil', 1),
#  ('bhringraj oil', 1),
#  ('jojoba oil', 1),
#  ('and fragranceisododecane', 1),
#  ('petrolatum', 1),
#  ('cera alba', 1),
#  ('silica dimethyl silylate', 1),
#  ('synthetic fluorphlogopite', 1),
#  ('glyceryl behenateeicosadioate', 1),
#  ('persea gratissima oil', 1),
#  ('and  ci ', 1),
#  ('ci chickpea flour', 1),
#  ('lodhra powder', 1),
#  ('orange peel powder', 1),
#  ('rose petal powder', 1),
#  ('indian madder powder', 1),
#  ('licorice root powder', 1),
#  ('and saffrongreen apple', 1),
#  ('sea algae extract', 1),
#  ('centella asiatica extract', 1),
#  ('eclipta prostrata extract', 1),
#  ('soap nut extract', 1),
#  ('musk root extract', 1),
#  ('grape seed oil', 1),
#  ('and pure himalayan waterwater', 1),
#  ('sodium polyacrylate starch', 1),
#  ('alumina', 1),
#  ('milk enzymes', 1),
#  ('and titanium dioxidesaffron', 1),
#  ('kumkumadi tailam', 1),
#  ('and kumariaqua', 1),
#  ('caprylylcapryl glucoside', 1),
#  ('sodium lauroyl glutamate', 1),
#  ('xylitylglucoside', 1),
#  ('anhydroxylitol', 1),
#  ('xylitol', 1),
#  ('sodium gluconate', 1),
#  ('betaine', 1),
#  ('rosa damascena flower oil', 1),
#  ('and jasminum grandiflorum flower extractwater', 1),
#  ('and curcuma longa turmeric root extractaloe vera juice', 1),
#  ('rosa centifolia rose flower extract', 1),
#  ('ocimum basilicum basil extract', 1),
#  ('santalum album sandalwood oil', 1),
#  ('and aquakokum butter', 1),
#  ('organic beeswax', 1),
#  ('organic honey', 1),
#  ('mulethi extract', 1),
#  ('fennel extract', 1),
#  ('lodhra extract', 1),
#  ('lemon peel extract', 1),
#  ('and turmeric oilpurified water', 1),
#  ('disodium cocoamphodiacetate', 1),
#  ('and lavender oilhoney', 1),
#  ('neem leaf extract', 1),
#  ('and rose extractrosa damascena flower distillatewater', 1),
#  ('and polysorbate surajmukhi oil', 1),
#  ('badam oil', 1),
#  ('arandi oil', 1),
#  ('neem oil', 1),
#  ('soy lecithin', 1),
#  ('and cleanser base qswater', 1),
#  ('glycyrrhiza glabra licorice root extract', 1),
#  ('punica granatum pomegranate fruit extract', 1),
#  ('morus nigra mulberry fruit extract', 1),
#  ('arctostaphylos uva ursi bearberry leaf extract', 1),
#  ('lactic acid', 1),
#  ('and methylparabenpurified water', 1),
#  ('cold pressed organic oils of coconut', 1),
#  ('almond', 1),
#  ('and wheat germ', 1),
#  ('and k gold bhasmawater', 1),
#  ('sodium lauryl sulfoacetate', 1),
#  ('and citric acidaloe vera aloe barbadensis gel', 1),
#  ('and permitted colorextracts of neem', 1),
#  ('long pepper', 1),
#  ('and tea tree oil', 1),
#  ('and cream base qs', 1)]

# %%
# create histogram
import matplotlib.pyplot as plt
import numpy as np

plt.bar(range(len(sorted_dict)), [val[1] for val in sorted_dict], align='center')
plt.xticks(range(len(sorted_dict)), [val[0] for val in sorted_dict], rotation='vertical')
plt.show()

# %%
# create a new dictionary with only the most common words
new_dict = {}
for i in range(0, 35):
    new_dict[sorted_dict[i][0]] = sorted_dict[i][1]

# %%
# create histogram
# import matplotlib.pyplot as plt
# import numpy as np

plt.bar(range(len(new_dict)), [val for val in new_dict.values()], align='center')
plt.xticks(range(len(new_dict)), [key for key in new_dict.keys()], rotation='vertical')
plt.show()
