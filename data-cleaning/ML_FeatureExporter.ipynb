# %% [markdown]
# ### Importing Data

# %%
dataFilePath = "dataset/sample2.md"

dataFile = open(dataFilePath)

# %% [markdown]
# ### Parameters

# %%
elementCount = 60

# %% [markdown]
# ## Converting Raw Data to Array

# %%
include_Product_Name_in_Dataset = 1

dictionary = {}

ingdList = []

buf = []
for line in dataFile.readlines():
    if(len(line) > 2):
        ## Check if new ingridient has started
        if (line[1] == "." or line[2] == "."): # or line[3] == "."):
            # store product name
            # words = line.split(' ')
            # words 


            # store ingridients from buf to list
            # ingdList.append(buf)
            # buf = []
            # if(len(buf) > 0):
            if(buf != []):
                ingdList.append(buf)
                buf = []
        else:
            spaceCount = line.count(' ')
            newLineCount = line.count('\n')

            # check if it has other character than space and new line
            if (spaceCount + newLineCount != len(line)):
              if(line[0] == '-' or line[0] == '.'):
                line = line[1:]
                while(line[0] == ' '):
                  line = line[1:]
                while(line[-1] == '\n'):
                  line = line[0:-1]
                buf.append(line)


print(ingdList)
# Out:
# [['Water, Ammonium Lauryl Sulfate, Cocamidopropyl Betaine, Sodium Cocoyl Glutamate, Glycerin, Sodium Lauroyl Sarcosinate, Glycol Distearate, Decyl Glucoside, PEG-150 Distearate, Sodium Lauryl Glucose Carboxylate (and) Lauryl Glucoside, Fragrance, Phenoxyethanol, Sodium Benzoate, Azadirachta Indica (Neem) Leaf Extract, Melia Azadirachta (Neem) Leaf Extract, Sodium Citrate, Citric Acid, Butylene Glycol (and) Boswellia Serrata Gum, Tocopheryl Acetate, CI 19140, CI 42090.'], ['Turmeric Extract, Sandalwood Oil, Water, Stearic Acid, Sorbitol, Sodium Hydroxide, Methyl Paraben, Propyl Paraben.'], ['Coconut Oil, Dugdh (Lactus), Manjistha (Rubia Cordifolia), Nimba Kamla (Citrus Limonum), Badam Tail (Prunus Amygdalus Oil), Cream Base Q.S.'], ['Water, Phenylbenzimidazole Sulfonic Acid, Oxybenzone, Octyl Methoxy Cinnamate, Cyclopentasiloxane, Acrylates/C10-30 Alkyl Acrylate Crosspolymer, Triethanolamine, Glycerin, Phenoxyethanol, Polysorbate 20, Methyl Paraben, Propyl Paraben, Fragrance, Carbomer, Disodium EDTA, Vitamin E.'], ['Methi Seed Extract, Bhringraj Extract, Nagarmotha Extract, Amla Extract, Reetha Extract, Madhu (Honey), Kikar Gond (Acacia Arabica Extract), Vanilla Extract, Purified Water Q.S.'], ['Cyclomethicone, Aqua, Butylene Glycol, Glycerin, Talc, Isotridecyl Isononanoate, Cetyl PEG/PPG-10/1 Dimethicone, HDI/Trimethylol Hexyllactone Crosspolymer, Phenyl Trimethicone, Sodium Chloride, Acrylates/Dimethicone Copolymer, Phenoxyethanol, Methylparaben, Ethylparaben, Propylparaben, Parfum, Tocopheryl Acetate, Disodium EDTA, Sodium Hyaluronate, Butylphenyl Methylpropional, Citronellol, Hexyl Cinnamal, Limonene, Linalool, Alpha-Isomethyl Ionone. May contain Cl 77491, Cl 77492, Cl 77499, Cl 77891.'], ['Aloe Vera, Base Material', 'Aqua, Vitamin E, Permitted Colour and Fragrance.'], ['Aqua, Glycerin, Walnut Shell Powder, Apricot Kernel Oil, Sweet Almond Oil, Kokum Butter, Sesame Oil, Beeswax, Avocado Butter, Kokum Butter, Kumkumadi Oil, Saffron Flower Extract, Vitamin E, Grapefruit Seed Extract, Potassium Sorbate, Essential Oils of Rose, Jasmine, and Lotus.'], ['100% Natural Steam Distilled Pure Rosewater.'], ['Sandalwood Oil, Chamomile Extract, Aloe Vera Gel, Wheat Germ Oil, Carrot Seed Oil, Zinc Oxide, Titanium Dioxide, Avobenzone, Octylmethoxy Cinnamate, Micronized Titanium Dioxide, Beeswax, Methyl Paraben, Propyl Paraben, Phenoxyethanol, Triethanolamine, Allantoin, Potassium Sorbate, Sodium Benzoate, Fragrance.'], ['Calcium Carbonate, Water, Sorbitol, Sodium Lauryl Sulphate, Flavour, Indian Licorice Root Extract, Gum Tragacanth, Carrageenan, Clove Oil, Eucalyptus Oil, Sodium Saccharin, Methyl Paraben, Propyl Paraben.'], ['Water, Sodium Lauryl Ether Sulphate, Glycerin, Sodium Lauryl Sulphate, Propylene Glycol, Cocamidopropyl Betaine, Decyl Glucoside, Acrylates Copolymer, Sodium Cocoyl Glutamate, Coco-Glucoside (and) Glyceryl Oleate, Walnut Shell Powder, Niacinamide, Glycolic Acid, Sodium Hydroxide, Tocopheryl Acetate, Allantoin, Sodium PCA, Camellia Sinensis (Green Tea) Leaf Extract, Morus Alba (Mulberry) Root Extract, BHT, Disodium EDTA, Fragrance, Methylchloroisothiazolinone, Methylisothiazolinone.'], ['Water, Caprylic/Capric Triglyceride, Glycerin, Polyglyceryl-3 Methylglucose Distearate, Glyceryl Stearate, Cetyl Alcohol, Isopropyl Myristate, Simmondsia Chinensis (Jojoba) Seed Oil, Triticum Vulgare (Wheat) Germ Oil, Prunus Amygdalus Dulcis (Sweet Almond) Oil, Butyrospermum Parkii (Shea Butter), Hedychium Spicatum (Spiked Ginger Lily) Extract, Citrus Medica Limonum (Lemon) Peel Extract, Malus Domestica (Apple) Fruit Extract, Vitis Vinifera (Grape Seed) Extract, Aloe Barbadensis (Barbados Aloe) Leaf Juice, Tocopherol, Xanthan Gum, Phenoxyethanol, Ethylhexylglycerin, Fragrance.'], ["Multani Mitti, Calamine, Kaolin, Aloe Vera, Fuller's Earth, Glycerin, PEG-400, Sodium Methyl Paraben."], ['Chickpea Flour, Almond Powder, Neem Leaf Powder, Turmeric Root Powder, Mulethi Root Powder, Sandalwood Powder, Saffron Flower Extract, Essential Oils ...

# %% [markdown]
# ### Remove brackets and spaces

# %%
### Remove brackets and spaces in ingridients
for indx, ingdOf1 in enumerate(ingdList):
    ingds = ingdOf1[0].split(",")
    for i, ingd in enumerate(ingds):
        if(ingd.__contains__('(')):
            ingds[i] = ingd[0:ingd.find('(')]
        while(ingds[i][-1] == ' '):
            ingds[i] = ingds[i][0:-1]
        while(ingds[i][0] == ' '):
            ingds[i] = ingds[i][1:]
    ingdList[indx] = ingds
        # ingds[i] = ingd.replace('(', '')
        # ingds[i] = ingd.replace(')', '')
        # ingd = ingd.replace(' ', '')

# %%
print(ingdList)
# Out:
# [['Water', 'Ammonium Lauryl Sulfate', 'Cocamidopropyl Betaine', 'Sodium Cocoyl Glutamate', 'Glycerin', 'Sodium Lauroyl Sarcosinate', 'Glycol Distearate', 'Decyl Glucoside', 'PEG-150 Distearate', 'Sodium Lauryl Glucose Carboxylate', 'Fragrance', 'Phenoxyethanol', 'Sodium Benzoate', 'Azadirachta Indica', 'Melia Azadirachta', 'Sodium Citrate', 'Citric Acid', 'Butylene Glycol', 'Tocopheryl Acetate', 'CI 19140', 'CI 42090.'], ['Turmeric Extract', 'Sandalwood Oil', 'Water', 'Stearic Acid', 'Sorbitol', 'Sodium Hydroxide', 'Methyl Paraben', 'Propyl Paraben.'], ['Coconut Oil', 'Dugdh', 'Manjistha', 'Nimba Kamla', 'Badam Tail', 'Cream Base Q.S.'], ['Water', 'Phenylbenzimidazole Sulfonic Acid', 'Oxybenzone', 'Octyl Methoxy Cinnamate', 'Cyclopentasiloxane', 'Acrylates/C10-30 Alkyl Acrylate Crosspolymer', 'Triethanolamine', 'Glycerin', 'Phenoxyethanol', 'Polysorbate 20', 'Methyl Paraben', 'Propyl Paraben', 'Fragrance', 'Carbomer', 'Disodium EDTA', 'Vitamin E.'], ['Methi Seed Extract', 'Bhringraj Extract', 'Nagarmotha Extract', 'Amla Extract', 'Reetha Extract', 'Madhu', 'Kikar Gond', 'Vanilla Extract', 'Purified Water Q.S.'], ['Cyclomethicone', 'Aqua', 'Butylene Glycol', 'Glycerin', 'Talc', 'Isotridecyl Isononanoate', 'Cetyl PEG/PPG-10/1 Dimethicone', 'HDI/Trimethylol Hexyllactone Crosspolymer', 'Phenyl Trimethicone', 'Sodium Chloride', 'Acrylates/Dimethicone Copolymer', 'Phenoxyethanol', 'Methylparaben', 'Ethylparaben', 'Propylparaben', 'Parfum', 'Tocopheryl Acetate', 'Disodium EDTA', 'Sodium Hyaluronate', 'Butylphenyl Methylpropional', 'Citronellol', 'Hexyl Cinnamal', 'Limonene', 'Linalool', 'Alpha-Isomethyl Ionone. May contain Cl 77491', 'Cl 77492', 'Cl 77499', 'Cl 77891.'], ['Aloe Vera', 'Base Material'], ['Aqua', 'Glycerin', 'Walnut Shell Powder', 'Apricot Kernel Oil', 'Sweet Almond Oil', 'Kokum Butter', 'Sesame Oil', 'Beeswax', 'Avocado Butter', 'Kokum Butter', 'Kumkumadi Oil', 'Saffron Flower Extract', 'Vitamin E', 'Grapefruit Seed Extract', 'Potassium Sorbate', 'Essential Oils of Rose', 'Jasmine', 'and Lotus.'], ['100% Natural Steam Distilled Pure Rosewater.'], ['Sandalwood Oil', 'Chamomile Extract', 'Aloe Vera Gel', 'Wheat Germ Oil', 'Carrot Seed Oil', 'Zinc Oxide', 'Titanium Dioxide', 'Avobenzone', 'Octylmethoxy Cinnamate', 'Micronized Titanium Dioxide', 'Beeswax', 'Methyl Paraben', 'Propyl Paraben', 'Phenoxyethanol', 'Triethanolamine', 'Allantoin', 'Potassium Sorbate', 'Sodium Benzoate', 'Fragrance.'], ['Calcium Carbonate', 'Water', 'Sorbitol', 'Sodium Lauryl Sulphate', 'Flavour', 'Indian Licorice Root Extract', 'Gum Tragacanth', 'Carrageenan', 'Clove Oil', 'Eucalyptus Oil', 'Sodium Saccharin', 'Methyl Paraben', 'Propyl Paraben.'], ['Water', 'Sodium Lauryl Ether Sulphate', 'Glycerin', 'Sodium Lauryl Sulphate', 'Propylene Glycol', 'Cocamidopropyl Betaine', 'Decyl Glucoside', 'Acrylates Copolymer', 'Sodium Cocoyl Glutamate', 'Coco-Glucoside', 'Walnut Shell Powder', 'Niacinamide', 'Glycolic Acid', 'Sodium Hydroxide', 'Tocopheryl Acetate', 'Allantoin', 'Sodium PCA', 'Camellia Sinensis', 'Morus Alba', 'BHT', 'Disodium EDTA', 'Fragrance', 'Methylchloroisothiazolinone', 'Methylisothiazolinone.'], ['Water', 'Caprylic/Capric Triglyceride', 'Glycerin', 'Polyglyceryl-3 Methylglucose Distearate', 'Glyceryl Stearate', 'Cetyl Alcohol', 'Isopropyl Myristate', 'Simmondsia Chinensis', 'Triticum Vulgare', 'Prunus Amygdalus Dulcis', 'Butyrospermum Parkii', 'Hedychium Spicatum', 'Citrus Medica Limonum', 'Malus Domestica', 'Vitis Vinifera', 'Aloe Barbadensis', 'Tocopherol', 'Xanthan Gum', 'Phenoxyethanol', 'Ethylhexylglycerin', 'Fragrance.'], ['Multani Mitti', 'Calamine', 'Kaolin', 'Aloe Vera', "Fuller's Earth", 'Glycerin', 'PEG-400', 'Sodium Methyl Paraben.'], ['Chickpea Flour', 'Almond Powder', 'Neem Leaf Powder', 'Turmeric Root Powder', 'Mulethi Root Powder', 'Sandalwood Powder', 'Saffron Flower Extract', 'Essential Oils of Sandalwood', 'Orange', 'and Nagkesar.'], ['Wheat Germ Oil', 'Sunflower Oil', 'Aloe Vera Juice', 'Honey', 'Methi Seed Extract' ...

# %%
def toLetters(input):
    valids = []
    for character in input:
        if character.isalpha():
            valids.append(character)
    return ''.join(valids)

def getWordComponents(inpList):
    subIng = []
    for subindx, ingd in enumerate(inpList):
        sub = ingd.split(' ')   # ['Milk', 'Fat']
        for x in sub:
            converted = toLetters(x.lower())
            if(len(converted) > 0):
                subIng.append(converted)
    return subIng

# %% [markdown]
# ## Separating ingridient by space and to lower

# %%
seprdIngdList = []
### Split ingridients by space also
for indx, ingdOf1 in enumerate(ingdList):
    seprdIngdList.append(getWordComponents(ingdOf1))

# %%
seprdIngdList
# Out:
# [['water',
#   'ammonium',
#   'lauryl',
#   'sulfate',
#   'cocamidopropyl',
#   'betaine',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'glycerin',
#   'sodium',
#   'lauroyl',
#   'sarcosinate',
#   'glycol',
#   'distearate',
#   'decyl',
#   'glucoside',
#   'peg',
#   'distearate',
#   'sodium',
#   'lauryl',
#   'glucose',
#   'carboxylate',
#   'fragrance',
#   'phenoxyethanol',
#   'sodium',
#   'benzoate',
#   'azadirachta',
#   'indica',
#   'melia',
#   'azadirachta',
#   'sodium',
#   'citrate',
#   'citric',
#   'acid',
#   'butylene',
#   'glycol',
#   'tocopheryl',
#   'acetate',
#   'ci',
#   'ci'],
#  ['turmeric',
#   'extract',
#   'sandalwood',
#   'oil',
#   'water',
#   'stearic',
#   'acid',
#   'sorbitol',
#   'sodium',
#   'hydroxide',
#   'methyl',
#   'paraben',
#   'propyl',
#   'paraben'],
#  ['coconut',
#   'oil',
#   'dugdh',
#   'manjistha',
#   'nimba',
#   'kamla',
#   'badam',
#   'tail',
#   'cream',
#   'base',
#   'qs'],
#  ['water',
#   'phenylbenzimidazole',
#   'sulfonic',
#   'acid',
#   'oxybenzone',
#   'octyl',
#   'methoxy',
#   'cinnamate',
#   'cyclopentasiloxane',
#   'acrylatesc',
#   'alkyl',
#   'acrylate',
#   'crosspolymer',
#   'triethanolamine',
#   'glycerin',
#   'phenoxyethanol',
#   'polysorbate',
#   'methyl',
#   'paraben',
#   'propyl',
#   'paraben',
#   'fragrance',
#   'carbomer',
#   'disodium',
#   'edta',
#   'vitamin',
#   'e'],
#  ['methi',
#   'seed',
#   'extract',
#   'bhringraj',
#   'extract',
#   'nagarmotha',
#   'extract',
#   'amla',
#   'extract',
#   'reetha',
#   'extract',
#   'madhu',
#   'kikar',
#   'gond',
#   'vanilla',
#   'extract',
#   'purified',
#   'water',
#   'qs'],
#  ['cyclomethicone',
#   'aqua',
#   'butylene',
#   'glycol',
#   'glycerin',
#   'talc',
#   'isotridecyl',
#   'isononanoate',
#   'cetyl',
#   'pegppg',
#   'dimethicone',
#   'hditrimethylol',
#   'hexyllactone',
#   'crosspolymer',
#   'phenyl',
#   'trimethicone',
#   'sodium',
#   'chloride',
#   'acrylatesdimethicone',
#   'copolymer',
#   'phenoxyethanol',
#   'methylparaben',
#   'ethylparaben',
#   'propylparaben',
#   'parfum',
#   'tocopheryl',
#   'acetate',
#   'disodium',
#   'edta',
#   'sodium',
#   'hyaluronate',
#   'butylphenyl',
#   'methylpropional',
#   'citronellol',
#   'hexyl',
#   'cinnamal',
#   'limonene',
#   'linalool',
#   'alphaisomethyl',
#   'ionone',
#   'may',
#   'contain',
#   'cl',
#   'cl',
#   'cl',
#   'cl'],
#  ['aloe', 'vera', 'base', 'material'],
#  ['aqua',
#   'glycerin',
#   'walnut',
#   'shell',
#   'powder',
#   'apricot',
#   'kernel',
#   'oil',
#   'sweet',
#   'almond',
#   'oil',
#   'kokum',
#   'butter',
#   'sesame',
#   'oil',
#   'beeswax',
#   'avocado',
#   'butter',
#   'kokum',
#   'butter',
#   'kumkumadi',
#   'oil',
#   'saffron',
#   'flower',
#   'extract',
#   'vitamin',
#   'e',
#   'grapefruit',
#   'seed',
#   'extract',
#   'potassium',
#   'sorbate',
#   'essential',
#   'oils',
#   'of',
#   'rose',
#   'jasmine',
#   'and',
#   'lotus'],
#  ['natural', 'steam', 'distilled', 'pure', 'rosewater'],
#  ['sandalwood',
#   'oil',
#   'chamomile',
#   'extract',
#   'aloe',
#   'vera',
#   'gel',
#   'wheat',
#   'germ',
#   'oil',
#   'carrot',
#   'seed',
#   'oil',
#   'zinc',
#   'oxide',
#   'titanium',
#   'dioxide',
#   'avobenzone',
#   'octylmethoxy',
#   'cinnamate',
#   'micronized',
#   'titanium',
#   'dioxide',
#   'beeswax',
#   'methyl',
#   'paraben',
#   'propyl',
#   'paraben',
#   'phenoxyethanol',
#   'triethanolamine',
#   'allantoin',
#   'potassium',
#   'sorbate',
#   'sodium',
#   'benzoate',
#   'fragrance'],
#  ['calcium',
#   'carbonate',
#   'water',
#   'sorbitol',
#   'sodium',
#   'lauryl',
#   'sulphate',
#   'flavour',
#   'indian',
#   'licorice',
#   'root',
#   'extract',
#   'gum',
#   'tragacanth',
#   'carrageenan',
#   'clove',
#   'oil',
#   'eucalyptus',
#   'oil',
#   'sodium',
#   'saccharin',
#   'methyl',
#   'paraben',
#   'propyl',
#   'paraben'],
#  ['water',
#   'sodium',
#   'lauryl',
#   'ether',
#   'sulphate',
#   'glycerin',
#   'sodium',
#   'lauryl',
#   'sulphate',
#   'propylene',
#   'glycol',
#   'cocamidopropyl',
#   'betaine',
#   'decyl',
#   'glucoside',
#   'acrylates',
#   'copolymer',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'cocoglucoside',
#   'walnut',
#   'shell',
#   'powder',
#   'niacinamide',
#   'glycolic',
#   'acid',
#   'sodium',
#   'hydroxide',
#   'tocopheryl',
#   'acetate',
#   'allantoin',
#   'sodium',
#   'pca',
#   'camellia',
#   'sinensis',
#   'morus',
#   'alba',
#   'bht',
#   'disodium',
#   'edta',
#   'fragrance',
#   'methylchloroisothiazolinone',
#   'methylisothiazolinone'],
#  ['water',
#   'capryliccapric',
#   'triglyceride',
#   'glycerin',
#   'polyglyceryl',
#   'methylglucose',
#   'distearate',
#   'glyceryl',
#   'stearate',
#   'cetyl',
#   'alcohol',
#   'isopropyl',
#   'myristate',
#   'simmondsia',
#   'chinensis',
#   'triticum',
#   'vulgare',
#   'prunus',
#   'amygdalus',
#   'dulcis',
#   'butyrospermum',
#   'parkii',
#   'hedychium',
#   'spicatum',
#   'citrus',
#   'medica',
#   'limonum',
#   'malus',
#   'domestica',
#   'vitis',
#   'vinifera',
#   'aloe',
#   'barbadensis',
#   'tocopherol',
#   'xanthan',
#   'gum',
#   'phenoxyethanol',
#   'ethylhexylglycerin',
#   'fragrance'],
#  ['multani',
#   'mitti',
#   'calamine',
#   'kaolin',
#   'aloe',
#   'vera',
#   'fullers',
#   'earth',
#   'glycerin',
#   'peg',
#   'sodium',
#   'methyl',
#   'paraben'],
#  ['chickpea',
#   'flour',
#   'almond',
#   'powder',
#   'neem',
#   'leaf',
#   'powder',
#   'turmeric',
#   'root',
#   'powder',
#   'mulethi',
#   'root',
#   'powder',
#   'sandalwood',
#   'powder',
#   'saffron',
#   'flower',
#   'extract',
#   'essential',
#   'oils',
#   'of',
#   'sandalwood',
#   'orange',
#   'and',
#   'nagkesar'],
#  ['wheat',
#   'germ',
#   'oil',
#   'sunflower',
#   'oil',
#   'aloe',
#   'vera',
#   'juice',
#   'honey',
#   'methi',
#   'seed',
#   'extract',
#   'kulanjan',
#   'rhizome',
#   'extract',
#   'ankurit',
#   'gehun',
#   'seed',
#   'extract',
#   'madhu',
#   'purified',
#   'water',
#   'cream',
#   'base',
#   'qs'],
#  ['water',
#   'paraffinum',
#   'liquidum',
#   'isohexadecane',
#   'glycerin',
#   'cetearyl',
#   'alcohol',
#   'glyceryl',
#   'stearate',
#   'citrate',
#   'dimethicone',
#   'glyceryl',
#   'stearate',
#   'prunus',
#   'amygdalus',
#   'dulcis',
#   'oil',
#   'sodium',
#   'carbomer',
#   'sodium',
#   'acrylatesc',
#   'alkyl',
#   'acrylate',
#   'crosspolymer',
#   'phenoxyethanol',
#   'ethylhexylglycerin',
#   'linalool',
#   'citronellol',
#   'alphaisomethyl',
#   'ionone',
#   'geraniol',
#   'benzyl',
#   'alcohol',
#   'parfum'],
#  ['papaya',
#   'seed',
#   'scrub',
#   'papaya',
#   'seed',
#   'powder',
#   'kaolin',
#   'powder',
#   'solum',
#   'fullonum',
#   'sodium',
#   'methylparaben',
#   'fragrance',
#   'cucumber',
#   'gel',
#   'cucumber',
#   'extract',
#   'propylene',
#   'glycol',
#   'glycerine',
#   'cellulose',
#   'gum',
#   'methylparaben',
#   'propylparaben',
#   'fragrance',
#   'peach',
#   'massage',
#   'cream',
#   'wheat',
#   'germ',
#   'oil',
#   'olive',
#   'oil',
#   'vitamin',
#   'e',
#   'xanthan',
#   'gum',
#   'isopropyl',
#   'myristate',
#   'methylparaben',
#   'propylparaben',
#   'fragrance',
#   'orange',
#   'antitan',
#   'pack',
#   'orange',
#   'peel',
#   'powder',
#   'zinc',
#   'oxide',
#   'kaolin',
#   'powder',
#   'bentonite',
#   'powder',
#   'cetyl',
#   'alcohol',
#   'isopropyl',
#   'myristate',
#   'sodium',
#   'lauryl',
#   'sulphate',
#   'methylparaben',
#   'propylparaben',
#   'fragrance'],
#  ['aloe',
#   'vera',
#   'manjishta',
#   'ghritkumari',
#   'kesar',
#   'sandalwood',
#   'akarkara',
#   'anantmool',
#   'durva',
#   'ghritkumari',
#   'daruhaldi',
#   'lodhra',
#   'neem',
#   'tulsi',
#   'turmeric',
#   'xanthan',
#   'gum',
#   'vitamin',
#   'e',
#   'potassium',
#   'sorbate',
#   'sodium',
#   'benzoate',
#   'pudina',
#   'ka',
#   'phool',
#   'sugandhit',
#   'dravya',
#   'aqua'],
#  ['cyclopentasiloxane',
#   'trimethylsiloxysilicate',
#   'polyethylene',
#   'mica',
#   'lauroyl',
#   'lysine',
#   'ozokerite',
#   'octyldodecanol',
#   'disteardimonium',
#   'hectorite',
#   'propylene',
#   'carbonate',
#   'tocopherol',
#   'calcium',
#   'aluminum',
#   'borosilicate',
#   'propylparaben',
#   'bht',
#   'tin',
#   'oxide',
#   'may',
#   'contain',
#   'cl',
#   'cl',
#   'cl',
#   'cl',
#   'cl',
#   'cl'],
#  ['water',
#   'octyl',
#   'methoxy',
#   'cinnamate',
#   'butyl',
#   'methoxy',
#   'dibenzoyl',
#   'methane',
#   'benzophenone',
#   'phenylbenzimidazole',
#   'sulfonic',
#   'acid',
#   'polyacrylamide',
#   'c',
#   'isoparaffin',
#   'laureth',
#   'triethanolamine',
#   'cyclopentasiloxane',
#   'dimethicone',
#   'titanium',
#   'dioxide',
#   'methyl',
#   'paraben',
#   'propyl',
#   'paraben',
#   'disodium',
#   'edta',
#   'allantoin',
#   'glycerin',
#   'butylene',
#   'glycol',
#   'phenoxyethanol',
#   'perfume'],
#  ['fullers',
#   'earth',
#   'calamine',
#   'powder',
#   'sandalwood',
#   'powder',
#   'neem',
#   'powder',
#   'turmeric',
#   'powder',
#   'fennel',
#   'powder',
#   'star',
#   'anise',
#   'powder',
#   'almond',
#   'powder',
#   'fenugreek',
#   'powder',
#   'saffron',
#   'extract',
#   'orange',
#   'peel',
#   'powder'],
#  ['water',
#   'ammonium',
#   'lauryl',
#   'sulfate',
#   'disodium',
#   'cocamphodiacetate',
#   'sodium',
#   'lauroyl',
#   'sarcosinate',
#   'cocamidopropyl',
#   'betaine',
#   'extracts',
#   'of',
#   'neem',
#   'and',
#   'turmeric',
#   'sodium',
#   'pca',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'decyl',
#   'glucoside',
#   'fragrance',
#   'phenoxyethanol',
#   'methylchloroisothiazolinone',
#   'methylisothiazolinone',
#   'citric',
#   'acid',
#   'ci',
#   'ci'],
#  ['saffron',
#   'vetiver',
#   'lotus',
#   'licorice',
#   'indian',
#   'madder',
#   'manjistha',
#   'sandalwood',
#   'orange',
#   'peel',
#   'turmeric',
#   'sesame',
#   'oil',
#   'bael',
#   'base',
#   'qs'],
#  ['aquawater',
#   'sodium',
#   'laureth',
#   'sulfate',
#   'cocobetaine',
#   'sodium',
#   'chloride',
#   'glycol',
#   'distearate',
#   'dimethicone',
#   'guar',
#   'hydroxypropyltrimonium',
#   'chloride',
#   'cocamide',
#   'mipa',
#   'sodium',
#   'benzoate',
#   'hydroxypropyltrimonium',
#   'hydrolyzed',
#   'wheat',
#   'protein',
#   'sodium',
#   'hydroxide',
#   'ppgceteth',
#   'arginine',
#   'salicylic',
#   'acid',
#   'polyquaternium',
#   'limonene',
#   'linalool',
#   'benzyl',
#   'salicylate',
#   'oleamido',
#   'octadecanediol',
#   'carbomer',
#   'serine',
#   'butylphenyl',
#   'methylpropional',
#   'citric',
#   'acid',
#   'glutamic',
#   'acid',
#   'hexyl',
#   'cinnamal',
#   'glyceryl',
#   'linoleate',
#   'glyceryl',
#   'oleate',
#   'glyceryl',
#   'linolenate',
#   'parfumfragrance'],
#  ['turmeric',
#   'sandalwood',
#   'oil',
#   'sodium',
#   'hydroxide',
#   'beeswax',
#   'water',
#   'borax',
#   'perfume'],
#  ['green',
#   'apple',
#   'centella',
#   'bhringraj',
#   'sea',
#   'algae',
#   'himalayan',
#   'water',
#   'sles',
#   'derived',
#   'neutral',
#   'thickener',
#   'polyquaterium',
#   'natural',
#   'preservative',
#   'blend'],
#  ['fullers',
#   'earth',
#   'neem',
#   'turmeric',
#   'lodhra',
#   'multani',
#   'mitti',
#   'kaolin',
#   'aloe',
#   'vera',
#   'bentone',
#   'gel',
#   'zinc',
#   'oxide',
#   'gum',
#   'acacia',
#   'methylparaben',
#   'sodium',
#   'propylparaben',
#   'sodium',
#   'sodium',
#   'lauryl',
#   'ether',
#   'sulphate',
#   'titanium',
#   'dioxide',
#   'perfume'],
#  ['aloe', 'vera', 'base', 'material', 'qs', 'preservatives'],
#  ['isododecane',
#   'polyethylene',
#   'synthetic',
#   'wax',
#   'hydrogenated',
#   'polydicyclopentadiene',
#   'ethylenepropylene',
#   'copolymer',
#   'bisdiglyceryl',
#   'polyacyladipate',
#   'hydrogenated',
#   'styrenemethyl',
#   'styreneindene',
#   'copolymer',
#   'silica',
#   'polybutene',
#   'pentaerythrityl',
#   'tetraditbutyl',
#   'hydroxyhydrocinnamate',
#   'cococaprylatecaprate',
#   'talc',
#   'trimethylsiloxysilicate',
#   'mica',
#   'ci',
#   'nanoblack',
#   'ci',
#   'ultramarines',
#   'ci',
#   'iron',
#   'oxides',
#   'ci',
#   'iron',
#   'oxides',
#   'ci',
#   'iron',
#   'oxides'],
#  ['kiehls', 'clearly', 'corrective', 'dark', 'spot', 'solution'],
#  ['purified',
#   'water',
#   'decyl',
#   'glucoside',
#   'cocoamidopropyl',
#   'betain',
#   'lauryl',
#   'glucoside',
#   'glycerin',
#   'sodium',
#   'pca',
#   'sodium',
#   'lactate',
#   'pca',
#   'glyceryl',
#   'oleate',
#   'hydrolyzed',
#   'wheat',
#   'protein',
#   'soy',
#   'protein',
#   'coco',
#   'glucoside',
#   'aloe',
#   'vera',
#   'extract',
#   'vetiver',
#   'oil',
#   'patchouli',
#   'oil',
#   'lavender',
#   'oil',
#   'geranium',
#   'oil',
#   'rose',
#   'oil',
#   'hibiscus',
#   'extract',
#   'shikakai',
#   'extract',
#   'reetha',
#   'extract',
#   'lemon',
#   'extract',
#   'citric',
#   'acid',
#   'potassium',
#   'sorbate',
#   'sodium',
#   'benzoate',
#   'xanthan',
#   'gum',
#   'caprylyl',
#   'glycol',
#   'essential',
#   'oils',
#   'of',
#   'lavender',
#   'patchouli',
#   'geranium',
#   'and',
#   'rose',
#   'certified',
#   'organic',
#   'ingredient'],
#  ['purified',
#   'water',
#   'bhringraj',
#   'extract',
#   'hibiscus',
#   'extract',
#   'fenugreek',
#   'extract',
#   'brahmi',
#   'extract',
#   'nettle',
#   'extract',
#   'cinnamon',
#   'extract',
#   'bay',
#   'leaf',
#   'extract',
#   'almond',
#   'extract',
#   'orange',
#   'peel',
#   'extract',
#   'neem',
#   'extract',
#   'turmeric',
#   'extract',
#   'wheat',
#   'protein',
#   'vegetable',
#   'glycerin',
#   'hydroxypropyltrimonium',
#   'honey',
#   'silk',
#   'amino',
#   'acids',
#   'inositol',
#   'citric',
#   'acid',
#   'essential',
#   'oils',
#   'of',
#   'orange',
#   'lemongrass',
#   'and',
#   'lavender'],
#  ['purified',
#   'water',
#   'decyl',
#   'glucoside',
#   'glycerin',
#   'sodium',
#   'lauroyl',
#   'sarcosinate',
#   'carbomer',
#   'turmeric',
#   'saffron',
#   'cucumber',
#   'aloe',
#   'vera',
#   'extract',
#   'licorice',
#   'extract',
#   'peppermint',
#   'oil',
#   'potassium',
#   'sorbate',
#   'sodium',
#   'benzoate',
#   'citric',
#   'acid'],
#  ['madhu', 'ghrit', 'kumari', 'rosa', 'purified', 'water', 'qs'],
#  ['water',
#   'propylene',
#   'glycol',
#   'cyclopentasiloxane',
#   'cyclohexasiloxane',
#   'zinc',
#   'oxide',
#   'titanium',
#   'dioxide',
#   'isopropyl',
#   'myristate',
#   'octyl',
#   'methoxycinnamate',
#   'phenylbenzimidazole',
#   'sulfonic',
#   'acid',
#   'triethanolamine',
#   'stearic',
#   'acid',
#   'aluminum',
#   'hydroxide',
#   'carbomer',
#   'tocopheryl',
#   'acetate',
#   'methylparaben',
#   'propylparaben',
#   'fragrance'],
#  ['purified',
#   'water',
#   'decyl',
#   'glucoside',
#   'cocoamidopropyl',
#   'betaine',
#   'lauryl',
#   'glucoside',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'vegetable',
#   'glycerin',
#   'honey',
#   'vanilla',
#   'extract',
#   'brahmi',
#   'extract',
#   'neem',
#   'extract',
#   'fenugreek',
#   'extract',
#   'bhringraj',
#   'extract',
#   'hibiscus',
#   'extract',
#   'almond',
#   'extract',
#   'wheat',
#   'protein',
#   'soy',
#   'protein',
#   'xanthan',
#   'gum',
#   'citric',
#   'acid',
#   'caprylyl',
#   'glycol',
#   'sodium',
#   'benzoate',
#   'potassium',
#   'sorbate'],
#  ['multani',
#   'mitti',
#   'geru',
#   'yasad',
#   'bhasm',
#   'tomato',
#   'pineapple',
#   'papaya',
#   'apple',
#   'cucumber',
#   'fullers',
#   'earth',
#   'qs'],
#  ['aloe',
#   'vera',
#   'extracts',
#   'of',
#   'kesar',
#   'and',
#   'chandan',
#   'vitamin',
#   'e',
#   'permitted',
#   'colour',
#   'sugandhit',
#   'dravya',
#   'base',
#   'material',
#   'qs'],
#  ['water',
#   'ammonium',
#   'lauryl',
#   'sulfate',
#   'melia',
#   'azadirachta',
#   'leaf',
#   'extract',
#   'cocamidopropyl',
#   'betaine',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'sodium',
#   'lauryl',
#   'glucose',
#   'carboxylate',
#   'lauryl',
#   'glucoside',
#   'decyl',
#   'glucoside',
#   'glycerin',
#   'citric',
#   'acid',
#   'fragrance',
#   'potassium',
#   'sorbate',
#   'sodium',
#   'benzoate',
#   'tocopheryl',
#   'acetate'],
#  ['aqua',
#   'rose',
#   'water',
#   'aloe',
#   'vera',
#   'honey',
#   'decyl',
#   'glucoside',
#   'cocoglucoside',
#   'lauryl',
#   'glucoside',
#   'glycerin',
#   'citric',
#   'acid',
#   'xanthan',
#   'gum',
#   'sodium',
#   'levulinate',
#   'sodium',
#   'anisate',
#   'sodium',
#   'benzoate',
#   'potassium',
#   'sorbate',
#   'fragrance'],
#  ['capryliccapric',
#   'triglyceride',
#   'onion',
#   'seed',
#   'oil',
#   'organic',
#   'sunflower',
#   'oil',
#   'organic',
#   'amla',
#   'oil',
#   'organic',
#   'hibiscus',
#   'oil',
#   'tocopherol',
#   'rosemary',
#   'oil',
#   'sodium',
#   'benzoate'],
#  ['saffron',
#   'indian',
#   'madder',
#   'licorice',
#   'lotus',
#   'vetiver',
#   'kashmiri',
#   'saffron',
#   'sweet',
#   'almond',
#   'oil',
#   'sesame',
#   'oil',
#   'castor',
#   'oil',
#   'sandalwood',
#   'oil',
#   'vetiver',
#   'oil',
#   'lotus',
#   'oil',
#   'turmeric',
#   'manjishtha',
#   'padmakashtha',
#   'anantmool'],
#  ['turmeric',
#   'extract',
#   'sandalwood',
#   'oil',
#   'water',
#   'stearic',
#   'acid',
#   'sorbitol',
#   'methylparaben',
#   'propylparaben',
#   'sodium',
#   'hydroxide',
#   'scented',
#   'perfume'],
#  ['aqua',
#   'kaolin',
#   'china',
#   'clay',
#   'glycerin',
#   'aloe',
#   'vera',
#   'extract',
#   'bentonite',
#   'powder',
#   'activated',
#   'charcoal',
#   'powder',
#   'tea',
#   'tree',
#   'oil',
#   'calendula',
#   'extract',
#   'lavender',
#   'oil',
#   'camphor',
#   'oil',
#   'vitamin',
#   'e',
#   'oil'],
#  ['aqua',
#   'capryliccapric',
#   'triglyceride',
#   'isopropyl',
#   'myristate',
#   'glycerin',
#   'cetyl',
#   'alcohol',
#   'glyceryl',
#   'stearate',
#   'cetearyl',
#   'alcohol',
#   'dimethicone',
#   'phenoxyethanol',
#   'sodium',
#   'lauryl',
#   'sulfate',
#   'fragrance',
#   'triethanolamine',
#   'carbomer',
#   'sodium',
#   'benzoate',
#   'methylparaben',
#   'tocopheryl',
#   'acetate',
#   'propylparaben',
#   'disodium',
#   'edta',
#   'sodium',
#   'metabisulfite'],
#  ['extracts',
#   'of',
#   'haldi',
#   'chandan',
#   'aloe',
#   'vera',
#   'glycerin',
#   'perfume',
#   'soap',
#   'base',
#   'qs'],
#  ['desi',
#   'cows',
#   'milk',
#   'ghee',
#   'kokum',
#   'butter',
#   'raw',
#   'honey',
#   'sandalwood',
#   'oil',
#   'rose',
#   'oil',
#   'anantmool',
#   'root',
#   'extract',
#   'aloe',
#   'vera',
#   'leaf',
#   'extract',
#   'nagkesar',
#   'flower',
#   'extract',
#   'mulethi',
#   'root',
#   'extract',
#   'vitamin',
#   'e',
#   'potassium',
#   'sorbate'],
#  ['water',
#   'light',
#   'liquid',
#   'paraffin',
#   'hydrogenated',
#   'polyisobutene',
#   'glycerin',
#   'arbutin',
#   'cyclopentasiloxane',
#   'capryliccapric',
#   'triglyceride',
#   'titanium',
#   'dioxide',
#   'cetyl',
#   'alcohol',
#   'glyceryl',
#   'stearate',
#   'peg',
#   'stearate',
#   'behenyl',
#   'alcohol',
#   'phenoxyethanol',
#   'methylparaben',
#   'propylparaben',
#   'carbomer',
#   'triethanolamine',
#   'tocopheryl',
#   'acetate',
#   'fragrance',
#   'sodium',
#   'ascorbyl',
#   'phosphate',
#   'allantoin',
#   'disodium',
#   'edta'],
#  ['ghrit',
#   'kumari',
#   'methi',
#   'madhu',
#   'ankurit',
#   'gehun',
#   'kusumbhi',
#   'vach',
#   'lotion',
#   'base',
#   'qs'],
#  ['water',
#   'mineral',
#   'oil',
#   'propylene',
#   'glycol',
#   'stearic',
#   'acid',
#   'glyceryl',
#   'stearate',
#   'cetyl',
#   'alcohol',
#   'triethanolamine',
#   'polysorbate',
#   'phenoxyethanol',
#   'methylparaben',
#   'propylparaben',
#   'sodium',
#   'lauryl',
#   'ether',
#   'sulfate',
#   'acrylatesc',
#   'alkyl',
#   'acrylate',
#   'crosspolymer',
#   'fragrance',
#   'allantoin',
#   'disodium',
#   'edta',
#   'tocopheryl',
#   'acetate',
#   'sandalwood',
#   'oil',
#   'milk'],
#  ['purified',
#   'water',
#   'almond',
#   'oil',
#   'honey',
#   'aloe',
#   'vera',
#   'juice',
#   'rose',
#   'water',
#   'emulsifying',
#   'wax',
#   'glycerin',
#   'stearic',
#   'acid',
#   'sodium',
#   'benzoate',
#   'potassium',
#   'sorbate',
#   'cetyl',
#   'alcohol',
#   'triethanolamine',
#   'vitamin',
#   'e',
#   'acetate',
#   'dimethicone',
#   'methylparaben',
#   'propylparaben',
#   'carbopol',
#   'fragrance'],
#  ['aloe',
#   'vera',
#   'neem',
#   'tulsi',
#   'orange',
#   'peel',
#   'pudina',
#   'aqua',
#   'gel',
#   'base',
#   'diazolidinyl',
#   'urea',
#   'iodopropynyl',
#   'butylcarbamate',
#   'vitamin',
#   'e',
#   'vitamin',
#   'a',
#   'ci',
#   'ci',
#   'sugandhit',
#   'dravyaqs'],
#  ['amla',
#   'shikakai',
#   'reetha',
#   'water',
#   'sodium',
#   'laureth',
#   'sulphate',
#   'cocamidopropyl',
#   'betaine',
#   'cocamide',
#   'dea',
#   'polyquaternium',
#   'glycerin',
#   'sodium',
#   'chloride',
#   'methylparaben',
#   'propylparaben',
#   'citric',
#   'acid',
#   'fragrance'],
#  ['water',
#   'glycerin',
#   'cyclopentasiloxane',
#   'ethylhexyl',
#   'methoxycinnamate',
#   'dimethicone',
#   'crosspolymer',
#   'titanium',
#   'dioxide',
#   'sodium',
#   'acrylatesodium',
#   'acryloyldimethyl',
#   'taurate',
#   'copolymer',
#   'isohexadecane',
#   'cyclohexasiloxane',
#   'peg',
#   'trimethylolpropane',
#   'coconut',
#   'ether',
#   'benzophenone',
#   'polysorbate',
#   'aluminium',
#   'hydroxide',
#   'stearic',
#   'acid',
#   'phenoxyethanol',
#   'methylparaben',
#   'propylparaben',
#   'allantoin',
#   'vitamin',
#   'e',
#   'acetate',
#   'fragrance'],
#  ['water',
#   'ammonium',
#   'lauryl',
#   'sulfate',
#   'cocamidopropyl',
#   'betaine',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'sodium',
#   'lauryl',
#   'glucose',
#   'carboxylate',
#   'and',
#   'lauryl',
#   'glucoside',
#   'decyl',
#   'glucoside',
#   'glycerin',
#   'sodium',
#   'hydroxide',
#   'fragrance',
#   'phenoxyethanol',
#   'curcuma',
#   'longa',
#   'azadirachta',
#   'indica',
#   'sodium',
#   'benzoate',
#   'potassium',
#   'sorbate',
#   'citric',
#   'acid'],
#  ['green',
#   'apple',
#   'sea',
#   'algae',
#   'centella',
#   'sodium',
#   'laureth',
#   'sulphate',
#   'himalayan',
#   'water',
#   'qs'],
#  ['aqua',
#   'glycerin',
#   'almond',
#   'oil',
#   'mulethi',
#   'anantmool',
#   'ashwagandha',
#   'nagkesar',
#   'durva',
#   'yashtimadhu',
#   'manjishtha',
#   'cows',
#   'milk',
#   'sesame',
#   'oil',
#   'shea',
#   'butter',
#   'kokum',
#   'butter',
#   'bees',
#   'wax',
#   'vitamin',
#   'e',
#   'saffron',
#   'karat',
#   'gold',
#   'bhasma',
#   'cinnamon',
#   'oil',
#   'rose',
#   'oil',
#   'mogra',
#   'oil',
#   'jasmine',
#   'oil',
#   'spf'],
#  ['rosa', 'damascena', 'flower', 'water'],
#  ['aqua',
#   'sodium',
#   'laureth',
#   'sulfate',
#   'cocobetaine',
#   'dimethicone',
#   'glycol',
#   'distearate',
#   'sodium',
#   'chloride',
#   'guar',
#   'hydroxypropyltrimonium',
#   'chloride',
#   'cocoamide',
#   'mipa',
#   'sodium',
#   'benzoate',
#   'sodium',
#   'hydroxide',
#   'citric',
#   'acid',
#   'hexylene',
#   'glycol',
#   'argania',
#   'spinosa',
#   'kernel',
#   'oil',
#   'salicylic',
#   'acid',
#   'carbomer',
#   'ci',
#   'ci',
#   'fragrance'],
#  ['aloe', 'vera', 'base', 'material', 'preservatives', 'diazolidinyl', 'urea'],
#  ['turmeric', 'sandalwood', 'oil', 'sodium', 'hydroxide', 'borax', 'water'],
#  ['water',
#   'cyclopentasiloxane',
#   'ethylhexyl',
#   'methoxycinnamate',
#   'titanium',
#   'dioxide',
#   'zinc',
#   'oxide',
#   'butyl',
#   'methoxydibenzoylmethane',
#   'octocrylene',
#   'glycerin',
#   'potassium',
#   'cetyl',
#   'phosphate',
#   'cetyl',
#   'alcohol',
#   'phenylbenzimidazole',
#   'sulfonic',
#   'acid',
#   'glyceryl',
#   'stearate',
#   'peg',
#   'stearate',
#   'phenoxyethanol',
#   'acrylatesc',
#   'alkyl',
#   'acrylate',
#   'crosspolymer',
#   'triethanolamine',
#   'methylparaben',
#   'propylparaben',
#   'xanthan',
#   'gum',
#   'disodium',
#   'edta',
#   'fragrance',
#   'bht',
#   'epilobium',
#   'angustifolium',
#   'extract',
#   'cyclohexasiloxane'],
#  ['mineral',
#   'oil',
#   'vegetable',
#   'oil',
#   'amla',
#   'extract',
#   'perfume',
#   'antioxidant',
#   'tertbutylhydroquinone'],
#  ['fullers',
#   'earth',
#   'chickpea',
#   'flour',
#   'sandalwood',
#   'powder',
#   'turmeric',
#   'powder',
#   'mulberry',
#   'extract',
#   'cucumber',
#   'extract',
#   'papaya',
#   'extract',
#   'licorice',
#   'extract',
#   'carrot',
#   'seed',
#   'oil',
#   'saffron',
#   'oil',
#   'aqua',
#   'preservatives'],
#  ['water',
#   'cyclomethicone',
#   'dimethicone',
#   'crosspolymer',
#   'caprylyl',
#   'methicone',
#   'glycerine',
#   'niacinamide',
#   'sodium',
#   'pca',
#   'trehalose',
#   'sodium',
#   'hyaluronate',
#   'saxifraga',
#   'extract',
#   'grape',
#   'extract',
#   'morus',
#   'alba',
#   'root',
#   'extract',
#   'scutellaria',
#   'baicalensis',
#   'root',
#   'extract',
#   'glutathione',
#   'phenyl',
#   'ethyl',
#   'resorcinol',
#   'sodium',
#   'ascorbyl',
#   'phosphate',
#   'polysorbate',
#   'fragrance',
#   'disodium',
#   'edta',
#   'phenoxyethanol',
#   'methylparaben',
#   'propylparaben',
#   'ethylparaben',
#   'butylparaben',
#   'isobutylparaben',
#   'sodium',
#   'hydroxide'],
#  ['water',
#   'juglans',
#   'regia',
#   'glyceryl',
#   'stearate',
#   'se',
#   'propylene',
#   'glycol',
#   'cetyl',
#   'alcohol',
#   'stearic',
#   'acid',
#   'isopropyl',
#   'myristate',
#   'cetearyl',
#   'alcohol',
#   'fragrance',
#   'tocopheryl',
#   'acetate',
#   'methylparaben',
#   'propylparaben',
#   'phenoxyethanol',
#   'carbomer',
#   'sodium',
#   'hydroxide'],
#  ['purified',
#   'water',
#   'almond',
#   'oil',
#   'coconut',
#   'oil',
#   'cocoa',
#   'butter',
#   'shea',
#   'butter',
#   'bees',
#   'wax',
#   'kokum',
#   'butter',
#   'glycerin',
#   'jasmine',
#   'extract',
#   'mogra',
#   'extract',
#   'aloe',
#   'vera',
#   'vitamin',
#   'e',
#   'potassium',
#   'sorbate',
#   'sodium',
#   'benzoate',
#   'essential',
#   'oil',
#   'of',
#   'jasmine'],
#  ['sesame',
#   'oil',
#   'milk',
#   'indigo',
#   'eclipta',
#   'alba',
#   'gooseberry',
#   'balloon',
#   'vine',
#   'liquorice',
#   'madder',
#   'root',
#   'fenugreek',
#   'rosemary',
#   'himalayan',
#   'cedarwood',
#   'henna',
#   'ashwagandha',
#   'essential',
#   'oil',
#   'of',
#   'vetiver',
#   'essential',
#   'oil',
#   'of',
#   'geranium'],
#  ['castor',
#   'oil',
#   'amla',
#   'almond',
#   'oil',
#   'triphala',
#   'ghrit',
#   'kumari',
#   'damask',
#   'rose',
#   'camphor',
#   'cows',
#   'ghee'],
#  ['water',
#   'cyclopentasiloxane',
#   'ethylhexyl',
#   'methoxycinnamate',
#   'zinc',
#   'oxide',
#   'titanium',
#   'dioxide',
#   'glycerin',
#   'peg',
#   'dimethicone',
#   'methylene',
#   'bisbenzotriazolyl',
#   'tetramethylbutylphenol',
#   'butyl',
#   'methoxydibenzoylmethane',
#   'isododecane',
#   'bisethylhexyloxyphenol',
#   'methoxyphenyl',
#   'triazine',
#   'sodium',
#   'chloride',
#   'phenoxyethanol',
#   'benzyl',
#   'alcohol',
#   'acrylatesdimethicone',
#   'copolymer',
#   'triethanolamine',
#   'tocopheryl',
#   'acetate',
#   'perfume',
#   'disodium',
#   'edta',
#   'bht'],
#  ['neem',
#   'bark',
#   'chamomile',
#   'haldi',
#   'gulab',
#   'phool',
#   'water',
#   'ritha',
#   'kulanjan',
#   'madhu',
#   'coconut',
#   'oil',
#   'derivatives',
#   'purified',
#   'himalayan',
#   'water',
#   'qs'],
#  ['aloe',
#   'vera',
#   'vitamin',
#   'e',
#   'permitted',
#   'colour',
#   'fragrance',
#   'preservatives',
#   'qs'],
#  ['water',
#   'aloe',
#   'vera',
#   'leaf',
#   'juice',
#   'apricot',
#   'kernel',
#   'oil',
#   'sweet',
#   'almond',
#   'oil',
#   'emulsifying',
#   'wax',
#   'walnuts',
#   'beeswax',
#   'glycerin',
#   'cetyl',
#   'alcohol',
#   'sodium',
#   'pca',
#   'potassium',
#   'sorbate',
#   'sodium',
#   'benzoate',
#   'kokum',
#   'butter',
#   'honey',
#   'olive',
#   'oil',
#   'vitamin',
#   'e',
#   'turmeric',
#   'sandalwood',
#   'oil',
#   'geranium',
#   'oil'],
#  ['multani',
#   'mitti',
#   'geru',
#   'yasad',
#   'bhasm',
#   'tamator',
#   'ananas',
#   'seb',
#   'beheda',
#   'badam',
#   'jaiphal',
#   'kikar',
#   'gaund',
#   'paste',
#   'base',
#   'qs'],
#  ['saffron',
#   'red',
#   'sandalwood',
#   'vetiver',
#   'lotus',
#   'liquorice',
#   'turmeric',
#   'manjistha',
#   'sesame',
#   'oil',
#   'indian',
#   'madder',
#   'banyan',
#   'indian',
#   'barberry',
#   'flame',
#   'of',
#   'the',
#   'forest',
#   'mulethi',
#   'kashmiri',
#   'saffron',
#   'rose',
#   'padma',
#   'kesar',
#   'and',
#   'sesame',
#   'oil'],
#  ['neem',
#   'turmeric',
#   'water',
#   'ammonium',
#   'lauryl',
#   'sulfate',
#   'cocamidopropyl',
#   'betaine',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'sodium',
#   'lauryl',
#   'sarcosinate',
#   'glycol',
#   'distearate',
#   'decyl',
#   'glucoside',
#   'polyquaternium',
#   'citric',
#   'acid',
#   'fragrance',
#   'phenoxyethanol',
#   'methylchloroisothiazolinone',
#   'methylisothiazolinone',
#   'sodium',
#   'benzoate',
#   'potassium',
#   'sorbate',
#   'disodium',
#   'edta',
#   'and',
#   'ci'],
#  ['turmeric',
#   'extract',
#   'sandalwood',
#   'oil',
#   'sodi',
#   'biboras',
#   'borax',
#   'and',
#   'cream',
#   'base'],
#  ['onion',
#   'seed',
#   'oil',
#   'sunflower',
#   'oil',
#   'amla',
#   'oil',
#   'hibiscus',
#   'oil',
#   'bhringraj',
#   'oil',
#   'sesame',
#   'oil',
#   'castor',
#   'oil',
#   'jojoba',
#   'oil',
#   'rosemary',
#   'oil',
#   'vitamin',
#   'e',
#   'and',
#   'fragrance'],
#  ['isododecane',
#   'dimethicone',
#   'trimethylsiloxysilicate',
#   'polybutene',
#   'petrolatum',
#   'cyclohexasiloxane',
#   'kaolin',
#   'disteardimonium',
#   'hectorite',
#   'cera',
#   'alba',
#   'silica',
#   'dimethyl',
#   'silylate',
#   'synthetic',
#   'fluorphlogopite',
#   'glyceryl',
#   'behenateeicosadioate',
#   'propylene',
#   'carbonate',
#   'silica',
#   'tin',
#   'oxide',
#   'tocopherol',
#   'persea',
#   'gratissima',
#   'oil',
#   'and',
#   'ci',
#   'ci',
#   'ci',
#   'ci',
#   'ci',
#   'ci'],
#  ['chickpea',
#   'flour',
#   'almond',
#   'powder',
#   'turmeric',
#   'sandalwood',
#   'powder',
#   'fenugreek',
#   'powder',
#   'lodhra',
#   'powder',
#   'orange',
#   'peel',
#   'powder',
#   'rose',
#   'petal',
#   'powder',
#   'indian',
#   'madder',
#   'powder',
#   'licorice',
#   'root',
#   'powder',
#   'and',
#   'saffron'],
#  ['green',
#   'apple',
#   'sea',
#   'algae',
#   'extract',
#   'centella',
#   'asiatica',
#   'extract',
#   'eclipta',
#   'prostrata',
#   'extract',
#   'soap',
#   'nut',
#   'extract',
#   'musk',
#   'root',
#   'extract',
#   'grape',
#   'seed',
#   'oil',
#   'and',
#   'pure',
#   'himalayan',
#   'water'],
#  ['water',
#   'glycerin',
#   'sodium',
#   'polyacrylate',
#   'starch',
#   'alumina',
#   'methyl',
#   'paraben',
#   'propyl',
#   'paraben',
#   'arbutin',
#   'mulberry',
#   'extract',
#   'saxifraga',
#   'extract',
#   'grape',
#   'extract',
#   'milk',
#   'enzymes',
#   'and',
#   'titanium',
#   'dioxide'],
#  ['saffron',
#   'kumkumadi',
#   'tailam',
#   'manjistha',
#   'lodhra',
#   'turmeric',
#   'and',
#   'kumari'],
#  ['aqua',
#   'caprylylcapryl',
#   'glucoside',
#   'sodium',
#   'lauroyl',
#   'glutamate',
#   'coco',
#   'glucoside',
#   'glyceryl',
#   'oleate',
#   'sodium',
#   'pca',
#   'xylitylglucoside',
#   'anhydroxylitol',
#   'xylitol',
#   'sodium',
#   'levulinate',
#   'potassium',
#   'sorbate',
#   'sodium',
#   'gluconate',
#   'betaine',
#   'aloe',
#   'vera',
#   'juice',
#   'rosa',
#   'damascena',
#   'flower',
#   'oil',
#   'and',
#   'jasminum',
#   'grandiflorum',
#   'flower',
#   'extract'],
#  ['water',
#   'ammonium',
#   'lauryl',
#   'sulfate',
#   'cocamidopropyl',
#   'betaine',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'sodium',
#   'lauryl',
#   'sulfate',
#   'glycerin',
#   'glycol',
#   'distearate',
#   'acrylatesc',
#   'alkyl',
#   'acrylate',
#   'crosspolymer',
#   'polyquaternium',
#   'phenoxyethanol',
#   'sodium',
#   'hydroxide',
#   'fragrance',
#   'azadirachta',
#   'indica',
#   'and',
#   'curcuma',
#   'longa'],
#  ['aloe',
#   'vera',
#   'juice',
#   'rosa',
#   'centifolia',
#   'ocimum',
#   'basilicum',
#   'santalum',
#   'album',
#   'and',
#   'aqua'],
#  ['kokum',
#   'butter',
#   'organic',
#   'beeswax',
#   'organic',
#   'honey',
#   'aloe',
#   'vera',
#   'juice',
#   'mulethi',
#   'extract',
#   'fennel',
#   'extract',
#   'lodhra',
#   'extract',
#   'lemon',
#   'peel',
#   'extract',
#   'orange',
#   'peel',
#   'extract',
#   'sandalwood',
#   'oil',
#   'rose',
#   'oil',
#   'saffron',
#   'extract',
#   'and',
#   'turmeric',
#   'oil'],
#  ['purified',
#   'water',
#   'sodium',
#   'lauroyl',
#   'sarcosinate',
#   'disodium',
#   'cocoamphodiacetate',
#   'glycerin',
#   'sodium',
#   'pca',
#   'sodium',
#   'lactate',
#   'tea',
#   'tree',
#   'oil',
#   'allantoin',
#   'xanthan',
#   'gum',
#   'vitamin',
#   'e',
#   'and',
#   'lavender',
#   'oil'],
#  ['honey',
#   'aloe',
#   'vera',
#   'neem',
#   'leaf',
#   'extract',
#   'turmeric',
#   'extract',
#   'and',
#   'rose',
#   'extract'],
#  ['rosa', 'damascena', 'flower', 'distillate'],
#  ['water',
#   'talc',
#   'cyclomethicone',
#   'octyl',
#   'methoxy',
#   'cinnamate',
#   'butyl',
#   'methoxydibenzoylmethane',
#   'benzophenone',
#   'phenoxyethanol',
#   'methylparaben',
#   'propylparaben',
#   'ethylhexyl',
#   'methoxycinnamate',
#   'perfume',
#   'allantoin',
#   'and',
#   'polysorbate'],
#  ['surajmukhi',
#   'oil',
#   'badam',
#   'oil',
#   'arandi',
#   'oil',
#   'neem',
#   'oil',
#   'soy',
#   'lecithin',
#   'vitamin',
#   'e',
#   'and',
#   'cleanser',
#   'base',
#   'qs'],
#  ['water',
#   'glycerin',
#   'propylene',
#   'glycol',
#   'niacinamide',
#   'glycyrrhiza',
#   'glabra',
#   'punica',
#   'granatum',
#   'morus',
#   'nigra',
#   'arctostaphylos',
#   'uva',
#   'ursi',
#   'lactic',
#   'acid',
#   'polysorbate',
#   'xanthan',
#   'gum',
#   'phenoxyethanol',
#   'and',
#   'methylparaben'],
#  ['purified',
#   'water',
#   'cold',
#   'pressed',
#   'organic',
#   'oils',
#   'of',
#   'coconut',
#   'almond',
#   'and',
#   'wheat',
#   'germ',
#   'beeswax',
#   'kokum',
#   'butter',
#   'ghee',
#   'honey',
#   'mulethi',
#   'sandalwood',
#   'oil',
#   'and',
#   'k',
#   'gold',
#   'bhasma'],
#  ['water',
#   'ammonium',
#   'lauryl',
#   'sulfate',
#   'cocamidopropyl',
#   'betaine',
#   'sodium',
#   'cocoyl',
#   'glutamate',
#   'sodium',
#   'lauryl',
#   'sulfoacetate',
#   'glycerin',
#   'polysorbate',
#   'azadirachta',
#   'indica',
#   'peg',
#   'distearate',
#   'fragrance',
#   'phenoxyethanol',
#   'caprylyl',
#   'glycol',
#   'sodium',
#   'benzoate',
#   'and',
#   'citric',
#   'acid'],
#  ['aloe',
#   'vera',
#   'base',
#   'material',
#   'qs',
#   'vitamin',
#   'e',
#   'and',
#   'permitted',
#   'color'],
#  ['extracts',
#   'of',
#   'neem',
#   'long',
#   'pepper',
#   'red',
#   'sandalwood',
#   'and',
#   'tea',
#   'tree',
#   'oil',
#   'clove',
#   'oil',
#   'camphor',
#   'zinc',
#   'oxide',
#   'and',
#   'cream',
#   'base',
#   'qs']]

# %% [markdown]
# ## Sort feature by Occurence

# %%
occurences = {}
for indx, ingdOf1 in enumerate(seprdIngdList):
    for ingd in ingdOf1:
        if(occurences.__contains__(ingd)):
            occurences[ingd] += 1
        else:
            occurences[ingd] = 1
        
occurences
# Out:
# {'water': 49,
#  'ammonium': 7,
#  'lauryl': 25,
#  'sulfate': 12,
#  'cocamidopropyl': 9,
#  'betaine': 11,
#  'sodium': 93,
#  'cocoyl': 9,
#  'glutamate': 10,
#  'glycerin': 33,
#  'lauroyl': 6,
#  'sarcosinate': 5,
#  'glycol': 18,
#  'distearate': 8,
#  'decyl': 10,
#  'glucoside': 18,
#  'peg': 7,
#  'glucose': 3,
#  'carboxylate': 3,
#  'fragrance': 29,
#  'phenoxyethanol': 22,
#  'benzoate': 18,
#  'azadirachta': 6,
#  'indica': 4,
#  'melia': 2,
#  'citrate': 2,
#  'citric': 14,
#  'acid': 30,
#  'butylene': 3,
#  'tocopheryl': 10,
#  'acetate': 12,
#  'ci': 20,
#  'turmeric': 22,
#  'extract': 81,
#  'sandalwood': 21,
#  'oil': 98,
#  'stearic': 7,
#  'sorbitol': 3,
#  'hydroxide': 13,
#  'methyl': 7,
#  'paraben': 13,
#  'propyl': 6,
#  'coconut': 5,
#  'dugdh': 1,
#  'manjistha': 4,
#  'nimba': 1,
#  'kamla': 1,
#  'badam': 3,
#  'tail': 1,
#  'cream': 5,
#  'base': 15,
#  'qs': 17,
#  'phenylbenzimidazole': 4,
#  'sulfonic': 4,
#  'oxybenzone': 1,
#  'octyl': 4,
#  'methoxy': 4,
#  'cinnamate': 4,
#  'cyclopentasiloxane': 8,
#  'acrylatesc': 5,
#  'alkyl': 5,
#  'acrylate': 5,
#  'crosspolymer': 8,
#  'triethanolamine': 10,
#  'polysorbate': 7,
#  'carbomer': 9,
#  'disodium': 13,
#  'edta': 11,
#  'vitamin': 19,
#  'e': 18,
#  'methi': 3,
#  'seed': 11,
#  'bhringraj': 5,
#  'nagarmotha': 1,
#  'amla': 6,
#  'reetha': 3,
#  'madhu': 5,
#  'kikar': 2,
#  'gond': 1,
#  'vanilla': 2,
#  'purified': 12,
#  'cyclomethicone': 3,
#  'aqua': 12,
#  'talc': 3,
#  'isotridecyl': 1,
#  'isononanoate': 1,
#  'cetyl': 11,
#  'pegppg': 1,
#  'dimethicone': 11,
#  'hditrimethylol': 1,
#  'hexyllactone': 1,
#  'phenyl': 2,
#  'trimethicone': 1,
#  'chloride': 7,
#  'acrylatesdimethicone': 2,
#  'copolymer': 6,
#  'methylparaben': 19,
#  'ethylparaben': 2,
#  'propylparaben': 18,
#  'parfum': 2,
#  'hyaluronate': 2,
#  'butylphenyl': 2,
#  'methylpropional': 2,
#  'citronellol': 2,
#  'hexyl': 2,
#  'cinnamal': 2,
#  'limonene': 2,
#  'linalool': 3,
#  'alphaisomethyl': 2,
#  'ionone': 2,
#  'may': 2,
#  'contain': 2,
#  'cl': 10,
#  'aloe': 26,
#  'vera': 25,
#  'material': 5,
#  'walnut': 2,
#  'shell': 2,
#  'powder': 33,
#  'apricot': 2,
#  'kernel': 3,
#  'sweet': 3,
#  'almond': 13,
#  'kokum': 8,
#  'butter': 12,
#  'sesame': 8,
#  'beeswax': 6,
#  'avocado': 1,
#  'kumkumadi': 2,
#  'saffron': 14,
#  'flower': 7,
#  'grapefruit': 1,
#  'potassium': 16,
#  'sorbate': 15,
#  'essential': 7,
#  'oils': 5,
#  'of': 13,
#  'rose': 12,
#  'jasmine': 4,
#  'and': 31,
#  'lotus': 5,
#  'natural': 2,
#  'steam': 1,
#  'distilled': 1,
#  'pure': 2,
#  'rosewater': 1,
#  'chamomile': 2,
#  'gel': 4,
#  'wheat': 8,
#  'germ': 4,
#  'carrot': 2,
#  'zinc': 7,
#  'oxide': 9,
#  'titanium': 10,
#  'dioxide': 10,
#  'avobenzone': 1,
#  'octylmethoxy': 1,
#  'micronized': 1,
#  'allantoin': 8,
#  'calcium': 2,
#  'carbonate': 3,
#  'sulphate': 7,
#  'flavour': 1,
#  'indian': 6,
#  'licorice': 6,
#  'root': 10,
#  'gum': 12,
#  'tragacanth': 1,
#  'carrageenan': 1,
#  'clove': 2,
#  'eucalyptus': 1,
#  'saccharin': 1,
#  'ether': 4,
#  'propylene': 8,
#  'acrylates': 1,
#  'cocoglucoside': 2,
#  'niacinamide': 3,
#  'glycolic': 1,
#  'pca': 8,
#  'camellia': 1,
#  'sinensis': 1,
#  'morus': 3,
#  'alba': 4,
#  'bht': 4,
#  'methylchloroisothiazolinone': 3,
#  'methylisothiazolinone': 3,
#  'capryliccapric': 4,
#  'triglyceride': 4,
#  'polyglyceryl': 1,
#  'methylglucose': 1,
#  'glyceryl': 14,
#  'stearate': 10,
#  'alcohol': 15,
#  'isopropyl': 6,
#  'myristate': 6,
#  'simmondsia': 1,
#  'chinensis': 1,
#  'triticum': 1,
#  'vulgare': 1,
#  'prunus': 2,
#  'amygdalus': 2,
#  'dulcis': 2,
#  'butyrospermum': 1,
#  'parkii': 1,
#  'hedychium': 1,
#  'spicatum': 1,
#  'citrus': 1,
#  'medica': 1,
#  'limonum': 1,
#  'malus': 1,
#  'domestica': 1,
#  'vitis': 1,
#  'vinifera': 1,
#  'barbadensis': 1,
#  'tocopherol': 4,
#  'xanthan': 9,
#  'ethylhexylglycerin': 2,
#  'multani': 4,
#  'mitti': 4,
#  'calamine': 2,
#  'kaolin': 6,
#  'fullers': 5,
#  'earth': 5,
#  'chickpea': 3,
#  'flour': 3,
#  'neem': 13,
#  'leaf': 6,
#  'mulethi': 6,
#  'orange': 10,
#  'nagkesar': 3,
#  'sunflower': 3,
#  'juice': 6,
#  'honey': 10,
#  'kulanjan': 2,
#  'rhizome': 1,
#  'ankurit': 2,
#  'gehun': 2,
#  'paraffinum': 1,
#  'liquidum': 1,
#  'isohexadecane': 2,
#  'cetearyl': 3,
#  'geraniol': 1,
#  'benzyl': 3,
#  'papaya': 4,
#  'scrub': 1,
#  'solum': 1,
#  'fullonum': 1,
#  'cucumber': 5,
#  'glycerine': 2,
#  'cellulose': 1,
#  'peach': 1,
#  'massage': 1,
#  'olive': 2,
#  'antitan': 1,
#  'pack': 1,
#  'peel': 8,
#  'bentonite': 2,
#  'manjishta': 1,
#  'ghritkumari': 2,
#  'kesar': 3,
#  'akarkara': 1,
#  'anantmool': 4,
#  'durva': 2,
#  'daruhaldi': 1,
#  'lodhra': 5,
#  'tulsi': 2,
#  'pudina': 2,
#  'ka': 1,
#  'phool': 2,
#  'sugandhit': 3,
#  'dravya': 2,
#  'trimethylsiloxysilicate': 3,
#  'polyethylene': 2,
#  'mica': 2,
#  'lysine': 1,
#  'ozokerite': 1,
#  'octyldodecanol': 1,
#  'disteardimonium': 2,
#  'hectorite': 2,
#  'aluminum': 2,
#  'borosilicate': 1,
#  'tin': 2,
#  'butyl': 4,
#  'dibenzoyl': 1,
#  'methane': 1,
#  'benzophenone': 3,
#  'polyacrylamide': 1,
#  'c': 1,
#  'isoparaffin': 1,
#  'laureth': 5,
#  'perfume': 8,
#  'fennel': 2,
#  'star': 1,
#  'anise': 1,
#  'fenugreek': 5,
#  'cocamphodiacetate': 1,
#  'extracts': 4,
#  'vetiver': 6,
#  'madder': 5,
#  'bael': 1,
#  'aquawater': 1,
#  'cocobetaine': 2,
#  'guar': 2,
#  'hydroxypropyltrimonium': 4,
#  'cocamide': 2,
#  'mipa': 2,
#  'hydrolyzed': 2,
#  'protein': 6,
#  'ppgceteth': 1,
#  'arginine': 1,
#  'salicylic': 2,
#  'polyquaternium': 4,
#  'salicylate': 1,
#  'oleamido': 1,
#  'octadecanediol': 1,
#  'serine': 1,
#  'glutamic': 1,
#  'linoleate': 1,
#  'oleate': 3,
#  'linolenate': 1,
#  'parfumfragrance': 1,
#  'borax': 3,
#  'green': 3,
#  'apple': 4,
#  'centella': 3,
#  'sea': 3,
#  'algae': 3,
#  'himalayan': 5,
#  'sles': 1,
#  'derived': 1,
#  'neutral': 1,
#  'thickener': 1,
#  'polyquaterium': 1,
#  'preservative': 1,
#  'blend': 1,
#  'bentone': 1,
#  'acacia': 1,
#  'preservatives': 4,
#  'isododecane': 3,
#  'synthetic': 2,
#  'wax': 5,
#  'hydrogenated': 3,
#  'polydicyclopentadiene': 1,
#  'ethylenepropylene': 1,
#  'bisdiglyceryl': 1,
#  'polyacyladipate': 1,
#  'styrenemethyl': 1,
#  'styreneindene': 1,
#  'silica': 3,
#  'polybutene': 2,
#  'pentaerythrityl': 1,
#  'tetraditbutyl': 1,
#  'hydroxyhydrocinnamate': 1,
#  'cococaprylatecaprate': 1,
#  'nanoblack': 1,
#  'ultramarines': 1,
#  'iron': 3,
#  'oxides': 3,
#  'kiehls': 1,
#  'clearly': 1,
#  'corrective': 1,
#  'dark': 1,
#  'spot': 1,
#  'solution': 1,
#  'cocoamidopropyl': 2,
#  'betain': 1,
#  'lactate': 2,
#  'soy': 3,
#  'coco': 2,
#  'patchouli': 2,
#  'lavender': 5,
#  'geranium': 4,
#  'hibiscus': 5,
#  'shikakai': 2,
#  'lemon': 2,
#  'caprylyl': 4,
#  'certified': 1,
#  'organic': 7,
#  'ingredient': 1,
#  'brahmi': 2,
#  'nettle': 1,
#  'cinnamon': 2,
#  'bay': 1,
#  'vegetable': 3,
#  'silk': 1,
#  'amino': 1,
#  'acids': 1,
#  'inositol': 1,
#  'lemongrass': 1,
#  'peppermint': 1,
#  'ghrit': 3,
#  'kumari': 4,
#  'rosa': 5,
#  'cyclohexasiloxane': 4,
#  'methoxycinnamate': 5,
#  'geru': 2,
#  'yasad': 2,
#  'bhasm': 2,
#  'tomato': 1,
#  'pineapple': 1,
#  'chandan': 2,
#  'permitted': 3,
#  'colour': 2,
#  'levulinate': 2,
#  'anisate': 1,
#  'onion': 2,
#  'rosemary': 3,
#  'kashmiri': 2,
#  'castor': 3,
#  'manjishtha': 2,
#  'padmakashtha': 1,
#  'scented': 1,
#  'china': 1,
#  'clay': 1,
#  'activated': 1,
#  'charcoal': 1,
#  'tea': 3,
#  'tree': 3,
#  'calendula': 1,
#  'camphor': 3,
#  'metabisulfite': 1,
#  'haldi': 2,
#  'soap': 2,
#  'desi': 1,
#  'cows': 3,
#  'milk': 5,
#  'ghee': 3,
#  'raw': 1,
#  'light': 1,
#  'liquid': 1,
#  'paraffin': 1,
#  'polyisobutene': 1,
#  'arbutin': 2,
#  'behenyl': 1,
#  'ascorbyl': 2,
#  'phosphate': 3,
#  'kusumbhi': 1,
#  'vach': 1,
#  'lotion': 1,
#  'mineral': 2,
#  'emulsifying': 2,
#  'carbopol': 1,
#  'diazolidinyl': 2,
#  'urea': 2,
#  'iodopropynyl': 1,
#  'butylcarbamate': 1,
#  'a': 1,
#  'dravyaqs': 1,
#  'dea': 1,
#  'ethylhexyl': 4,
#  'acrylatesodium': 1,
#  'acryloyldimethyl': 1,
#  'taurate': 1,
#  'trimethylolpropane': 1,
#  'aluminium': 1,
#  'curcuma': 2,
#  'longa': 2,
#  'ashwagandha': 2,
#  'yashtimadhu': 1,
#  'shea': 2,
#  'bees': 2,
#  'karat': 1,
#  'gold': 2,
#  'bhasma': 2,
#  'mogra': 2,
#  'spf': 1,
#  'damascena': 3,
#  'cocoamide': 1,
#  'hexylene': 1,
#  'argania': 1,
#  'spinosa': 1,
#  'methoxydibenzoylmethane': 3,
#  'octocrylene': 1,
#  'epilobium': 1,
#  'angustifolium': 1,
#  'antioxidant': 1,
#  'tertbutylhydroquinone': 1,
#  'mulberry': 2,
#  'methicone': 1,
#  'trehalose': 1,
#  'saxifraga': 2,
#  'grape': 3,
#  'scutellaria': 1,
#  'baicalensis': 1,
#  'glutathione': 1,
#  'ethyl': 1,
#  'resorcinol': 1,
#  'butylparaben': 1,
#  'isobutylparaben': 1,
#  'juglans': 1,
#  'regia': 1,
#  'se': 1,
#  'cocoa': 1,
#  'indigo': 1,
#  'eclipta': 2,
#  'gooseberry': 1,
#  'balloon': 1,
#  'vine': 1,
#  'liquorice': 2,
#  'cedarwood': 1,
#  'henna': 1,
#  'triphala': 1,
#  'damask': 1,
#  'methylene': 1,
#  'bisbenzotriazolyl': 1,
#  'tetramethylbutylphenol': 1,
#  'bisethylhexyloxyphenol': 1,
#  'methoxyphenyl': 1,
#  'triazine': 1,
#  'bark': 1,
#  'gulab': 1,
#  'ritha': 1,
#  'derivatives': 1,
#  'walnuts': 1,
#  'tamator': 1,
#  'ananas': 1,
#  'seb': 1,
#  'beheda': 1,
#  'jaiphal': 1,
#  'gaund': 1,
#  'paste': 1,
#  'red': 2,
#  'banyan': 1,
#  'barberry': 1,
#  'flame': 1,
#  'the': 1,
#  'forest': 1,
#  'padma': 1,
#  'sodi': 1,
#  'biboras': 1,
#  'jojoba': 1,
#  'petrolatum': 1,
#  'cera': 1,
#  'dimethyl': 1,
#  'silylate': 1,
#  'fluorphlogopite': 1,
#  'behenateeicosadioate': 1,
#  'persea': 1,
#  'gratissima': 1,
#  'petal': 1,
#  'asiatica': 1,
#  'prostrata': 1,
#  'nut': 1,
#  'musk': 1,
#  'polyacrylate': 1,
#  'starch': 1,
#  'alumina': 1,
#  'enzymes': 1,
#  'tailam': 1,
#  'caprylylcapryl': 1,
#  'xylitylglucoside': 1,
#  'anhydroxylitol': 1,
#  'xylitol': 1,
#  'gluconate': 1,
#  'jasminum': 1,
#  'grandiflorum': 1,
#  'centifolia': 1,
#  'ocimum': 1,
#  'basilicum': 1,
#  'santalum': 1,
#  'album': 1,
#  'cocoamphodiacetate': 1,
#  'distillate': 1,
#  'surajmukhi': 1,
#  'arandi': 1,
#  'lecithin': 1,
#  'cleanser': 1,
#  'glycyrrhiza': 1,
#  'glabra': 1,
#  'punica': 1,
#  'granatum': 1,
#  'nigra': 1,
#  'arctostaphylos': 1,
#  'uva': 1,
#  'ursi': 1,
#  'lactic': 1,
#  'cold': 1,
#  'pressed': 1,
#  'k': 1,
#  'sulfoacetate': 1,
#  'color': 1,
#  'long': 1,
#  'pepper': 1}

# %%
len(occurences.keys())
# Out:
# 583

# %%
# sort dictionary by value in descending order
sorted_occurences = {k: v for k, v in sorted(occurences.items(), key=lambda item: item[1], reverse=True)}

# %%
(sorted_occurences)
# Out:
# {'oil': 98,
#  'sodium': 93,
#  'extract': 81,
#  'water': 49,
#  'glycerin': 33,
#  'powder': 33,
#  'and': 31,
#  'acid': 30,
#  'fragrance': 29,
#  'aloe': 26,
#  'lauryl': 25,
#  'vera': 25,
#  'phenoxyethanol': 22,
#  'turmeric': 22,
#  'sandalwood': 21,
#  'ci': 20,
#  'vitamin': 19,
#  'methylparaben': 19,
#  'glycol': 18,
#  'glucoside': 18,
#  'benzoate': 18,
#  'e': 18,
#  'propylparaben': 18,
#  'qs': 17,
#  'potassium': 16,
#  'base': 15,
#  'sorbate': 15,
#  'alcohol': 15,
#  'citric': 14,
#  'saffron': 14,
#  'glyceryl': 14,
#  'hydroxide': 13,
#  'paraben': 13,
#  'disodium': 13,
#  'almond': 13,
#  'of': 13,
#  'neem': 13,
#  'sulfate': 12,
#  'acetate': 12,
#  'purified': 12,
#  'aqua': 12,
#  'butter': 12,
#  'rose': 12,
#  'gum': 12,
#  'betaine': 11,
#  'edta': 11,
#  'seed': 11,
#  'cetyl': 11,
#  'dimethicone': 11,
#  'glutamate': 10,
#  'decyl': 10,
#  'tocopheryl': 10,
#  'triethanolamine': 10,
#  'cl': 10,
#  'titanium': 10,
#  'dioxide': 10,
#  'root': 10,
#  'stearate': 10,
#  'orange': 10,
#  'honey': 10,
#  'cocamidopropyl': 9,
#  'cocoyl': 9,
#  'carbomer': 9,
#  'oxide': 9,
#  'xanthan': 9,
#  'distearate': 8,
#  'cyclopentasiloxane': 8,
#  'crosspolymer': 8,
#  'kokum': 8,
#  'sesame': 8,
#  'wheat': 8,
#  'allantoin': 8,
#  'propylene': 8,
#  'pca': 8,
#  'peel': 8,
#  'perfume': 8,
#  'ammonium': 7,
#  'peg': 7,
#  'stearic': 7,
#  'methyl': 7,
#  'polysorbate': 7,
#  'chloride': 7,
#  'flower': 7,
#  'essential': 7,
#  'zinc': 7,
#  'sulphate': 7,
#  'organic': 7,
#  'lauroyl': 6,
#  'azadirachta': 6,
#  'propyl': 6,
#  'amla': 6,
#  'copolymer': 6,
#  'beeswax': 6,
#  'indian': 6,
#  'licorice': 6,
#  'isopropyl': 6,
#  'myristate': 6,
#  'kaolin': 6,
#  'leaf': 6,
#  'mulethi': 6,
#  'juice': 6,
#  'vetiver': 6,
#  'protein': 6,
#  'sarcosinate': 5,
#  'coconut': 5,
#  'cream': 5,
#  'acrylatesc': 5,
#  'alkyl': 5,
#  'acrylate': 5,
#  'bhringraj': 5,
#  'madhu': 5,
#  'material': 5,
#  'oils': 5,
#  'lotus': 5,
#  'fullers': 5,
#  'earth': 5,
#  'cucumber': 5,
#  'lodhra': 5,
#  'laureth': 5,
#  'fenugreek': 5,
#  'madder': 5,
#  'himalayan': 5,
#  'wax': 5,
#  'lavender': 5,
#  'hibiscus': 5,
#  'rosa': 5,
#  'methoxycinnamate': 5,
#  'milk': 5,
#  'indica': 4,
#  'manjistha': 4,
#  'phenylbenzimidazole': 4,
#  'sulfonic': 4,
#  'octyl': 4,
#  'methoxy': 4,
#  'cinnamate': 4,
#  'jasmine': 4,
#  'gel': 4,
#  'germ': 4,
#  'ether': 4,
#  'alba': 4,
#  'bht': 4,
#  'capryliccapric': 4,
#  'triglyceride': 4,
#  'tocopherol': 4,
#  'multani': 4,
#  'mitti': 4,
#  'papaya': 4,
#  'anantmool': 4,
#  'butyl': 4,
#  'extracts': 4,
#  'hydroxypropyltrimonium': 4,
#  'polyquaternium': 4,
#  'apple': 4,
#  'preservatives': 4,
#  'geranium': 4,
#  'caprylyl': 4,
#  'kumari': 4,
#  'cyclohexasiloxane': 4,
#  'ethylhexyl': 4,
#  'glucose': 3,
#  'carboxylate': 3,
#  'butylene': 3,
#  'sorbitol': 3,
#  'badam': 3,
#  'methi': 3,
#  'reetha': 3,
#  'cyclomethicone': 3,
#  'talc': 3,
#  'linalool': 3,
#  'kernel': 3,
#  'sweet': 3,
#  'carbonate': 3,
#  'niacinamide': 3,
#  'morus': 3,
#  'methylchloroisothiazolinone': 3,
#  'methylisothiazolinone': 3,
#  'chickpea': 3,
#  'flour': 3,
#  'nagkesar': 3,
#  'sunflower': 3,
#  'cetearyl': 3,
#  'benzyl': 3,
#  'kesar': 3,
#  'sugandhit': 3,
#  'trimethylsiloxysilicate': 3,
#  'benzophenone': 3,
#  'oleate': 3,
#  'borax': 3,
#  'green': 3,
#  'centella': 3,
#  'sea': 3,
#  'algae': 3,
#  'isododecane': 3,
#  'hydrogenated': 3,
#  'silica': 3,
#  'iron': 3,
#  'oxides': 3,
#  'soy': 3,
#  'vegetable': 3,
#  'ghrit': 3,
#  'permitted': 3,
#  'rosemary': 3,
#  'castor': 3,
#  'tea': 3,
#  'tree': 3,
#  'camphor': 3,
#  'cows': 3,
#  'ghee': 3,
#  'phosphate': 3,
#  'damascena': 3,
#  'methoxydibenzoylmethane': 3,
#  'grape': 3,
#  'melia': 2,
#  'citrate': 2,
#  'kikar': 2,
#  'vanilla': 2,
#  'phenyl': 2,
#  'acrylatesdimethicone': 2,
#  'ethylparaben': 2,
#  'parfum': 2,
#  'hyaluronate': 2,
#  'butylphenyl': 2,
#  'methylpropional': 2,
#  'citronellol': 2,
#  'hexyl': 2,
#  'cinnamal': 2,
#  'limonene': 2,
#  'alphaisomethyl': 2,
#  'ionone': 2,
#  'may': 2,
#  'contain': 2,
#  'walnut': 2,
#  'shell': 2,
#  'apricot': 2,
#  'kumkumadi': 2,
#  'natural': 2,
#  'pure': 2,
#  'chamomile': 2,
#  'carrot': 2,
#  'calcium': 2,
#  'clove': 2,
#  'cocoglucoside': 2,
#  'prunus': 2,
#  'amygdalus': 2,
#  'dulcis': 2,
#  'ethylhexylglycerin': 2,
#  'calamine': 2,
#  'kulanjan': 2,
#  'ankurit': 2,
#  'gehun': 2,
#  'isohexadecane': 2,
#  'glycerine': 2,
#  'olive': 2,
#  'bentonite': 2,
#  'ghritkumari': 2,
#  'durva': 2,
#  'tulsi': 2,
#  'pudina': 2,
#  'phool': 2,
#  'dravya': 2,
#  'polyethylene': 2,
#  'mica': 2,
#  'disteardimonium': 2,
#  'hectorite': 2,
#  'aluminum': 2,
#  'tin': 2,
#  'fennel': 2,
#  'cocobetaine': 2,
#  'guar': 2,
#  'cocamide': 2,
#  'mipa': 2,
#  'hydrolyzed': 2,
#  'salicylic': 2,
#  'synthetic': 2,
#  'polybutene': 2,
#  'cocoamidopropyl': 2,
#  'lactate': 2,
#  'coco': 2,
#  'patchouli': 2,
#  'shikakai': 2,
#  'lemon': 2,
#  'brahmi': 2,
#  'cinnamon': 2,
#  'geru': 2,
#  'yasad': 2,
#  'bhasm': 2,
#  'chandan': 2,
#  'colour': 2,
#  'levulinate': 2,
#  'onion': 2,
#  'kashmiri': 2,
#  'manjishtha': 2,
#  'haldi': 2,
#  'soap': 2,
#  'arbutin': 2,
#  'ascorbyl': 2,
#  'mineral': 2,
#  'emulsifying': 2,
#  'diazolidinyl': 2,
#  'urea': 2,
#  'curcuma': 2,
#  'longa': 2,
#  'ashwagandha': 2,
#  'shea': 2,
#  'bees': 2,
#  'gold': 2,
#  'bhasma': 2,
#  'mogra': 2,
#  'mulberry': 2,
#  'saxifraga': 2,
#  'eclipta': 2,
#  'liquorice': 2,
#  'red': 2,
#  'dugdh': 1,
#  'nimba': 1,
#  'kamla': 1,
#  'tail': 1,
#  'oxybenzone': 1,
#  'nagarmotha': 1,
#  'gond': 1,
#  'isotridecyl': 1,
#  'isononanoate': 1,
#  'pegppg': 1,
#  'hditrimethylol': 1,
#  'hexyllactone': 1,
#  'trimethicone': 1,
#  'avocado': 1,
#  'grapefruit': 1,
#  'steam': 1,
#  'distilled': 1,
#  'rosewater': 1,
#  'avobenzone': 1,
#  'octylmethoxy': 1,
#  'micronized': 1,
#  'flavour': 1,
#  'tragacanth': 1,
#  'carrageenan': 1,
#  'eucalyptus': 1,
#  'saccharin': 1,
#  'acrylates': 1,
#  'glycolic': 1,
#  'camellia': 1,
#  'sinensis': 1,
#  'polyglyceryl': 1,
#  'methylglucose': 1,
#  'simmondsia': 1,
#  'chinensis': 1,
#  'triticum': 1,
#  'vulgare': 1,
#  'butyrospermum': 1,
#  'parkii': 1,
#  'hedychium': 1,
#  'spicatum': 1,
#  'citrus': 1,
#  'medica': 1,
#  'limonum': 1,
#  'malus': 1,
#  'domestica': 1,
#  'vitis': 1,
#  'vinifera': 1,
#  'barbadensis': 1,
#  'rhizome': 1,
#  'paraffinum': 1,
#  'liquidum': 1,
#  'geraniol': 1,
#  'scrub': 1,
#  'solum': 1,
#  'fullonum': 1,
#  'cellulose': 1,
#  'peach': 1,
#  'massage': 1,
#  'antitan': 1,
#  'pack': 1,
#  'manjishta': 1,
#  'akarkara': 1,
#  'daruhaldi': 1,
#  'ka': 1,
#  'lysine': 1,
#  'ozokerite': 1,
#  'octyldodecanol': 1,
#  'borosilicate': 1,
#  'dibenzoyl': 1,
#  'methane': 1,
#  'polyacrylamide': 1,
#  'c': 1,
#  'isoparaffin': 1,
#  'star': 1,
#  'anise': 1,
#  'cocamphodiacetate': 1,
#  'bael': 1,
#  'aquawater': 1,
#  'ppgceteth': 1,
#  'arginine': 1,
#  'salicylate': 1,
#  'oleamido': 1,
#  'octadecanediol': 1,
#  'serine': 1,
#  'glutamic': 1,
#  'linoleate': 1,
#  'linolenate': 1,
#  'parfumfragrance': 1,
#  'sles': 1,
#  'derived': 1,
#  'neutral': 1,
#  'thickener': 1,
#  'polyquaterium': 1,
#  'preservative': 1,
#  'blend': 1,
#  'bentone': 1,
#  'acacia': 1,
#  'polydicyclopentadiene': 1,
#  'ethylenepropylene': 1,
#  'bisdiglyceryl': 1,
#  'polyacyladipate': 1,
#  'styrenemethyl': 1,
#  'styreneindene': 1,
#  'pentaerythrityl': 1,
#  'tetraditbutyl': 1,
#  'hydroxyhydrocinnamate': 1,
#  'cococaprylatecaprate': 1,
#  'nanoblack': 1,
#  'ultramarines': 1,
#  'kiehls': 1,
#  'clearly': 1,
#  'corrective': 1,
#  'dark': 1,
#  'spot': 1,
#  'solution': 1,
#  'betain': 1,
#  'certified': 1,
#  'ingredient': 1,
#  'nettle': 1,
#  'bay': 1,
#  'silk': 1,
#  'amino': 1,
#  'acids': 1,
#  'inositol': 1,
#  'lemongrass': 1,
#  'peppermint': 1,
#  'tomato': 1,
#  'pineapple': 1,
#  'anisate': 1,
#  'padmakashtha': 1,
#  'scented': 1,
#  'china': 1,
#  'clay': 1,
#  'activated': 1,
#  'charcoal': 1,
#  'calendula': 1,
#  'metabisulfite': 1,
#  'desi': 1,
#  'raw': 1,
#  'light': 1,
#  'liquid': 1,
#  'paraffin': 1,
#  'polyisobutene': 1,
#  'behenyl': 1,
#  'kusumbhi': 1,
#  'vach': 1,
#  'lotion': 1,
#  'carbopol': 1,
#  'iodopropynyl': 1,
#  'butylcarbamate': 1,
#  'a': 1,
#  'dravyaqs': 1,
#  'dea': 1,
#  'acrylatesodium': 1,
#  'acryloyldimethyl': 1,
#  'taurate': 1,
#  'trimethylolpropane': 1,
#  'aluminium': 1,
#  'yashtimadhu': 1,
#  'karat': 1,
#  'spf': 1,
#  'cocoamide': 1,
#  'hexylene': 1,
#  'argania': 1,
#  'spinosa': 1,
#  'octocrylene': 1,
#  'epilobium': 1,
#  'angustifolium': 1,
#  'antioxidant': 1,
#  'tertbutylhydroquinone': 1,
#  'methicone': 1,
#  'trehalose': 1,
#  'scutellaria': 1,
#  'baicalensis': 1,
#  'glutathione': 1,
#  'ethyl': 1,
#  'resorcinol': 1,
#  'butylparaben': 1,
#  'isobutylparaben': 1,
#  'juglans': 1,
#  'regia': 1,
#  'se': 1,
#  'cocoa': 1,
#  'indigo': 1,
#  'gooseberry': 1,
#  'balloon': 1,
#  'vine': 1,
#  'cedarwood': 1,
#  'henna': 1,
#  'triphala': 1,
#  'damask': 1,
#  'methylene': 1,
#  'bisbenzotriazolyl': 1,
#  'tetramethylbutylphenol': 1,
#  'bisethylhexyloxyphenol': 1,
#  'methoxyphenyl': 1,
#  'triazine': 1,
#  'bark': 1,
#  'gulab': 1,
#  'ritha': 1,
#  'derivatives': 1,
#  'walnuts': 1,
#  'tamator': 1,
#  'ananas': 1,
#  'seb': 1,
#  'beheda': 1,
#  'jaiphal': 1,
#  'gaund': 1,
#  'paste': 1,
#  'banyan': 1,
#  'barberry': 1,
#  'flame': 1,
#  'the': 1,
#  'forest': 1,
#  'padma': 1,
#  'sodi': 1,
#  'biboras': 1,
#  'jojoba': 1,
#  'petrolatum': 1,
#  'cera': 1,
#  'dimethyl': 1,
#  'silylate': 1,
#  'fluorphlogopite': 1,
#  'behenateeicosadioate': 1,
#  'persea': 1,
#  'gratissima': 1,
#  'petal': 1,
#  'asiatica': 1,
#  'prostrata': 1,
#  'nut': 1,
#  'musk': 1,
#  'polyacrylate': 1,
#  'starch': 1,
#  'alumina': 1,
#  'enzymes': 1,
#  'tailam': 1,
#  'caprylylcapryl': 1,
#  'xylitylglucoside': 1,
#  'anhydroxylitol': 1,
#  'xylitol': 1,
#  'gluconate': 1,
#  'jasminum': 1,
#  'grandiflorum': 1,
#  'centifolia': 1,
#  'ocimum': 1,
#  'basilicum': 1,
#  'santalum': 1,
#  'album': 1,
#  'cocoamphodiacetate': 1,
#  'distillate': 1,
#  'surajmukhi': 1,
#  'arandi': 1,
#  'lecithin': 1,
#  'cleanser': 1,
#  'glycyrrhiza': 1,
#  'glabra': 1,
#  'punica': 1,
#  'granatum': 1,
#  'nigra': 1,
#  'arctostaphylos': 1,
#  'uva': 1,
#  'ursi': 1,
#  'lactic': 1,
#  'cold': 1,
#  'pressed': 1,
#  'k': 1,
#  'sulfoacetate': 1,
#  'color': 1,
#  'long': 1,
#  'pepper': 1}

# %%
# get top "#elementCount" ingridients
topElements = list(sorted_occurences.keys())[0:elementCount]
print(topElements)
# Out:
# ['oil', 'sodium', 'extract', 'water', 'glycerin', 'powder', 'and', 'acid', 'fragrance', 'aloe', 'lauryl', 'vera', 'phenoxyethanol', 'turmeric', 'sandalwood', 'ci', 'vitamin', 'methylparaben', 'glycol', 'glucoside', 'benzoate', 'e', 'propylparaben', 'qs', 'potassium', 'base', 'sorbate', 'alcohol', 'citric', 'saffron', 'glyceryl', 'hydroxide', 'paraben', 'disodium', 'almond', 'of', 'neem', 'sulfate', 'acetate', 'purified', 'aqua', 'butter', 'rose', 'gum', 'betaine', 'edta', 'seed', 'cetyl', 'dimethicone', 'glutamate', 'decyl', 'tocopheryl', 'triethanolamine', 'cl', 'titanium', 'dioxide', 'root', 'stearate', 'orange', 'honey']

# %%
# export top elements to file
topElementsFile = open("dataset/topBeautyLabels.txt", "w")
for element in topElements:
    if(element == topElements[-1]):
        topElementsFile.write(element)
    else:
        topElementsFile.write(element + ",")
topElementsFile.close()

# %%
# create a histogram

import matplotlib.pyplot as plt
import numpy as np

plt.bar(sorted_occurences.keys(), sorted_occurences.values(), color='g')
plt.show()
